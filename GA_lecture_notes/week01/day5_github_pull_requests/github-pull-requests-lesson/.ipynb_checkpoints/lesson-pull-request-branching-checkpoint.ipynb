# %% [markdown]
# <img src="http://imgur.com/1ZcRyrc.png" style="float: left; margin: 20px; height: 55px">
#
# # Github Pull Request and Branching
# ___

# %% [markdown]
# <h1>Lesson Guide<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Github-Pull-Request-and-Branching" data-toc-modified-id="Github-Pull-Request-and-Branching-1">Github Pull Request and Branching</a></span><ul class="toc-item"><li><span><a href="#Learning-objectives" data-toc-modified-id="Learning-objectives-1.1">Learning objectives</a></span></li><li><span><a href="#Review" data-toc-modified-id="Review-1.2">Review</a></span><ul class="toc-item"><li><span><a href="#The-git-pull-command" data-toc-modified-id="The-git-pull-command-1.2.1">The git pull command</a></span></li></ul></li><li><span><a href="#Pull-request" data-toc-modified-id="Pull-request-1.3">Pull request</a></span><ul class="toc-item"><li><span><a href="#What-is-a-pull-request-?" data-toc-modified-id="What-is-a-pull-request-?-1.3.1">What is a pull request ?</a></span></li><li><span><a href="#How-it-works-visually" data-toc-modified-id="How-it-works-visually-1.3.2">How it works visually</a></span></li><li><span><a href="#Let's-get-our-hands-dirty" data-toc-modified-id="Let's-get-our-hands-dirty-1.3.3">Let's get our hands dirty</a></span></li></ul></li><li><span><a href="#Branching" data-toc-modified-id="Branching-1.4">Branching</a></span></li><li><span><a href="#What-is-Branching-and-where-does-it-come-from?" data-toc-modified-id="What-is-Branching-and-where-does-it-come-from?-1.5">What is Branching and where does it come from?</a></span><ul class="toc-item"><li><span><a href="#Until-now" data-toc-modified-id="Until-now-1.5.1">Until now</a></span></li><li><span><a href="#With-branching" data-toc-modified-id="With-branching-1.5.2">With branching</a></span></li></ul></li><li><span><a href="#Concretely,-how-do-we-use-it?" data-toc-modified-id="Concretely,-how-do-we-use-it?-1.6">Concretely, how do we use it?</a></span><ul class="toc-item"><li><span><a href="#Let's-practice-branching" data-toc-modified-id="Let's-practice-branching-1.6.1">Let's practice branching</a></span><ul class="toc-item"><li><span><a href="#Create-a-repository" data-toc-modified-id="Create-a-repository-1.6.1.1">Create a repository</a></span></li><li><span><a href="#Create-a-branch" data-toc-modified-id="Create-a-branch-1.6.1.2">Create a branch</a></span></li></ul></li><li><span><a href="#When-working-on-a-large-project,-branching-tends-to-look-like-this:" data-toc-modified-id="When-working-on-a-large-project,-branching-tends-to-look-like-this:-1.6.2">When working on a large project, branching tends to look like this:</a></span></li><li><span><a href="#The-ugly-duckling:-merge-conflict" data-toc-modified-id="The-ugly-duckling:-merge-conflict-1.6.3">The ugly duckling: merge conflict</a></span></li><li><span><a href="#What-is-a-merge-conflict-and-how-does-it-happen?" data-toc-modified-id="What-is-a-merge-conflict-and-how-does-it-happen?-1.6.4">What is a merge conflict and how does it happen?</a></span></li><li><span><a href="#Resolving-merge-conflicts" data-toc-modified-id="Resolving-merge-conflicts-1.6.5">Resolving merge conflicts</a></span><ul class="toc-item"><li><span><a href="#First-solution:-tell-git-which-file-you-want-to-keep" data-toc-modified-id="First-solution:-tell-git-which-file-you-want-to-keep-1.6.5.1">First solution: tell git which file you want to keep</a></span></li><li><span><a href="#Second-solution:-manually-edit-the-file" data-toc-modified-id="Second-solution:-manually-edit-the-file-1.6.5.2">Second solution: manually edit the file</a></span></li></ul></li></ul></li><li><span><a href="#Breakout-(5-min)" data-toc-modified-id="Breakout-(5-min)-1.7">Breakout (5 min)</a></span><ul class="toc-item"><li><span><a href="#In-pairs,-explain-with-your-own-words-:" data-toc-modified-id="In-pairs,-explain-with-your-own-words-:-1.7.1">In pairs, explain with your own words :</a></span></li></ul></li></ul></li></ul></div>

# %% [markdown]
# ## Learning objectives
#
# - Open a pull request on github
# - Understand the concept of branching

# %% [markdown]
# ## Review
#
# - What is the difference between local and remote repository?
# - What are each of those git commands used for?
#     - fork
#     - clone
#     - add
#     - commit
#     - log
#     - push
#     - pull

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### The git pull command
#
# In order to get the lessons, every morning, you have to do (from the lessons repo):
#     - git pull upstream master
#     - git push origin master

# %%
#upstream and origin 都是names，可以修改

# %% [markdown]
# The "git pull"  command will fetch and replay the changes from the remote master branch since it diverged from the local master (i.e., until its current commit):
#
# ![image.png](attachment:image.png)
#
#
# **Checkout (in pairs):** The above schema does not reflect the workflow we use to share the lessons. Draw a new one that represents it.

# %% [markdown]
# ## Pull request

# %% [markdown]
# ### What is a pull request ?
#
# - After adding, committing, and pushing, if you're collaborating on a project, one of the common ways to **share your code** is to do a pull request (PR)
# - At that point, whoever you're working with **will look over the code you've issued a pull request on**, and make any comments/suggestions they have, or ask any questions
#     - If hosted through Github (or some similar system), these typically **take place through the browser**. In it you can have a discussion about pieces of the code and even view the changes made (see the pictures in the following slides).
# - Once your code is ready to merge, the other person (or you if you have the correct rights) will merge via the browser (ie: "accept" the Pull Request, and then close it).

# %% [markdown]
# ### How it works visually
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Let's get our hands dirty
#
# - Using the command line, navigate into the project submission folder
# - If you haven't done it yet, create a folder with a text file in it (name them respectively  `<Your-FirstName-LastName>` and `hello_world.md`)
# - Write a few words in the text file
# - Add, commit and push your changes
# - Finally, go on your project submission repository page to check that your changes have been committed:
#
# ```
# https://git.generalassemb.ly/<your_username_here>/DSI9-project-submissions
# ```

# %% [markdown]
# **Click on `New pull request`**
#
# ![image.png](attachment:image.png)

# %% [markdown]
# **Then, select the repository to which you want to submit the pull request (for the projects, the central DSI one) and push again `Create pull request`.**
#
# The left button displays the repo from which you forked, the right one your forked version. The buttons with `master` allow you to select different branches if they exist, see below.
#
# ![git-6.png](attachment:git-6.png)

# %% [markdown]
# **Check if it worked by going to the central repository. Click on the icon `Pull requests` and look for yours.**
#
# ![git_pull.png](attachment:git_pull.png)

# %% [markdown]
# **Once you found your pull request, click on it. You will see a window like the following one. If your proposed changes are acknowledged, one of the admins of the repository will merge your pull request into the central repository.**
# ![git-7.png](attachment:git-7.png)

# %% [markdown]
# Once your pull requets has been **reviewed and accepted**, your folder will appear in the course repository.
#
# **Well done this is your first Pull Request :)**

# %% [markdown]
# ## Branching
#
# - Pull requests are one way to collaborate with a team assuming one person has **authority over the repository** (*authority*: higher admin rights over the repository in order to review the Pull Request, comment / validate them)
# - Another way to collaborate is to use branching

# %% [markdown]
# ## What is Branching and where does it come from?

# %% [markdown]
# ### Until now
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ### With branching
#
# ![image.png](attachment:image.png)
#
#
# * **Question**: How does it look like?

# %% [markdown]
# ## Concretely, how do we use it?
#
#
#
# - Unlike trees, with version control branching, at some point we need to merge the branches. This process looks like this:
#
# ![image.png](attachment:image.png)
#
# * **Question**: How do you think you could use branching during this course?

# %% [markdown]
# ### Let's practice branching

# %% [markdown]
# #### Create a repository
#
# - Go to https://git.generalassemb.ly
# - Create a new repository (Click on the + in top right corner) and give it a name (note that you can make public or private)
# - Optional: Initialize the repository with a readme-file
# - Optional: Add a `.gitignore` file designed for python
#     - A `.gitignore` file can list files which should not be tracked (e.g. a lot of hidden files)
# - Click on `clone or download` and copy the link
#
# - Open the terminal and type `cd` + enter (making sure you are in your home directory)
# - Enter: `git clone` + the link you just copied
# - Type `ls` to see your repository and `cd` into it

# %% [markdown]
# #### Create a branch
#
# - Let's create a branch, type:
#     `git branch <name_of_your_branch>`
# - We are now going to move the workspace to the branch we just created:
#     `git checkout <name_of_your_branch>`
#
# This is a different "working environment" than the master branch. As a consequence, if we **create files / folders and move back to the master branch, we won't be able to see them**.
#
# - Still in your branch, create a folder and a text file into it
# - Add, commit and push the folder you just created
# - Note that you now need to specify the branch you are pushing to
# - Next, got to your repository on https://git.generalassemb.ly and try to visualize the branch just created.
#
# Finally let's merge your branch:
# ```
# git checkout master
# git pull origin master
# git merge <name_of_your_branch>
# git push origin master
# ```
#
# **Note:** In reality you will wait until you finish the reason why you created the branch to merge it.

# %% [markdown]
# ### When working on a large project, branching tends to look like this:
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ### The ugly duckling: merge conflict
#
#
# Sometimes you get merge conflicts when merging or pulling from a branch. Git will then tell you something like
#
# ```
# CONFLICT (content): Merge conflict in Fakefile
# ```
#
# It also tells you to fix the conflicts and then to commit the result. **So how to fix the conflicts?**

# %% [markdown]
# ### What is a merge conflict and how does it happen?
#
# A merge conflict usually occurs when your current branch and the branch you want to merge into the current branch **have diverged**. That is, you have commits in your current branch which **are not in the other branch, and vice versa**.
#
# When Git merges the other branch into your current branch, it looks at the differences between latest common commits. When there are unambiguous differences (i.e. only one side changed a certain piece of code), **the changes are applied**.
#
# The merge conflicts occur when there are **disagreeing changes** (typically, both branches have new commits). In that case, your conflicted file will have so-called conflict markers:
#
# ```
# <<<<<<< HEAD
# jars/VIB-lib.jar
# =======
# plugins/Plugin.jar
# >>>>>>> branch-with-amazing-new-feature
# ```

# %% [markdown]
# ### Resolving merge conflicts

# %% [markdown]
# #### First solution: tell git which file you want to keep
#
# - for your version:
# ```
# git checkout --ours <file_with_merge_conflict>
# ```
#
# - for their version:
# ```
# git checkout --theirs <file_with_merge_conflict>
# ```

# %% [markdown]
# #### Second solution: manually edit the file
#
# When you have a merge conflict, git will automatically point the differences in the files using `<<<<<<` or `>>>>>>` (also called conflict markers) to indicate which changes belongs to who.
#
# - You can consequently either:
#     - change manually the contents of the file
#     - use a built in tool like the one in `Atom`:
#
# ![image.png](attachment:image.png)
#
# To see those, you just have to navigate to the file with merge conflicts and click on the changes you want to keep.

# %% [markdown]
# ## Breakout (5 min)
#
# ### In pairs, explain with your own words :
#
# - What is a pull request?
# - What is the difference with the command `pull`?
# - What is the difference between pull requests and branching?
# - What is a merge conflict? In which situation you might have a merge conflict with the project-submissions repository?
