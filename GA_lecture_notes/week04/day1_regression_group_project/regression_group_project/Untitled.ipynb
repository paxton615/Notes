# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

sns.set(font_scale=1.5)
# %config InlineBackend.figure_format = 'retina'
# %matplotlib inline

# %%
from sklearn.datasets import load_diabetes
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LinearRegression, Ridge, Lasso, RidgeCV, LassoCV

# %%
import csv
import os

# %%
import pandas as pd
#pd.read_csv (r'Path where the CSV file is stored\File name.csv')
movies = pd.read_csv("/Users/paxton615/Desktop/movies_metadata.csv", low_memory=False)
ratings = pd.read_csv("/Users/paxton615/Desktop/ratings (1).csv", low_memory=False)

# %%
movies_rev = movies[(movies['revenue'] != 0)]
movies_rev = movies_rev[(movies_rev['runtime'] != 0)]
movies_rev.drop(columns=['belongs_to_collection', 'tagline', 'adult', 
                         'imdb_id', 'overview', 'poster_path', 'homepage', 'production_countries', 'video'], inplace=True)
movies_rev = movies_rev[(movies_rev['runtime'].isnull()==False)]
movies_rev = movies_rev[(movies_rev['popularity'].isnull()==False)]
movies_rev = movies_rev[(movies_rev['release_date'].isnull()==False)]
movies_rev = movies_rev[(movies_rev['status'].isnull()==False)]
movies_rev.popularity = movies_rev.popularity.astype(float)
movies_rev = pd.get_dummies(movies_rev, columns = ['status'])
movies_rev.budget = movies_rev.budget.astype(float)

# %%
#movies.release_date.drop([45461],axis=0, inplace = True)

# %%
movies.release_date.shape
# Out:
# (45466,)

# %%
movies.release_date.dropna(inplace=True)

# %%
#movies[df.Name != 'Alisa']

# %%
movies_rev.release_date.isnull().sum()
# Out:
# 0

# %%
movies.release_date.drop(movies.index[45461], axis=0, inplace=True)

# %%
movies.release_date.shape
# Out:
# (45466,)

# %%
movies.shape
# Out:
# (45466, 25)

# %%
#movies.release_date.describe

# %%
import datetime as dt

#movies['release_date'] = movies['release_date'].apply(lambda x : pd.to_datetime(str(x)))

#movies['dates'] = movies['release_date'].dt.date

# %%
#movies.release_date[200].split('-')[0]

# %%
#movies.release_date[45461]

# %%
2010-10-20

# %%
movies_rev["year"]= movies_rev.release_date.apply(lambda x: float((str(x).split("-"))[0]))
#movies["month"]=movies.release_date.apply(lambda x: float((str(x).split("-"))[1]))

# %%
movies_rev["month"]=movies_rev.release_date.apply(lambda x: float((str(x).split("-"))[1]))

# %%
#df['year'] = pd.DatetimeIndex(df['ArrivalDate']).year
#df['month'] = pd.DatetimeIndex(df['ArrivalDate']).month

# %%
#movies["year"]= movies.release_date.apply(lambda x: x.split("-")[0])

# %%
#df['ArrivalDate'] = pandas.to_datetime(df['ArrivalDate'])
#df['Month'] = df['ArrivalDate'].values.astype('datetime64[M]')

# %%
movies_rev.head()
# Out:
#        budget                                             genres     id  \
# 0  30000000.0  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...    862
# 1  65000000.0  [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...   8844
# 3  16000000.0  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...  31357
# 4         0.0                     [{'id': 35, 'name': 'Comedy'}]  11862
# 5  60000000.0  [{'id': 28, 'name': 'Action'}, {'id': 80, 'nam...    949
#
#   original_language               original_title  popularity  \
# 0                en                    Toy Story   21.946943
# 1                en                      Jumanji   17.015539
# 3                en            Waiting to Exhale    3.859495
# 4                en  Father of the Bride Part II    8.387519
# 5                en                         Heat   17.924927
#
#                                 production_companies release_date  \
# 0     [{'name': 'Pixar Animation Studios', 'id': 3}]   1995-10-30
# ...

# %%
# Out:
# Empty DataFrame
# Columns: [userId, movieId, rating, timestamp]
# Index: []

# %%
movie.shape
# Out:
# (45466, 24)

# %%
ratings[ratings["movieId"]==862]
# Out:
#           userId  movieId  rating   timestamp
# 184624      1923      862     3.0   858335006
# 200490      2103      862     5.0   946044912
# 524001      5380      862     1.0   878941641
# 610887      6177      862     4.0   859415226
# 643892      6525      862     4.0   857388995
# 692440      7050      862     3.0   951328483
# 712546      7238      862     3.0   988054686
# 842326      8659      862     4.0   997143296
# 913951      9328      862     4.0  1037486302
# 949383      9682      862     4.0   949005840
# 1025383    10425      862     3.0   878083313
# 1101490    11214      862     3.5  1078418362
# 1343494    13839      862     4.0  1182659035
# 1480781    15235      862     5.0   860224118
# 1571386    16287      862     4.0   877197469
# 1656549    17210      862     4.0   975100124
# 1656917    17211      862     5.0   953170641
# 1668820    17325      862     5.0  1487586599
# 1682586    17489      862     4.0   962654115
# ...

# %%
movies
# Out:
#        adult                              belongs_to_collection    budget  \
# 0      False  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1      False                                                NaN  65000000
# 2      False  {'id': 119050, 'name': 'Grumpy Old Men Collect...         0
# 3      False                                                NaN  16000000
# 4      False  {'id': 96871, 'name': 'Father of the Bride Col...         0
# 5      False                                                NaN  60000000
# 6      False                                                NaN  58000000
# 7      False                                                NaN         0
# 8      False                                                NaN  35000000
# 9      False  {'id': 645, 'name': 'James Bond Collection', '...  58000000
# 10     False                                                NaN  62000000
# 11     False                                                NaN         0
# ...

# %%
movies[movies["id"]== 862]
# Out:
# Empty DataFrame
# Columns: [adult, belongs_to_collection, budget, genres, homepage, id, imdb_id, original_language, original_title, overview, popularity, poster_path, production_companies, production_countries, release_date, revenue, runtime, spoken_languages, status, tagline, title, video, vote_average, vote_count]
# Index: []
#
# [0 rows x 24 columns]

# %%
movie.shape
# Out:
# (45466, 24)

# %%
movie.describe()
# Out:
#             revenue       runtime  vote_average    vote_count
# count  4.546000e+04  45203.000000  45460.000000  45460.000000
# mean   1.120935e+07     94.128199      5.618207    109.897338
# std    6.433225e+07     38.407810      1.924216    491.310374
# min    0.000000e+00      0.000000      0.000000      0.000000
# 25%    0.000000e+00     85.000000      5.000000      3.000000
# 50%    0.000000e+00     95.000000      6.000000     10.000000
# 75%    0.000000e+00    107.000000      6.800000     34.000000
# max    2.787965e+09   1256.000000     10.000000  14075.000000

# %%
movie[movie["revenue"]==0]
# Out:
#        adult                              belongs_to_collection    budget  \
# 2      False  {'id': 119050, 'name': 'Grumpy Old Men Collect...         0
# 6      False                                                NaN  58000000
# 7      False                                                NaN         0
# 11     False                                                NaN         0
# 21     False                                                NaN         0
# 23     False                                                NaN         0
# 25     False                                                NaN         0
# 27     False                                                NaN         0
# 29     False                                                NaN         0
# 32     False                                                NaN         0
# 34     False                                                NaN         0
# 36     False                                                NaN         0
# ...

# %%
movies_rev = movies[(movies['revenue'] != 0)]
