# %% [markdown]
# # Web Scraping
#
# ![](scraping_meme.jpg)
#
# ## Objectives
#
# - Understand what Web Scraping is.
# - Understand why as Data Scientists we might want to scrape the web.
# - Use `requests` and `BeautifulSoup` to scrape data from the web using Python.

# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Objectives" data-toc-modified-id="Objectives-1">Objectives</a></span></li><li><span><a href="#Why-do-we-scrape-the-web?" data-toc-modified-id="Why-do-we-scrape-the-web?-2">Why do we scrape the web?</a></span><ul class="toc-item"><li><span><a href="#Getting-Info-from-a-Web-Page" data-toc-modified-id="Getting-Info-from-a-Web-Page-2.1">Getting Info from a Web Page</a></span></li><li><span><a href="#If-I-wanted-to-get-a-list-of-all-of-the-countries-visited,-how-would-I-do-it?" data-toc-modified-id="If-I-wanted-to-get-a-list-of-all-of-the-countries-visited,-how-would-I-do-it?-2.2">If I wanted to get a list of all of the countries visited, how would I do it?</a></span></li></ul></li><li><span><a href="#Getting-Info-from-a-Web-Page" data-toc-modified-id="Getting-Info-from-a-Web-Page-3">Getting Info from a Web Page</a></span><ul class="toc-item"><li><span><a href="#Requests-Library" data-toc-modified-id="Requests-Library-3.1">Requests Library</a></span></li></ul></li><li><span><a href="#Example:-Autotrader" data-toc-modified-id="Example:-Autotrader-4">Example: Autotrader</a></span><ul class="toc-item"><li><span><a href="#Now-that-we-have-the-web-page,-we-can-parse-it-with-BeautifulSoup:" data-toc-modified-id="Now-that-we-have-the-web-page,-we-can-parse-it-with-BeautifulSoup:-4.1">Now that we have the web page, we can parse it with BeautifulSoup:</a></span></li><li><span><a href="#We-can-now-set-up-a-loop-to-go-through-all-the-different-pages-of-this-website-search:" data-toc-modified-id="We-can-now-set-up-a-loop-to-go-through-all-the-different-pages-of-this-website-search:-4.2">We can now set up a loop to go through all the different pages of this website search:</a></span></li></ul></li><li><span><a href="#Pair-Practice:-Rightmove" data-toc-modified-id="Pair-Practice:-Rightmove-5">Pair Practice: Rightmove</a></span></li></ul></div>

# %%
import pandas as pd
import numpy as np
from bs4 import BeautifulSoup
import requests
from tqdm import tqdm_notebook

# %% [markdown]
# ## Why do we scrape the web?
#
# * Realistically, data that you want to study won't always be available to you in the form of a curated data set.
# * Need to go to the internet to find interesting data:
#     * From an existing company
#     * Text for NLP
#     * Images

# %% [markdown]
# # Scraping from a Web Page with Python
#
# Scraping a web site basically comes down to making a **request from Python and parsing through the HTML** that is returned from each page. For each of these tasks we have a Python library, **`requests` and `bs4`**, respectively.
#
# https://www.crummy.com/software/BeautifulSoup/bs4/doc/

# %% [markdown]
# ### Getting Info from a Web Page
#
# Now that we can gain easy access to the HMTL for a web page, we need **some way to pull the desired content from it**. Luckily there is already a system in place to do this. With a **combination of HMTL and CSS selectors** we can identify the information on a HMTL page that we wish to retrieve and grab it with [BeautifulSoup](https://www.crummy.com/software/BeautifulSoup/bs4/doc/#searching-the-tree).

# %%
html = '''<!DOCTYPE html>
<html>
<head>
<title>The title of this web page</title>
</head>
<body>
<h1>My Photos</h1>
<div class='intro'>
<p>These are some photos of my trips.</p>
<img src="me.png">
</div>

<h3>Italy</h3>
<div class='country'>
<img src="venice1.png" alt="Venice"> <br />
<img src="venice2.png" alt="Venice"> <br />
<img src="rome.png" alt="Roma">
</div>

<h3>Germany</h3>
<div class='country'>
<img src="berlin.png" alt="Berlin">
</div>
</body>
</html>
'''

# %%
from bs4 import BeautifulSoup

# we create a soup object with the html:
soup = BeautifulSoup(html, 'html.parser')

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html>
#  <head>
#   <title>
#    The title of this web page
#   </title>
#  </head>
#  <body>
#   <h1>
#    My Photos
#   </h1>
#   <div class="intro">
#    <p>
#     These are some photos of my trips.
#    </p>
#    <img src="me.png"/>
#   </div>
#   <h3>
#    Italy
#   </h3>
#   <div class="country">
#    <img alt="Venice" src="venice1.png"/>
#    <br/>
#    <img alt="Venice" src="venice2.png"/>
#    <br/>
#    <img alt="Roma" src="rome.png"/>
#   </div>
#   <h3>
#    Germany
#   </h3>
#   <div class="country">
#    <img alt="Berlin" src="berlin.png"/>
#   </div>
#  </body>
# </html>

# %%
# now we can query it
soup.title
# Out:
# <title>The title of this web page</title>

# %%
soup.title.text
# Out:
# 'The title of this web page'

# %%
soup.h1
# Out:
# <h1>My Photos</h1>

# %%
soup.h3
# Out:
# <h3>Italy</h3>

# %%
soup.find('h3')
# Out:
# <h3>Italy</h3>

# %%
soup.find_all('h3')
# Out:
# [<h3>Italy</h3>, <h3>Germany</h3>]

# %%
soup.find_all('h3')[1].text
# Out:
# 'Germany'

# %%
soup.find_all('div', class_='country')
# Out:
# [<div class="country">
#  <img alt="Venice" src="venice1.png"/> <br/>
#  <img alt="Venice" src="venice2.png"/> <br/>
#  <img alt="Roma" src="rome.png"/>
#  </div>, <div class="country">
#  <img alt="Berlin" src="berlin.png"/>
#  </div>]

# %%
soup.find_all('img', alt='Venice')
# Out:
# [<img alt="Venice" src="venice1.png"/>, <img alt="Venice" src="venice2.png"/>]

# %%
soup.find('div', class_='country').find_previous_siblings('h3')
# Out:
# [<h3>Italy</h3>]

# %% [markdown]
# ### If I wanted to get a list of all of the countries visited, how would I do it?

# %%
#A

# %% [markdown]
# ## Getting Info from a Web Page

# %% [markdown]
# ### Requests Library
#
# The [requests](http://docs.python-requests.org/en/latest/index.html) library is designed to simplify the process of making **http requests within Python**. The interface is mind-bogglingly simple. Instantiate a requests object to the request, this will mostly be a `get`, with the URL and optional parameters you'd like passed through the request. That instance make the results of the request available via attributes/methods.

# %% [markdown]
# ## Example: Autotrader

# %%
import requests

url = 'https://www.autotrader.co.uk/\
car-search?sort=sponsored&radius=10&postcode=e16lt&onesearchad=Used&onesearchad=Nearly%20New&onesearchad=New'

r = requests.get(url)

# %%
r.text[:1000] # First 1000 characters of the HTML
# Out:
# '<!DOCTYPE html>\n<html lang="en-GB" class="is-not-modern property-for-sale channel--buy ">\n<head>\n    <meta charset="utf-8">\n    <title>Properties For Sale in London - Flats &amp; Houses For Sale in London - Rightmove</title>\n    <meta http-equiv="X-UA-Compatible" content="IE=Edge"/>\n    <meta name="viewport" content="width=device-width, shrink-to-fit=no, initial-scale=1.0, user-scalable=no"/>\n    <meta name="format-detection" content="telephone=no"/>\n    <meta name="HandheldFriendly" content="True"/>\n    <meta name="description" content="Find Properties For Sale in London - Flats &amp; Houses For Sale in London - Rightmove. Search over 900,000 properties for sale from the top estate agents and developers in the UK - Rightmove."/>\n        <meta name="referrer" content="origin-when-cross-origin">\n    \n    <link rel="preconnect" href="https://media.rightmove.co.uk:443" crossorigin/>\n    <link rel="preconnect" href="//product.rightmove.co.uk" crossorigin/><link rel="shortcut icon" href="/p'

# %% [markdown]
# ### Now that we have the web page, we can parse it with BeautifulSoup:

# %%
soup = BeautifulSoup(r.text, 'html.parser')

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html class="is-not-modern property-for-sale channel--buy" lang="en-GB">
#  <head>
#   <meta charset="utf-8"/>
#   <title>
#    Properties For Sale in London - Flats &amp; Houses For Sale in London - Rightmove
#   </title>
#   <meta content="IE=Edge" http-equiv="X-UA-Compatible">
#    <meta content="width=device-width, shrink-to-fit=no, initial-scale=1.0, user-scalable=no" name="viewport"/>
#    <meta content="telephone=no" name="format-detection"/>
#    <meta content="True" name="HandheldFriendly"/>
#    <meta content="Find Properties For Sale in London - Flats &amp; Houses For Sale in London - Rightmove. Search over 900,000 properties for sale from the top estate agents and developers in the UK - Rightmove." name="description"/>
#    <meta content="origin-when-cross-origin" name="referrer"/>
#    <link crossorigin="" href="https://media.rightmove.co.uk:443" rel="preconnect"/>
#    <link crossorigin="" href="//product.rightmove.co.uk" rel="preconnect"/>
#    <link href="/pvw/images/favicons/rebranded/favicon.ico" rel="shortcut icon"/>
#    <link href="/pvw/images/favicons/rebranded/apple-touch-icon-72x72.png" rel="apple-touch-icon" sizes="72x72"/>
#    <link href="/pvw/images/favicons/rebranded/apple-touch-icon-114x114.png" rel="apple-touch-icon" sizes="114x114"/>
#    <link href="/pvw/images/favicons/rebranded/apple-touch-icon-120x120.png" rel="apple-touch-icon" sizes="120x120"/>
#    <link href="/pvw/images/favicons/rebranded/apple-touch-icon-144x144.png" rel="apple-touch-icon" sizes="144x144"/>
#    <link href="/pvw/images/favicons/rebranded/apple-touch-icon-152x152.png" rel="apple-touch-icon" sizes="152x152"/>
#    <meta content="#262637" name="msapplication-TileColor"/>
#    <meta content="/pvw/images/favicons/rebranded/mstile-144x144.png" name="msapplication-TileImage"/>
#    <meta content="/pvw/images/favicons/rebranded/browserconfig.xml" name="msapplication-config"/>
#    <link href="/pvw/images/favicons/rebranded/manifest.json" rel="manifest"/>
#    <script>
#     var RESOURCE_PREFIX = '';
#    </script>
#    <meta content="Rightmove" name="apple-mobile-web-app-title"/>
#    <meta content="Rightmove" name="application-name"/>
#    <meta content="#262637" name="theme-color"/>
#    <meta content="/" property="og:url">
#     <meta content="Rightmove.co.uk" property="og:title">
#      <meta content="website" property="og:type">
#       <meta content="/pvw/images/favicons/rebranded/logo-share-fb.png" property="og:image">
#        <meta content="en_GB" property="og:locale">
#         <meta content="Rightmove.co.uk" property="og:site_name">
#          <meta content="Search over a Million properties for sale and to rent from the top estate agents and developers in the UK" property="og:description">
#           <meta content="rightmove.plc" property="fb:admins"/>
#           <meta content="485764298115191" property="fb:app_id"/>
#           <meta content="2911111" property="twitter:account_id"/>
#           <link href="https://www.rightmove.co.uk/property-for-sale/London-87490.html" rel="canonical">
#            <!--[if (lte IE 9)&(!IEMobile)]>
#     <script src="/pvw/javascript/oldie.273884a1c9b3de397aab.js"></script>
#     <![endif]-->
#            <!--[if (IE 8)&(!IEMobile)]>
#     <script>window.isIE8 = true;</script>
#     <![endif]-->
#            <!--[if (IE 9)&(!IEMobile)]>
#     <script>window.isIE9 = true;</script>
#     <![endif]-->
#            <style type="text/css">
#             svg {
#             display: none;
#         }
#            </style>
#            <style type="text/css">
#             @font-face {
#         font-family: 'effra-medium';
#         src: url('/pvw/fonts/Effra_WLatn_Md.eot'); /* IE9 Compat Modes */
#         src: /* IE6-IE8 */ url('/pvw/fonts/Effra_WLatn_Md.eot?#iefix') format('embedded-opentype'),
#             /* Super Modern Browsers */ url('/pvw/fonts/Effra_WLatn_Md.woff2') format('woff2'),
#             /* Pretty Modern Browsers */ url('/pvw/fonts/Effra_WLatn_Md.woff') format('woff');
#         font-style: normal;
#     }
#
#     @font-face {
#         font-family: 'effra-regular';
#         src: url('/pvw/fonts/Effra_WLatn_Rg.eot');
#         src: /* IE6-IE8 */ url('/pvw/fonts/Effra_WLatn_Rg.eot?#iefix') format('embedded-opentype'),
#             /* Super Modern Browsers */ url('/pvw/fonts/Effra_WLatn_Rg.woff2') format('woff'),
#             /* Pretty Modern Browsers */ url('/pvw/fonts/Effra_WLatn_Rg.woff') format('woff');
#         font-style: normal;
#     }
#            </style>
#            <link href="/pvw/css/rebranded-font.search.head.0152f0c3bd3b35e4582b.css" rel="stylesheet"/>
#            <link href="/pvw/css/rebranded-font.search.build.41ca962a58e15c9ffa13.css" media="spoderman" rel="stylesheet"/>
#            <link href="/pvw/css/rebranded-font.search.no-results.b5f47e7fff923f33fb75.css" media="spoderman" rel="stylesheet"/>
#            <!--[if (lte IE 9)&(!IEMobile)]>
#     <link rel="stylesheet" href="/pvw/css/rebranded-font.search.build.oldie.31bb5022da1e0ccadf3e.css">
# <![endif]-->
#            <script>
#             !function(e){var t={};function n(r){if(t[r])return t[r].exports;var o=t[r]={i:r,l:!1,exports:{}};return e[r].call(o.exports,o,o.exports,n),o.l=!0,o.exports}n.m=e,n.c=t,n.d=function(e,t,r){n.o(e,t)||Object.defineProperty(e,t,{enumerable:!0,get:r})},n.r=function(e){"undefined"!=typeof Symbol&&Symbol.toStringTag&&Object.defineProperty(e,Symbol.toStringTag,{value:"Module"}),Object.defineProperty(e,"__esModule",{value:!0})},n.t=function(e,t){if(1&t&&(e=n(e)),8&t)return e;if(4&t&&"object"==typeof e&&e&&e.__esModule)return e;var r=Object.create(null);if(n.r(r),Object.defineProperty(r,"default",{enumerable:!0,value:e}),2&t&&"string"!=typeof e)for(var o in e)n.d(r,o,function(t){return e[t]}.bind(null,o));return r},n.n=function(e){var t=e&&e.__esModule?function(){return e.default}:function(){return e};return n.d(t,"a",t),t},n.o=function(e,t){return Object.prototype.hasOwnProperty.call(e,t)},n.p="/pvw/",n(n.s=901)}({901:function(e,t,n){"use strict";var r=document.getElementsByTagName("link"),o=window.document.styleSheets;function u(e){for(var t=0,n=o.length;t<n;t++){var r=o[t];if(r.href&&r.href.indexOf(e.href)>-1)return e.media="all",!0}setTimeout(u,null,e)}!function(){for(var e=0,t=r.length;e<t;e++)"spoderman"===r[e].getAttribute("media")&&u(r[e])}()}});
#            </script>
#           </link>
#          </meta>
#         </meta>
#        </meta>
#       </meta>
#      </meta>
#     </meta>
#    </meta>
#   </meta>
#  </head>
#  <body class="header-rebranding rebranded-logo">
#   <noscript>
#    <iframe height="0" src="//www.googletagmanager.com/ns.html?id=GTM-T4524Q&gt;m_auth=g2ndo_352oWlGwJG7HHfyw&gt;m_preview=env-7&gt;m_cookies_win=x" style="display:none;visibility:hidden" width="0">
#    </iframe>
#   </noscript>
#   <svg height="0" style="position:absolute" width="0">
#    <symbol id="core-icon--account-silhouette" viewbox="0 0 13.8 21.8">
#     <circle cx="6.9" cy="5" r="5">
#     </circle>
#     <path d="M12 13.6L8.7 12c-.5-.2-1.2-.4-1.8-.4s-1.3.2-1.8.4l-3.3 1.6c-1 .5-1.8 1.8-1.8 2.9v3.3c0 1.1.9 2 2 2h9.8c1.1 0 2-.9 2-2v-3.3c0-1.1-.8-2.4-1.8-2.9z">
#     </path>
#    </symbol>
#    <symbol id="core-icon--awaiting-image" viewbox="0 0 16 16" xmlns="http://www.w3.org/2000/svg">
#     <path d="M11.88 2l-1 1H2.5A1.5 1.5 0 0 0 1 4.5v8c0 .107.034.206.091.288l-.652.651-.057.06A1.494 1.494 0 0 1 0 12.5v-8a2.5 2.5 0 0 1 2-2.45V1h3v1h6.88zm3.448.795c.417.447.672 1.046.672 1.705v8a1.5 1.5 0 0 1-1.5 1.5H4.121l1-1H14.5a.5.5 0 0 0 .5-.5v-8c0-.383-.143-.732-.38-.997l.708-.708zm-8.105 8.104l.903-.903a2 2 0 0 0 1.87-1.87l.903-.902a3.004 3.004 0 0 1-3.676 3.675zM5.102 8.778a3.004 3.004 0 0 1 3.676-3.676l-.902.902a2 2 0 0 0-1.872 1.872l-.902.902zm9.051-7.63a.5.5 0 0 1 .707.706l-13.001 13a.5.5 0 0 1-.707-.708L14.153 1.147z">
#     </path>
#    </symbol>
#    <symbol id="core-icon--camera" viewbox="0 0 16 16" xmlns="http://www.w3.org/2000/svg">
#     <path d="M2.5 2H2V1h3v1h8.5A2.5 2.5 0 0 1 16 4.5v8a1.5 1.5 0 0 1-1.5 1.5h-13A1.5 1.5 0 0 1 0 12.5v-8A2.5 2.5 0 0 1 2.5 2zm0 1A1.5 1.5 0 0 0 1 4.5v8a.5.5 0 0 0 .5.5h13a.5.5 0 0 0 .5-.5v-8A1.5 1.5 0 0 0 13.5 3h-11zM8 11a3 3 0 1 1 0-6 3 3 0 0 1 0 6zm0-1a2 2 0 1 0 0-4 2 2 0 0 0 0 4zm4-5h2v1h-2V5z">
#     </path>
#    </symbol>
#    <symbol id="core-icon--checkbox-tick" viewbox="0 0 378.2 291">
#     <path class="dst0" d="M357.9 3.3c-4.4-4.4-11.6-4.4-16 0L123.4 221.7c-4.4 4.4-11.6 4.4-16 0l-71.1-71.1c-4.4-4.4-11.6-4.4-16 0l-17 17c-4.4 4.4-4.4 11.6 0 16l104.1 104.1c4.4 4.4 11.6 4.4 16 0l17-17 16-16L374.9 36.3c4.4-4.4 4.4-11.6 0-16l-17-17z">
#     </path>
#    </symbol>
#    <symbol id="core-icon--chevron" viewbox="0 0 7.6 4.1">
#     <path d="M4 4L7.5.5c.2-.2.1-.5-.2-.5h-7C0 0-.1.3.1.5L3.6 4c.1.1.3.1.4 0z">
#     </path>
#    </symbol>
#    <symbol id="core-icon--chevron-double" viewbox="0 0 16 16">
#     <path d="M8 6.5L14.2.1c.2-.2.4-.2.6 0l1.1 1.1c.2.2.2.4 0 .6L8.3 9.7c-.1.1-.2.1-.3.1-.1 0-.2 0-.3-.1L.1 1.9c-.1-.2-.1-.4 0-.6L1.2.2c.2-.2.4-.2.6 0L8 6.5zm0 6.2l6.2-6.4c.2-.2.4-.2.6 0l1.1 1.1c.1.2.1.5 0 .6l-7.6 7.9c-.1.1-.2.1-.3.1-.1 0-.2 0-.3-.1L.1 8c-.1-.1-.1-.4 0-.5l1.1-1.1c.2-.2.4-.2.6 0L8 12.7z">
#     </path>
#    </symbol>
#    <symbol id="core-icon--chevron-line" viewbox="0 0 16 16">
#     <path d="M8 10.293l5.146-5.147a.5.5 0 0 1 .708.708l-5.5 5.5a.5.5 0 0 1-.708 0l-5.5-5.5a.5.5 0 1 1 .708-.708L8 10.293z">
#     </path>
#    </symbol>
#    <symbol id="core-icon--close" viewbox="0 0 16 16" xmlns="http://www.w3.org/2000/svg">
#     <path d="M7.293 8L1.146 1.854l.708-.708L8 7.293l6.146-6.147.708.708L8.707 8l6.147 6.146-.708.708L8 8.707l-6.146 6.147-.708-.708L7.293 8z" fill-rule="evenodd">
#     </path>
#    </symbol>
#    <symbol id="core-icon--cross" viewbox="0 0 15 15" xmlns="http://www.w3.org/2000/svg">
#     <path d="M13.246.87a.625.625 0 1 1 .884.884L1.754 14.13a.625.625 0 1 1-.884-.884L13.246.87z">
#     </path>
#     <path d="M1.754.87a.625.625 0 1 0-.884.884L13.246 14.13a.625.625 0 1 0 .884-.884L1.754.87z">
#     </path>
#    </symbol>
#    <symbol id="core-icon--floorplan" viewbox="0 0 16 16" xmlns="http://www.w3.org/2000/svg">
#     <path d="M14 8v5a1 1 0 0 1-1 1H7v1h6a2 2 0 0 0 2-2V3a2 2 0 0 0-2-2H3a2 2 0 0 0-2 2v10a2 2 0 0 0 2 2h2v-1H3a1 1 0 0 1-1-1v-2h7v-1H2V3a1 1 0 0 1 1-1h2v5h1V2h7a1 1 0 0 1 1 1v4H9v1h5z">
#     </path>
#    </symbol>
#    <symbol id="core-icon--rightmove-house" viewbox="0 0 35 35" xmlns="http://www.w3.org/2000/svg">
#     <path d="M2.4 13l10.8 5.2 2.5-.7.1 12.6-13.4-6.4" fill="#5A8D89">
#     </path>
#     <path d="M0 11.1L8.7 0 22 7l-8.7 10.5M22 4.9l2.9-1 3.4 1.7-3.2.8v2.4L22 7" fill="#94C04E">
#     </path>
#     <path d="M17.8 17.1l4.5-5.7 4.6 3.2-2 .6-.1 12.5-5 1.5-.1-12.6" fill="#A9D5D9">
#     </path>
#    </symbol>
#    <symbol id="core-icon--rightmove-house--blue" viewbox="0 0 160.7 170.9">
#     <path d="M13.6 73.8l61.3 29.5 14.2-4 .6 71.5-76.1-36.3" fill="#004D8C">
#     </path>
#             We're sorry, some parts of the Rightmove website don't work at their best without JavaScript enabled.
#             Please ensure your JavaScript is turned on to make sure you have the best experience.
#     </div>
#    </noscript>
#    <!--[if (lte IE 8)&(!IEMobile)]>
#     <div class="globalHeader-oldBrowser">
#         <p>You appear to be using a very old browser that doesn’t allow our site to work properly.</p>
#         <p>We recommend you:</p>
#         <ol>
#             <li>Update your browser</li>
#             <li>Use another up-to-date browser such as Chrome, Firefox or Safari.</li>
#         </ol>
#     </div>
#     <![endif]-->
#    <div class="l-container globalNav-wrapper" data-bind="css: {'globalNav--expanded': globalNavOpen}">
#     <a class="globalHeader-logo" data-bind="click: trackSubMenuItem('homepage', 'homepage')" href="/" title="Go to Rightmove homepage">
#      <div class="no-svg-rightmove-with-icon-logo globalHeader-logo-svg">
#       <svg>
#        <use xlink:href="#core-icon--rightmove-with-icon-logo">
#        </use>
#       </svg>
#      </div>
#     </a>
#     <nav class="globalNav" role="menubar">
#      <div class="globalNav-underlay" data-bind="css: { 'globalNav-underlay--open': currentSubNavMenuId }, click: closeHeader">
#      </div>
#      <div class="globalNav-container">
#       <div class="globalNav-item" data-bind="css : {'is-expanded': isGlobalNavItemOpen('buy')}">
#        <a class="globalNav-link globalNav-link--active" data-bind="click: toggleGlobalSubNav('buy', 'buy')" href="/property-for-sale.html">
#         <span>
#          Buy
#         </span>
#         <div class="no-svg-chevron select-chevron">
#          <svg>
#           <use xlink:href="#core-icon--chevron">
#           </use>
#          </svg>
#         </div>
#        </a>
#        <div class="globalNav-subNav" data-bind="stopScrollPropagation">
#         <ul class="globalNav-subNavColumn">
#          <li class="globalNav-subNavItem">
#           <a class="globalNav-subNavLink" data-bind="click: trackSubMenuItem('buy', 'property for sale')" href="/property-for-sale.html">
#            Property for sale
#           </a>
#          </li>
#          <li class="globalNav-subNavItem">
#           <a class="globalNav-subNavLink" data-bind="click: trackSubMenuItem('buy', 'new homes for sale')" href="/new-homes-for-sale.html">
#            New homes for sale
#           </a>
#          </li>
#         </ul>
#         <ul class="globalNav-subNavColumn">
#          <li class="globalNav-subNavItem">
#           <a class="globalNav-subNavLink" data-bind="click: trackSubMenuItem('buy', 'property valuation')" href="/property-valuation.html">
#            Property Valuation
#           </a>
#          </li>
#          <li class="globalNav-subNavItem">
#           <a class="globalNav-subNavLink" data-bind="click: trackSubMenuItem('buy', 'investors')" href="/property-investment.html">
#            Investors
#           </a>
#          </li>
#          <li class="globalNav-subNavItem">
#           <a class="globalNav-subNavLink" data-bind="click: trackSubMenuItem('buy', 'mortgages')" href="/mortgages/">
#            Mortgages
#           </a>
#          </li>
#         </ul>
#        </div>
#       </div>
#       <div class="globalNav-item" data-bind="css : {'is-expanded': isGlobalNavItemOpen('rent')}">
#        <a class="globalNav-link" data-bind="click: toggleGlobalSubNav('rent', 'rent')" href="/property-to-rent.html">
#         <span>
#          Rent
#         </span>
#         <div class="no-svg-chevron select-chevron">
#          <svg>
#           <use xlink:href="#core-icon--chevron">
#           </use>
#          </svg>
#         </div>
#        </a>
#        <div class="globalNav-subNav" data-bind="stopScrollPropagation">
#         <ul class="globalNav-subNavColumn">
#          <li class="globalNav-subNavItem">
#           <a class="globalNav-subNavLink" data-bind="click: trackSubMenuItem('rent', 'property to rent')" href="/property-to-rent">
#            Property to rent
#           </a>
#          </li>
#          <li class="globalNav-subNavItem">
#           <a class="globalNav-subNavLink" data-bind="click: trackSubMenuItem('rent', 'student property to rent')" href="/student-accommodation.html">
#            Student property to rent
#           </a>
#          </li>
#         </ul>
#        </div>
#       </div>
#       <div class="globalNav-item globalNav-item--fullList" data-bind="css : {'is-expanded': isGlobalNavItemOpen('find-agent')}">
#        <a class="globalNav-link" data-bind="click: toggleGlobalSubNav('find-agent', 'find agent')" href="/estate-agents.html">
#         <span>
#          Find Agent
#         </span>
#         <div class="no-svg-chevron select-chevron">
#          <svg>
#           <use xlink:href="#core-icon--chevron">
#           </use>
#          </svg>
#         </div>
#        </a>
#        <div class="globalNav-subNav" data-bind="stopScrollPropagation">
#         <ul class="globalNav-subNavColumn">
#          <li class="globalNav-subNavItem">
#           <a class="globalNav-subNavLink" data-bind="click: trackSubMenuItem('find agent', 'find estate agents')" href="/estate-agents.html">
#            Find estate agents
#           </a>
#          </li>
#          <li class="globalNav-subNavItem">
#           <a class="globalNav-subNavLink" data-bind="click: trackSubMenuItem('find agent', 'property valuation')" href="/property-valuation.html">
#            Property valuation
#           </a>
#          </li>
#         </ul>
#        </div>
#       </div>
#       <div class="globalNav-item globalNav-itemPrices" data-bind="css : {'is-expanded': isGlobalNavItemOpen('house-prices')}">
#        <a class="globalNav-link" data-bind="click: toggleGlobalSubNav('house-prices', 'house prices')" href="/house-prices.html">
#         <span>
#          House Prices
#         </span>
#         <div class="no-svg-chevron select-chevron">
#          <svg>
#           <use xlink:href="#core-icon--chevron">
#           </use>
#          </svg>
#         </div>
#        </a>
#        <div class="globalNav-subNav" data-bind="stopScrollPropagation">
#         <ul class="globalNav-subNavColumn">
#          <li class="globalNav-subNavItem">
#           <a class="globalNav-subNavLink" data-bind="click: trackSubMenuItem('house prices', 'sold house prices')" href="/house-prices.html">
#            Sold house prices
#           </a>
#          </li>
#          <li class="globalNav-subNavItem">
#           <a class="globalNav-subNavLink" data-bind="click: trackSubMenuItem('house prices', 'property valuation')" href="/property-valuation.html">
#            Property Valuation
#           </a>
#          </li>
#         </ul>
#         <ul class="globalNav-subNavColumn">
#          <li class="globalNav-subNavItem">
#           <a class="globalNav-subNavLink" data-bind="click: trackSubMenuItem('house prices', 'price comparison report')" href="/house-value.html">
#            Price comparison report
#           </a>
#          </li>
#          <li class="globalNav-subNavItem">
#           <a class="globalNav-subNavLink" data-bind="click: trackSubMenuItem('house prices', 'market trends')" href="/house-prices-in-my-area.html">
#            Market trends
#           </a>
#          </li>
#         </ul>
#        </div>
#       </div>
#       <div class="globalNav-item globalNav-item--fullList" data-bind="css : {'is-expanded': isGlobalNavItemOpen('commercial')}">
#        <a class="globalNav-link" data-bind="click: toggleGlobalSubNav('commercial', 'commercial')" href="/commercial-property-to-let.html">
#         <span>
#          Commercial
#         </span>
#         <div class="no-svg-chevron select-chevron">
#          <svg>
#           <use xlink:href="#core-icon--chevron">
#           </use>
#          </svg>
#         </div>
#        </a>
#        <div class="globalNav-subNav globalNav-subNav--commercial" data-bind="stopScrollPropagation">
#         <ul class="globalNav-subNavColumn">
#          <li class="globalNav-subNavItem">
#           <a class="globalNav-subNavLink" data-bind="click: trackSubMenuItem('commercial', 'commercial property to let')" href="/commercial-property-to-let.html">
#            Commercial property to rent
#           </a>
#          </li>
#          <li class="globalNav-subNavItem">
#           <a class="globalNav-subNavLink" data-bind="click: trackSubMenuItem('commercial', 'commercial property for sale')" href="/commercial-property-for-sale.html">
#            Commercial property for sale
#           </a>
#          </li>
#         </ul>
#        </div>
#       </div>
#       <div class="globalNav-item globalNav-item--rightAligned globalNav-item--fullList" data-bind="css : {'is-expanded': isGlobalNavItemOpen('inspire')}">
#        <a class="globalNav-link" data-bind="click: toggleGlobalSubNav('inspire', 'inspire')" href="/stories-and-advice">
#         <span>
#          Inspire
#         </span>
#         <div class="no-svg-chevron select-chevron">
#          <svg>
#           <use xlink:href="#core-icon--chevron">
#           </use>
#          </svg>
#         </div>
#        </a>
#        <div class="menuReverse globalNav-subNav" data-bind="stopScrollPropagation">
#         <ul class="menuBorderReverse globalNav-subNavColumn">
#          <li class="globalNav-subNavItem">
#           <a class="globalNav-subNavLink" data-bind="click: trackSubMenuItem('inspire', 'moving stories')" href="/moving-stories">
#            Moving stories
#           </a>
#          </li>
#          <li class="globalNav-subNavItem">
#           <a class="globalNav-subNavLink" data-bind="click: trackSubMenuItem('inspire', 'property blog')" href="/news">
#            Property blog
#           </a>
#          </li>
#         </ul>
#         <ul class="menuBorderReverse globalNav-subNavColumn">
#          <li class="globalNav-subNavItem">
#           <a class="globalNav-subNavLink" data-bind="click: trackSubMenuItem('inspire', 'property advice')" href="/advice">
#            Property advice
#           </a>
#          </li>
#          <li class="globalNav-subNavItem">
#           <a class="globalNav-subNavLink" data-bind="click: trackSubMenuItem('inspire', 'housing trends')" href="/news/house-price-index">
#            Housing trends
#           </a>
#          </li>
#         </ul>
#        </div>
#       </div>
#       <div class="globalNav-item globalNav-itemOverseas globalNav-item--rightAligned globalNav-item--fullList" data-bind="css : {'is-expanded': isGlobalNavItemOpen('overseas')}">
#        <a class="globalNav-link" data-bind="click: toggleGlobalSubNav('overseas', 'overseas')" href="/overseas-property.html">
#         <span>
#          Overseas
#         </span>
#         <div class="no-svg-chevron select-chevron">
#          <svg>
#           <use xlink:href="#core-icon--chevron">
#           </use>
#          </svg>
#         </div>
#        </a>
#        <div class="menuReverse globalNav-subNav" data-bind="stopScrollPropagation">
#         <ul class="menuBorderReverse globalNav-subNavColumn">
#          <li class="globalNav-subNavItem">
#           <a class="globalNav-subNavLink" data-bind="click: trackSubMenuItem('overseas', 'overseas properties for sale')" href="/overseas-property.html">
#            Overseas properties for sale
#           </a>
#          </li>
#          <li class="globalNav-subNavItem">
#           <a class="globalNav-subNavLink" data-bind="click: trackSubMenuItem('overseas', 'hot properties')" href="/overseas-property/hot-properties.html">
#            Hot properties
#           </a>
#          </li>
#          <li class="globalNav-subNavItem">
#           <a class="globalNav-subNavLink" data-bind="click: trackSubMenuItem('overseas', 'spain')" href="/overseas-property/in-Spain.html">
#            Spain
#           </a>
#          </li>
#         </ul>
#         <ul class="menuBorderReverse globalNav-subNavColumn">
#          <li class="globalNav-subNavItem">
#           <a class="globalNav-subNavLink" data-bind="click: trackSubMenuItem('overseas', 'france')" href="/overseas-property/in-France.html">
#            France
#           </a>
#          </li>
#          <li class="globalNav-subNavItem">
#           <a class="globalNav-subNavLink" data-bind="click: trackSubMenuItem('overseas', 'help and advice')" href="/overseas-property/help-and-advice/research.html">
#            Help and advice
#           </a>
#          </li>
#          <li class="globalNav-subNavItem">
#           <a class="globalNav-subNavLink" data-bind="click: trackSubMenuItem('overseas', 'sell overseas property')" href="/overseas-property/advertise.html">
#            Sell overseas property
#           </a>
#          </li>
#         </ul>
#        </div>
#       </div>
#       <div class="globalNav-item globalNav-itemSignin">
#        <a class="globalNav-link" data-bind="css: { 'globalNav-link--disabled': isAuthenticated }, attr: { href: loginLink }, click: trackSubMenuItem('sign in', 'sign in')" href="/login.html" rel="nofollow">
#         <span class="globalNav-linkLabel">
#          Sign In
#         </span>
#         <div class="icon-signedOut globalNav-signin-icon">
#          <svg>
#           <use xlink:href="#core-icon--account-silhouette">
#           </use>
#          </svg>
#         </div>
#        </a>
#        <a class="globalNav-link globalNav-link--disabled" data-bind="css: { 'globalNav-link--disabled': isAuthenticated() === false }, click: trackSubMenuItem('my rightmove', 'my rightmove')" href="/user/saved-searches/redirect.html" rel="nofollow">
#         <span class="globalNav-linkLabel">
#          My Rightmove
#         </span>
#         <div class="icon-signedIn globalNav-signin-icon">
#          <svg>
#           <use xlink:href="#core-icon--account-silhouette">
#           </use>
#          </svg>
#         </div>
#        </a>
#       </div>
#      </div>
#      <div class="globalNav-background" data-bind="css : { 'is-expanded' : currentSubNavMenuId }, stopScrollPropagation">
#      </div>
#     </nav>
#     <div class="globalHeader-burger" data-bind="click: toggleGlobalNav">
#      <div class="byron">
#      </div>
#     </div>
#     <a class="globalHeader-logo--house" data-bind="click: trackSubMenuItem('homepage', 'homepage')" href="/" title="Go to Rightmove homepage">
#      <div class="no-svg-rightmove-icon-logo globalHeader-logo--house-svg">
#       <svg>
#        <use xlink:href="#core-icon--rightmove-icon-logo">
#        </use>
#       </svg>
#      </div>
#     </a>
#     <div class="globalHeader-mobileTitle">
#      Search Results
#     </div>
#     <div class="globalHeader-signin">
#      <a class="globalHeader-signin-link" data-bind="css: { 'globalHeader-signin-link--disabled': isAuthenticated }, attr: { href: loginLink }, click: trackSubMenuItem('sign in', 'sign in')" href="/login.html" rel="nofollow" title="Sign in to My Rightmove">
#       <div class="no-svg-account-silhouette icon-signedOut globalHeader-signin-icon">
#        <svg>
#         <use xlink:href="#core-icon--account-silhouette">
#         </use>
#        </svg>
#       </div>
#      </a>
#      <a class="globalHeader-signin-link globalHeader-signin-link--disabled" data-bind="attr: { href: myRightmoveLink() }, css: { 'globalHeader-signin-link--disabled': isAuthenticated() === false }, click: trackSubMenuItem('my rightmove', 'my rightmove')" rel="nofollow">
#       <div class="no-svg-account-silhouette icon-signedIn globalHeader-signin-icon">
#        <svg>
#         <use xlink:href="#core-icon--account-silhouette">
#         </use>
#        </svg>
#       </div>
#      </a>
#     </div>
#    </div>
#   </header>
#   <div class="main">
#    <svg height="0" style="position:absolute" width="0">
#     <symbol id="search-icon--arrow" viewbox="0 0 14 13" xmlns="http://www.w3.org/2000/svg">
#      <title>
#       Combined Shape
#      </title>
#      <path d="M11.835 7.237H.583A.593.593 0 0 1 0 6.635c0-.332.261-.601.583-.601h11.281l-4.633-4.78a.615.615 0 0 1 0-.852.57.57 0 0 1 .825 0l5.615 5.793a.616.616 0 0 1 0 .851l-5.6 5.778a.573.573 0 0 1-.825 0 .616.616 0 0 1 0-.851l4.59-4.736z">
#      </path>
#     </symbol>
#     <symbol id="search-icon--bell-unsaved-v3" viewbox="0 0 15 16" xmlns="http://www.w3.org/2000/svg">
#      <g fill="none" fill-rule="evenodd" transform="translate(1 1)">
#       <circle cx="6" cy="12" fill="#F6A274" r="2" stroke="#7E2825" stroke-linecap="round" stroke-linejoin="round">
#       </circle>
#       <path d="M11.814 2.174a1.745 1.745 0 0 0-1.025-2.04 1.752 1.752 0 0 0-2.172.713c1.174.119 2.285.58 3.197 1.327z" fill="#F6A274" fill-rule="nonzero" stroke="#7E2825">
#       </path>
#       <path d="M12.745 6.901c.792-2.237-.317-4.698-2.526-5.605-2.21-.906-4.747.059-5.78 2.198l-.912 2.178A3.192 3.192 0 0 1 .96 7.613a1.077 1.077 0 1 0-.283 2.07l10.328 4.228c.457.197.99.06 1.294-.334.303-.392.299-.94-.012-1.327a3.15 3.15 0 0 1-.435-3.17l.892-2.179z" fill="#FFCB91" fill-rule="nonzero" stroke="#7E2825">
#       </path>
#       <path d="M9.907 3.062a.548.548 0 0 1-.423 0 2.343 2.343 0 0 0-1.784 0 2.317 2.317 0 0 0-1.26 1.251l-.913 2.179a5.285 5.285 0 0 1-1.392 1.94.546.546 0 0 1-.947-.265.537.537 0 0 1 .23-.532 4.206 4.206 0 0 0 1.109-1.553l.913-2.179C6.16 2.177 8.156 1.356 9.897 2.07c.273.11.408.416.304.69a.541.541 0 0 1-.294.302z" fill="#FFF">
#       </path>
#      </g>
#     </symbol>
#     <symbol id="search-icon--chevron-save-search" viewbox="0 0 6 12" xmlns="http://www.w3.org/2000/svg">
#      <path d="M1 11l4-4.667L1 1" fill="none" fill-rule="evenodd" stroke="#6B6B6B" stroke-width="1.5">
#      </path>
#     </symbol>
#     <symbol id="search-icon--enhanced-zero-results--beds" viewbox="0 0 32 32" xmlns="http://www.w3.org/2000/svg">
#      <title>
#       Artboard
#      </title>
#      <g fill="none" fill-rule="evenodd" stroke="#7E2825" transform="translate(0 5)">
#       <rect fill="#F6B18A" height="12" rx="2" width="29" x="1" y=".5">
#       </rect>
#       <path d="M4.5 3.5A1.5 1.5 0 0 0 3 5v4a1.5 1.5 0 0 0 1.5 1.5h10A1.5 1.5 0 0 0 16 9V5a1.5 1.5 0 0 0-1.5-1.5h-10zM17.5 3.5A1.5 1.5 0 0 0 16 5v4a1.5 1.5 0 0 0 1.5 1.5h9A1.5 1.5 0 0 0 28 9V5a1.5 1.5 0 0 0-1.5-1.5h-9z" fill="#8ED3CE">
#       </path>
#       <path d="M27.745 22v-2.75c0-.69-.486-1.25-1.085-1.25H4.34c-.6 0-1.085.56-1.085 1.25V22a1 1 0 0 1-1 1h-1.17C.485 23 0 22.44 0 21.75V10.5C0 9.12.972 8 2.17 8h26.66C30.028 8 31 9.12 31 10.5v11.25c0 .69-.486 1.25-1.085 1.25h-1.17a1 1 0 0 1-1-1z" fill="#F6B18A" stroke-linecap="round" stroke-linejoin="round">
#       </path>
#       <path d="M0 14.5v-4C0 9.12.972 8 2.17 8h26.66C30.028 8 31 9.12 31 10.5v4H0z" fill="#FFF" stroke-linecap="round" stroke-linejoin="round">
#       </path>
#      </g>
#     </symbol>
#     <symbol id="search-icon--enhanced-zero-results--bell" viewbox="0 0 32 32" xmlns="http://www.w3.org/2000/svg">
#      <title>
#       Artboard
#      </title>
#      <g fill="none" fill-rule="nonzero">
#       <circle cx="15.383" cy="25.53" fill="#F6A274" r="4.5" stroke="#7E2825" stroke-linecap="round" stroke-linejoin="round" transform="rotate(15 15.383 25.53)">
#       </circle>
#       <circle cx="20.818" cy="5.246" fill="#F6A274" r="3.5" stroke="#7E2825" stroke-linecap="round" stroke-linejoin="round" transform="rotate(15 20.818 5.246)">
#       </circle>
#       <path d="M4.323 18.102V18.1c1.966-.172 3.486-.842 4.01-2.798L9.6 10.58l.02.005c1.55-4.531 6.488-7.119 11.329-5.822 4.84 1.297 7.823 6.007 6.9 10.706l.02.006-1.266 4.722c-.492 1.838.259 3.468 1.77 4.287 1.173.462 1.844 1.711 1.52 2.921-.35 1.304-1.723 2.07-3.068 1.709l-23.14-6.2c-1.346-.361-2.153-1.71-1.804-3.015.295-1.1 1.32-1.817 2.443-1.797z" fill="#FFCB91" stroke="#7E2825" stroke-linecap="round" stroke-linejoin="round">
#       </path>
#       <path d="M10.3 19.112c-.345.449-1.016.552-1.498.23-.482-.32-.594-.945-.249-1.394.666-.866 1.632-3.274 2.05-5.097 1.149-5.017 4.157-7.711 10.523-6.514.582.11.958.637.84 1.178-.117.542-.683.892-1.265.783-5.126-.964-7.08.958-7.998 4.97-.474 2.068-1.536 4.715-2.403 5.844z" fill="#FFF">
#       </path>
#      </g>
#     </symbol>
#     <symbol id="search-icon--enhanced-zero-results--date-added" viewbox="0 0 32 32" xmlns="http://www.w3.org/2000/svg">
#      <title>
#       Artboard
#      </title>
#      <g fill="none" fill-rule="evenodd" stroke-linecap="round" stroke-linejoin="round">
#       <circle cx="16" cy="16" fill="#8FD4CF" r="15.5" stroke="#068277">
#       </circle>
#       <circle cx="16" cy="16" fill="#E7E7E7" r="12.5" stroke="#068277">
#       </circle>
#       <path d="M16 16l7 3M16 16v-5.419M6 16h1M25 16h1" fill-rule="nonzero" stroke="#006167">
#       </path>
#       <g fill-rule="nonzero" stroke="#006167" transform="rotate(90 5.5 11.5)">
#        <path d="M0 1h1M19 1h1">
#        </path>
#       </g>
#      </g>
#     </symbol>
#     <symbol id="search-icon--enhanced-zero-results--max-budget" viewbox="0 0 32 32" xmlns="http://www.w3.org/2000/svg">
#      <title>
#       Artboard
#      </title>
#      <g fill="none" fill-rule="evenodd" stroke="#7E2825" stroke-linecap="round" stroke-linejoin="round" transform="translate(0 6)">
#       <path d="M10 20c5.247 0 9.5-.885 9.5-1.977V14c-4.178.697-7.344 1.045-9.5 1.045-2.022 0-5.188-.348-9.5-1.045v4.023C.5 19.115 4.753 20 10 20z" fill="#F3BA66">
#       </path>
#       <ellipse cx="10" cy="14" fill="#F3BA66" rx="9.5" ry="2">
#       </ellipse>
#       <path d="M10 16c5.247 0 9.5-.885 9.5-1.977V10c-4.178.697-7.344 1.045-9.5 1.045-2.022 0-5.188-.348-9.5-1.045v4.023C.5 15.115 4.753 16 10 16z" fill="#F3BA66">
#       </path>
#       <ellipse cx="10" cy="10" fill="#F3BA66" rx="9.5" ry="2">
#       </ellipse>
#       <path d="M10 12c5.247 0 9.5-.885 9.5-1.977V6c-4.178.697-7.344 1.045-9.5 1.045C7.978 7.045 4.812 6.697.5 6v4.023C.5 11.115 4.753 12 10 12z" fill="#F3BA66">
#       </path>
#       <ellipse cx="10" cy="6" fill="#F3BA66" rx="9.5" ry="2">
#       </ellipse>
#       <path d="M10 8c5.247 0 9.5-.885 9.5-1.977V2c-4.178 1.364-7.344 2.045-9.5 2.045C7.978 4.045 4.812 3.364.5 2v4.023C.5 7.115 4.753 8 10 8z" fill="#F3BA66">
#       </path>
#       <ellipse cx="10" cy="2" fill="#F2DFBB" rx="9.5" ry="2">
#       </ellipse>
#       <g transform="translate(12 13)">
#        <path d="M10 8c5.247 0 9.5-.885 9.5-1.977V2c-4.178.705-7.344 1.057-9.5 1.057C7.978 3.057 4.812 2.705.5 2v4.023C.5 7.115 4.753 8 10 8z" fill="#F3BA66">
#        </path>
#        <ellipse cx="10" cy="2" fill="#F2DFBB" rx="9.5" ry="2">
#        </ellipse>
#       </g>
#      </g>
#     </symbol>
#     <symbol id="search-icon--enhanced-zero-results--min-budget" viewbox="0 0 32 32" xmlns="http://www.w3.org/2000/svg">
#      <title>
#       Artboard
#      </title>
#      <g fill="none" fill-rule="evenodd" stroke="#7E2825" stroke-linecap="round" stroke-linejoin="round" transform="translate(0 10)">
#       <path d="M10 12c5.247 0 9.5-.885 9.5-1.977V6c-4.178.697-7.344 1.045-9.5 1.045C7.978 7.045 4.812 6.697.5 6v4.023C.5 11.115 4.753 12 10 12z" fill="#F3BA66">
#       </path>
#       <ellipse cx="10" cy="6" fill="#F3BA66" rx="9.5" ry="2">
#       </ellipse>
#       <path d="M10 8c5.247 0 9.5-.885 9.5-1.977V2c-4.178.697-7.344 1.045-9.5 1.045C7.978 3.045 4.812 2.697.5 2v4.023C.5 7.115 4.753 8 10 8z" fill="#F3BA66">
#       </path>
#       <ellipse cx="10" cy="2" fill="#F3BA66" rx="9.5" ry="2">
#       </ellipse>
#       <ellipse cx="10" cy="2" fill="#F2DFBB" rx="9.5" ry="2">
#       </ellipse>
#       <g transform="translate(12 5)">
#        <path d="M10 8c5.247 0 9.5-.885 9.5-1.977V2c-4.178.705-7.344 1.057-9.5 1.057C7.978 3.057 4.812 2.705.5 2v4.023C.5 7.115 4.753 8 10 8z" fill="#F3BA66">
#        </path>
#        <ellipse cx="10" cy="2" fill="#F2DFBB" rx="9.5" ry="2">
#        </ellipse>
#       </g>
#      </g>
#     </symbol>
#     <symbol id="search-icon--enhanced-zero-results--no-garden" viewbox="0 0 32 32" xmlns="http://www.w3.org/2000/svg">
#      <title>
#       Artboard
#      </title>
#      <g fill="none" fill-rule="nonzero">
#       <g stroke-linejoin="round" transform="translate(8.5)">
#        <path d="M7.5 15v4" stroke="#2BAE8F" stroke-linecap="square">
#        </path>
#        <path d="M8.363 18.333s2.126.698 3.72-.223c1.595-.92 2.054-3.11 2.054-3.11s-2.126-.697-3.72.223c-1.595.92-2.054 3.11-2.054 3.11z" fill="#8FD4CF" stroke="#2BAE8F" stroke-linecap="round">
#        </path>
#        <g fill="#FFCB91" stroke="#E35E35" stroke-linecap="round" transform="translate(6)">
#         <ellipse cx="2" cy="4" rx="2" ry="3.5">
#         </ellipse>
#         <ellipse cx="2" cy="11" rx="2" ry="3.5">
#         </ellipse>
#        </g>
#        <g fill="#FFCB91" stroke="#E35E35" stroke-linecap="round" transform="rotate(90 5 10.5)">
#         <ellipse cx="2" cy="4" rx="2" ry="3.5">
#         </ellipse>
#         <ellipse cx="2" cy="11" rx="2" ry="3.5">
#         </ellipse>
#        </g>
#        <g fill="#FFCB91" stroke="#E35E35" stroke-linecap="round" transform="rotate(137 5 8.682)">
#         <ellipse cx="2" cy="4" rx="2" ry="3.5">
#         </ellipse>
#         <ellipse cx="2" cy="11" rx="2" ry="3.5">
#         </ellipse>
#        </g>
#        <g fill="#FFCB91" stroke="#E35E35" stroke-linecap="round" transform="rotate(-135 5 6.257)">
#         <ellipse cx="2" cy="4" rx="2" ry="3.5">
#         </ellipse>
#         <ellipse cx="2" cy="11" rx="2" ry="3.5">
#         </ellipse>
#        </g>
#        <circle cx="8" cy="7.5" fill="#FE9149" r="2" stroke="#BB1B24" stroke-linecap="round">
#        </circle>
#       </g>
#       <path d="M11 19.5a.5.5 0 0 0-.492.59l1.637 9a.5.5 0 0 0 .492.41h6.33a.5.5 0 0 0 .492-.41l1.637-9a.5.5 0 0 0-.492-.59H11z" fill="#F6B18A" stroke="#7E2825">
#       </path>
#       <path d="M11.5 21.5H20" stroke="#7E2825" stroke-linecap="square" stroke-linejoin="round">
#       </path>
#       <rect fill="#8FD4CF" height="2" rx="1" stroke="#7E2825" width="31" x=".5" y="27.5">
#       </rect>
# ...
#     <div class="globalFooter-legal">
#      <span class="globalFooter-legalTitle">
#       This site:
#      </span>
#      <a class="globalFooter-legalLink" href="/site-map.html">
#       Site map
#      </a>
#      <a class="globalFooter-legalLink globalFooter-legalLink--secondary" href="/this-site/help.html">
#       Help
#      </a>
#      <a class="globalFooter-legalLink optanon-show-settings-button optanon-toggle-display" href="/this-site/cookies.html" target="_blank">
#       Cookies
#      </a>
#      <a class="globalFooter-legalLink globalFooter-legalLink--secondary" href="/this-site/safety-and-security.html">
#       Safety and security
#      </a>
#      <a class="globalFooter-legalLink" href="/this-site/terms-of-use.html">
#       Terms of Use
#      </a>
#      <a class="globalFooter-legalLink" href="/this-site/privacy-policy.html">
#       Privacy Policy
#      </a>
#     </div>
#     <div class="globalFooter-cities">
#      <span class="globalFooter-citiesHeader">
#       Major cities and towns in the UK:
#      </span>
#      <div class="select-wrapper globalFooter-citiesSelectWrapper">
#       <select class="select globalFooter-citiesSelect" data-bind="value: citiesSelectValue" title="Major cities and towns in the UK">
#        <option selected="selected" value="">
#         Select (A-Z)
#        </option>
#        <optgroup label="United Kingdom:">
#         <option value="/uk-property-search-a-be.html">
#          A-Be
#         </option>
#         <option value="/uk-property-search-bl-bu.html">
#          Bl-Bu
#         </option>
#         <option value="/uk-property-search-ca-ce.html">
#          Ca-Ce
#         </option>
#         <option value="/uk-property-search-ch-con.html">
#          Ch-Con
#         </option>
#         <option value="/uk-property-search-cor-cu.html">
#          Cor-Cu
#         </option>
#         <option value="/uk-property-search-d.html">
#          D
#         </option>
#         <option value="/uk-property-search-ea.html">
#          Ea
#         </option>
#         <option value="/uk-property-search-ed-f.html">
#          Ed-F
#         </option>
#         <option value="/uk-property-search-g.html">
#          G
#         </option>
#         <option value="/uk-property-search-h.html">
#          H
#         </option>
#         <option value="/uk-property-search-i-k.html">
#          I-K
#         </option>
#         <option value="/uk-property-search-l.html">
#          L
#         </option>
#         <option value="/uk-property-search-m-ne.html">
#          M-Ne
#         </option>
#         <option value="/uk-property-search-no.html">
#          No
#         </option>
#         <option value="/uk-property-search-o-r.html">
#          O-R
#         </option>
#         <option value="/uk-property-search-sc-so.html">
#          Sc-So
#         </option>
#         <option value="/uk-property-search-st-sw.html">
#          St-Sw
#         </option>
#         <option value="/uk-property-search-t-v.html">
#          T-V
#         </option>
#         <option value="/uk-property-search-wa-we.html">
#          Wa-We
#         </option>
#         <option value="/uk-property-search-wi-wr.html">
#          Wi-Wr
#         </option>
#         <option value="/uk-property-search-y.html">
#          Y
#         </option>
#         <option value="/major-cities.html">
#          Major cities in the UK
#         </option>
#        </optgroup>
#        <optgroup label="London:">
#         <option value="/property/London.html">
#          London Property
#         </option>
#         <option value="/property-for-sale/London.html">
#          London Property for Sale
#         </option>
#         <option value="/property-to-rent/London.html">
#          London Property to Rent
#         </option>
#         <option value="/london-property-search-ba.html">
#          Ba
#         </option>
#         <option value="/london-property-search-be-br.html">
#          Be-Br
#         </option>
#         <option value="/london-property-search-c.html">
#          C
#         </option>
#         <option value="/london-property-search-e-g.html">
#          E-G
#         </option>
#         <option value="/london-property-search-ha.html">
#          Ha
#         </option>
#         <option value="/london-property-search-hi-ho.html">
#          Hi-Ho
#         </option>
#         <option value="/london-property-search-i-k.html">
#          I-K
#         </option>
#         <option value="/london-property-search-l-m.html">
#          L-M
#         </option>
#         <option value="/london-property-search-n-r.html">
#          N-R
#         </option>
#         <option value="/london-property-search-s-t.html">
#          S-T
#         </option>
#         <option value="/london-property-search-w.html">
#          W
#         </option>
#         <option value="/london-popular-regions.html">
#          Popular regions in London
#         </option>
#        </optgroup>
#        <optgroup label="Houses:">
#         <option value="/property-for-sale/B11.html">
#          Houses for sale in B11
#         </option>
#         <option value="/property-for-sale/B9.html">
#          Houses for sale in B9
#         </option>
#         <option value="/property-for-sale/Hu8.html">
#          Houses for sale in HU8
#         </option>
#         <option value="/property-for-sale/Bl1.html">
#          Houses for sale in BL1
#         </option>
#         <option value="/property-for-sale/Hu7.html">
#          Houses for sale in HU7
#         </option>
#         <option value="/property-for-sale/Sa4.html">
#          Houses for sale in SA4
#         </option>
#         <option value="/property-for-sale/Sa9.html">
#          Houses for sale in SA9
#         </option>
#         <option value="/property-for-sale/S4.html">
#          Houses for sale in S4
#         </option>
#         <option value="/property-for-sale/Sa5.html">
#          Houses for sale in SA5
#         </option>
#         <option value="/property-for-sale/Ls9.html">
#          Houses for sale in LS9
#         </option>
#         <option value="/property-to-rent/Bd3.html">
#          Houses to rent in BD3
#         </option>
#         <option value="/property-to-rent/Le5.html">
#          Houses to rent in LE5
#         </option>
#         <option value="/property-to-rent/Bd5.html">
#          Houses to rent in BD5
#         </option>
#         <option value="/property-to-rent/Bd8.html">
#          Houses to rent in BD8
#         </option>
#         <option value="/property-to-rent/Le4.html">
#          Houses to rent in LE4
#         </option>
#         <option value="/property-to-rent/S20.html">
#          Houses to rent in S20
#         </option>
#         <option value="/property-to-rent/Ls14.html">
#          Houses to rent in LS14
#         </option>
#         <option value="/property-to-rent/St6.html">
#          Houses to rent in ST6
#         </option>
#         <option value="/property-to-rent/Hu8.html">
#          Houses to rent in HU8
#         </option>
#         <option value="/property-to-rent/Hu6.html">
#          Houses to rent in HU6
#         </option>
#        </optgroup>
#        <optgroup label="Offices:">
#         <option value="/commercial-property-to-let/Birmingham/offices.html">
#          Offices to Rent in Birmingham
#         </option>
#         <option value="/commercial-property-to-let/Bristol/offices.html">
#          Offices to Rent in Bristol
#         </option>
#         <option value="/commercial-property-to-let/Glasgow/offices.html">
#          Offices to Rent in Glasgow
#         </option>
#         <option value="/commercial-property-to-let/Leeds/offices.html">
#          Offices to Rent in Leeds
#         </option>
#         <option value="/commercial-property-to-let/Leicester/offices.html">
#          Offices to Rent in Leicester
#         </option>
#         <option value="/commercial-property-to-let/London/offices.html">
#          Offices to Rent in London
#         </option>
#         <option value="/commercial-property-to-let/Manchester/offices.html">
#          Offices to Rent in Manchester
#         </option>
#         <option value="/commercial-property-to-let/Newcastle-Upon-Tyne/offices.html">
#          Offices to Rent in Newcastle Upon Tyne
#         </option>
#         <option value="/commercial-property-to-let/Nottingham/offices.html">
#          Offices to Rent in Nottingham
#         </option>
#         <option value="/commercial-property-to-let/Soho/offices.html">
#          Offices to Rent in Soho
#         </option>
#         <option value="/commercial-property-to-let/Birmingham/serviced-offices.html">
#          Serviced Offices to Rent in Birmingham
#         </option>
#         <option value="/commercial-property-to-let/Bristol/serviced-offices.html">
#          Serviced Offices to Rent in Bristol
#         </option>
#         <option value="/commercial-property-to-let/Glasgow/serviced-offices.html">
#          Serviced Offices to Rent in Glasgow
#         </option>
#         <option value="/commercial-property-to-let/Leeds/serviced-offices.html">
#          Serviced Offices to Rent in Leeds
#         </option>
#         <option value="/commercial-property-to-let/Leicester/serviced-offices.html">
#          Serviced Offices to Rent in Leicester
#         </option>
#         <option value="/commercial-property-to-let/London/serviced-offices.html">
#          Serviced Offices to Rent in London
#         </option>
#         <option value="/commercial-property-to-let/Manchester/serviced-offices.html">
#          Serviced Offices to Rent in Manchester
#         </option>
#         <option value="/commercial-property-to-let/Newcastle-Upon-Tyne/serviced-offices.html">
#          Serviced Offices to Rent in Newcastle Upon Tyne
#         </option>
#         <option value="/commercial-property-to-let/Nottingham/serviced-offices.html">
#          Serviced Offices to Rent in Nottingham
#         </option>
#         <option value="/commercial-property-to-let/Soho/serviced-offices.html">
#          Serviced Offices to Rent in Soho
#         </option>
#        </optgroup>
#       </select>
#       <svg class="no-svg-chevron select-chevron">
#        <use xlink:href="#core-icon--chevron">
#        </use>
#       </svg>
#      </div>
#     </div>
#    </div>
#   </div>
#   <div id="feedback-bar-container">
#   </div>
#   <div class="cookie-policy-wrapper" data-bind="css: { 'is-visible' : showMessage }" data-test="cookie-policy-wrapper" id="cookiePolicy">
#    <div>
#     <p>
#      <span>
#       We use cookies
#      </span>
#      to optimise your experience on our website.
#             If you continue we'll assume that you are happy to receive our cookies.
#             However, if you would like to, you can
#      <a href="/this-site/cookies.html">
#       change your cookie settings
#      </a>
#      at any time.
#     </p>
#     <button class="button" data-bind="click: closeMessage" data-test="close-cookie-popup-button">
#      <span class="button-icon">
#       <svg>
#        <use xlink:href="#core-icon--checkbox-tick">
#        </use>
#       </svg>
#      </span>
#      <span>
#       Continue
#      </span>
#     </button>
#    </div>
#   </div>
#   <script>
#    window.jsonModel = {"properties":[{"id":52636023,"bedrooms":3,"numberOfImages":13,"numberOfFloorplans":1,"numberOfVirtualTours":0,"summary":"A magnificent, three double bedroom, 1352 sq ft, 5th floor apartment situated in the prestigious Abell and Cleland Development in the heart of Westminster. The property comprises a substantial open-plan reception room with a superb private balcony and a highly specified, bespoke fitted kitch...","displayAddress":"Cleland House, Abell and Cleland, Westminster, London, SW1P","countryCode":"GB","location":{"latitude":51.493576,"longitude":-0.127125},"propertySubType":"Apartment","listingUpdate":{"listingUpdateReason":"price_reduced","listingUpdateDate":"2019-02-07T21:32:51Z"},"premiumListing":false,"featuredProperty":true,"price":{"amount":2500000,"frequency":"not specified","currencyCode":"GBP","displayPrices":[{"displayPrice":"£2,500,000","displayPriceQualifier":"Offers Over"}]},"customer":{"branchId":6464,"brandPlusLogoURI":"/7k/6464/branch_rmchoice_logo_6464_0005.jpeg","contactTelephone":"020 8012 1972","branchDisplayName":"MyLondonHome, Central London","branchName":"Central London","brandTradingName":"MyLondonHome","branchLandingPageUrl":"/estate-agents/agent/MyLondonHome/Central-London-6464.html","development":false,"showReducedProperties":true,"commercial":false,"showOnMap":true,"brandPlusLogoUrl":"https://media.rightmove.co.uk:443/dir/7k/6464/branch_rmchoice_logo_6464_0005_max_100x50.jpeg"},"distance":null,"transactionType":"buy","productLabel":{"productLabelText":""},"commercial":false,"development":false,"residential":true,"students":false,"auction":false,"feesApply":false,"feesApplyText":null,"displaySize":"","showOnMap":true,"propertyUrl":"/property-for-sale/property-52636023.html","contactUrl":"/property-for-sale/contactBranch.html?propertyId=52636023","channel":"BUY","firstVisibleDate":"2018-01-24T18:38:30Z","keywords":[],"keywordMatchType":"no_keyword","saved":null,"hidden":null,"displayStatus":"","propertyTypeFullDescription":"3 bedroom apartment for sale","propertyImages":{"images":[{"srcUrl":"https://media.rightmove.co.uk:443/dir/crop/10:9-16:9/7k/6464/52636023/6464_CWE180029_IMG_13_0000_max_476x317.jpg","srcsetUrl":"https://media.rightmove.co.uk:443/dir/crop/10:9-16:9/7k/6464/52636023/6464_CWE180029_IMG_13_0000_max_476x317.jpg 1x, https://media.rightmove.co.uk:443/dir/crop/10:9-16:9/7k/6464/52636023/6464_CWE180029_IMG_13_0000_max_656x437.jpg 2x","url":"7k/6464/52636023/6464_CWE180029_IMG_13_0000.jpg"},{"srcUrl":"https://media.rightmove.co.uk:443/dir/crop/10:9-16:9/7k/6464/52636023/6464_CWE180029_IMG_14_0000_max_476x317.jpg","srcsetUrl":"https://media.rightmove.co.uk:443/dir/crop/10:9-16:9/7k/6464/52636023/6464_CWE180029_IMG_14_0000_max_476x317.jpg 1x, https://media.rightmove.co.uk:443/dir/crop/10:9-16:9/7k/6464/52636023/6464_CWE180029_IMG_14_0000_max_656x437.jpg 2x","url":"7k/6464/52636023/6464_CWE180029_IMG_14_0000.jpg"},{"srcUrl":"https://media.rightmove.co.uk:443/dir/crop/10:9-16:9/7k/6464/52636023/6464_CWE180029_IMG_11_0000_max_476x317.jpg","srcsetUrl":"https://media.rightmove.co.uk:443/dir/crop/10:9-16:9/7k/6464/52636023/6464_CWE180029_IMG_11_0000_max_476x317.jpg 1x, https://media.rightmove.co.uk:443/dir/crop/10:9-16:9/7k/6464/52636023/6464_CWE180029_IMG_11_0000_max_656x437.jpg 2x","url":"7k/6464/52636023/6464_CWE180029_IMG_11_0000.jpg"},{"srcUrl":"https://media.rightmove.co.uk:443/dir/crop/10:9-16:9/7k/6464/52636023/6464_CWE180029_IMG_12_0000_max_476x317.jpg","srcsetUrl":"https://media.rightmove.co.uk:443/dir/crop/10:9-16:9/7k/6464/52636023/6464_CWE180029_IMG_12_0000_max_476x317.jpg 1x, https://media.rightmove.co.uk:443/dir/crop/10:9-16:9/7k/6464/52636023/6464_CWE180029_IMG_12_0000_max_656x437.jpg 2x","url":"7k/6464/52636023/6464_CWE180029_IMG_12_0000.jpg"}],"mainImageSrc":"https://media.rightmove.co.uk:443/dir/crop/10:9-16:9/7k/6464/52636023/6464_CWE180029_IMG_13_0000_max_476x317.jpg","mainImageSrcset":"https://media.rightmove.co.uk:443/dir/crop/10:9-16:9/7k/6464 ...
#   </script>
#   <script>
#    window.jsonModel.propertyTypeOptions = {};
#         window.jsonModel.propertyTypeOptions.propertyTypes = [{
#             value: 'detached',
#             name: 'Detached',
#             categoryId: ''
#         }, {
#             value: 'semi-detached',
#             name: 'Semi-detached',
#             categoryId: ''
#         }, {
#             value: 'terraced',
#             name: 'Terraced',
#             categoryId: ''
#         }, {
#             value: 'flat',
#             name: 'Flat',
#             categoryId: ''
#         }, {
#             value: 'bungalow',
#             name: 'Bungalow',
#             categoryId: ''
#         }, {
#             value: 'land',
#             name: 'Land',
#             categoryId: ''
#         }, {
#             value: 'park-home',
#             name: 'Park Home',
#             categoryId: ''
#         }];
#
#         window.jsonModel.propertyTypeOptions.parentCategories = [{
#             name: 'General',
#             value: 'General',
#             children: []
#         }];
#         window.jsonModel.propertyTypeOptions.groupSize = 4;
#   </script>
#   <script defer="" src="/pvw/javascript/search-vendor.3a83c5b3c2e46b0f7675.js">
#   </script>
#   <script defer="" src="/pvw/javascript/property-for-sale.search.89cfd63a93a3e77f822a.js">
#   </script>
#  </body>
# </html>

# %%
description = []
price = []
for car in soup.find_all('li', attrs={'class':'search-page__result'}):
    try:
        description.append(car.find('h2', attrs={'class':'listing-title title-wrap'}).text)
    except:
        description.append(np.nan)
    
    try:
        price.append(car.find('div', attrs={'class':'vehicle-price'}).text)
    except:
        price.append(np.nan)

cars = pd.DataFrame({'Description': description,
                     'Price': price})
cars
# Out:
#                                           Description    Price
# 0   \nRenault Kadjar 1.3 TCe ENERGY Dynamique S Na...  £16,000
# 1                            \nVolvo S40 1.6 XS 4dr\n     £400
# 2                         \nCitroen C3 1.4 i SX 5dr\n     £450
# 3                    \nCitroen Xsara 2.0 HDi LX 5dr\n     £500
# 4                    \nFord Fiesta 1.25 Finesse 3dr\n     £525
# 5       \nNissan Primera 2.0 SE Hypertronic CVT 5dr\n     £550
# 6                   \nFiat Punto 1.2 8v Dynamic 5dr\n     £600
# 7                \nToyota Avensis 2.2 D-4D T180 5dr\n     £600
# 8                    \nAudi A4 Avant 1.9 TDI SE 5dr\n     £650
# 9             \nRenault Clio 1.2 16v Expression 3dr\n     £650
# 10                  \nNissan Almera Tino 1.8 SE 5dr\n     £695
# 11            \nToyota Prius 1.8 VVTi Excel 5dr CVT\n  £25,980
# 12      \nRenault Captur 1.5 dCi ENERGY GT Line 5dr\n  £14,570

# %% [markdown]
# ### We can now set up a loop to go through all the different pages of this website search:

# %%
description = []
price = []
for x in tqdm_notebook(range(1, 21)):
    url = 'https://www.autotrader.co.uk/\
car-search?sort=sponsored&radius=10\
&postcode=e16lt&onesearchad=Used&onesearchad=Nearly%20New&onesearchad=New&page={}'.format(x)
    r = requests.get(url)
    soup = BeautifulSoup(r.text, 'html.parser')
    for car in soup.find_all('li', attrs={'class':'search-page__result'}):
        try:
            description.append(car.find('h2', attrs={'class':'listing-title title-wrap'}).text)
        except:
            description.append(np.nan)

        try:
            price.append(car.find('div', attrs={'class':'vehicle-price'}).text)
        except:
            price.append(np.nan)

cars = pd.DataFrame({'Description': description,
                     'Price': price})
# Out:
# HBox(children=(IntProgress(value=0, max=20), HTML(value='')))

# %%
cars.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 260 entries, 0 to 259
# Data columns (total 2 columns):
# Description    260 non-null object
# Price          260 non-null object
# dtypes: object(2)
# memory usage: 4.1+ KB

# %%
cars.head()
# Out:
#                                          Description    Price
# 0  \nRenault Kadjar 1.6 dCi ENERGY Signature S Na...  £12,950
# 1                           \nVolvo S40 1.6 XS 4dr\n     £400
# 2                        \nCitroen C3 1.4 i SX 5dr\n     £450
# 3                   \nCitroen Xsara 2.0 HDi LX 5dr\n     £500
# 4                   \nFord Fiesta 1.25 Finesse 3dr\n     £525

# %% [markdown]
# ## Pair Practice: Rightmove
#
# Using the URL below:
#
# 1. Have a look at the HTML using 'Inspect' on the website.
# 2. Look at the tags and what is linked to different sections of the website.
# 3. Write a script that creates a dataframe of the houses for sale, with their location, description and price.

# %%
url = 'https://www.rightmove.co.uk/property-for-sale/find.html?locationIdentifier=REGION%5E87490&index=0'
