# %%
import numpy as np
import pandas as pd
import scipy.stats as stats
import seaborn as sns
import matplotlib.pyplot as plt
import Regression_Evaluation

plt.style.use('fivethirtyeight')

# %config InlineBackend.figure_format = 'retina'
# %matplotlib inline

import warnings
warnings.simplefilter('ignore')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-47-b752c2bf371d> in <module>
#       4 import seaborn as sns
#       5 import matplotlib.pyplot as plt
# ----> 6 import Regression_Evaluation
#       7
#       8 plt.style.use('fivethirtyeight')
#
# ~/Github_Personal/Notes/Notes/Models/Linear/Regression_Evaluation.py in <module>
#      20
#      21
# ---> 22 pwd
#      23
#      24
#
# NameError: name 'pwd' is not defined

# %% [markdown]
# ### Benefits of centering data
#
# The primary benefit of centering your predictor data in linear modeling is that **the intercept represents the estimate of the target when all predictors are at their mean value.**

# %%
data = pd.read_csv('/Users/paxton615/GA/resource-datasets/football_combine/combine_train.csv')

# %%
df = data[['Name','Position','HeightInchesTotal','Weight']]

# %%
print(df.dtypes)
print(df.shape)
print(df.isnull().sum())
df.describe()
# Out:
# Name                  object
# Position              object
# HeightInchesTotal    float64
# Weight                 int64
# height_cm            float64
# weight_kg            float64
# dtype: object
# (3237, 6)
# Name                 0
# Position             0
# HeightInchesTotal    0
# Weight               0
# height_cm            0
# weight_kg            0
# dtype: int64
#        HeightInchesTotal       Weight    height_cm    weight_kg
# count        3237.000000  3237.000000  3237.000000  3237.000000
# mean           74.033982   245.536917   188.046314   111.228223
# std             2.577470    45.458286     6.546774    20.592604
# min            66.000000   160.000000   167.640000    72.480000
# 25%            73.000000   208.000000   185.420000    94.224000
# 50%            74.000000   237.000000   187.960000   107.361000
# 75%            76.000000   288.000000   193.040000   130.464000
# max            82.000000   386.000000   208.280000   174.858000

# %%
df['height_cm'] = df['HeightInchesTotal'].map(lambda x:x*2.54)

# %%
df['weight_kg'] = df['Weight'].map(lambda x:x*0.453)

# %%
df.hist();

# %%
df[['height_cm','weight_kg']].plot(kind='box', figsize=(12,12));

# %% [markdown]
# - 在box plot中就会出现一个问题。如果量级差别太大，则某些图形显示时就是畸形的。比如这里的height_cm, 明显矮了很多。
