# %%
import matplotlib.pyplot as plt# Pie chart
import pandas as pd

# %%
df = pd.DataFrame({'mass': [0.330, 4.87 , 5.97],

                   'radius': [2439.7, 6051.8, 6378.1]},

                  index=['Mercury', 'Venus', 'Earth'])

plot = df.plot.pie(y='mass', figsize=(10, 10))

# %%
df = pd.DataFrame({'Millionaires':[20215,5788],"Top 10% of global wealth holders":[97217,107517],"Top 1% of global wealth holders":[20148,5758]}, index=['USA','CHINA'])

# %%
df
# Out:
#        Millionaires  Top 10% of global wealth holders  \
# USA           20215                             97217
# CHINA          5788                            107517
#
#        Top 1% of global wealth holders
# USA                              20148
# CHINA                             5758

# %%
import seaborn as sns
# sns.set_theme(style="whitegrid")

penguins = sns.load_dataset("penguins")

# Draw a nested barplot by species and sex
g = sns.catplot(
    data=df, kind="bar",
    palette="dark", alpha=.6, height=6
)
g.despine(left=True)
g.set_axis_labels("", "Body mass (g)")
g.legend.set_title("")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-24-436380201be4> in <module>
#      11 g.despine(left=True)
#      12 g.set_axis_labels("", "Body mass (g)")
# ---> 13 g.legend.set_title("")
#
# AttributeError: 'FacetGrid' object has no attribute 'legend'

# %%
import seaborn as sns
# sns.set_theme(style="whitegrid")

penguins = sns.load_dataset("penguins")

# Draw a nested barplot by species and sex
g = sns.catplot(
    data=penguins, kind="bar",
    x="species", y="body_mass_g", hue="sex",
    ci="sd", palette="dark", alpha=.6, height=6
)
g.despine(left=True)
g.set_axis_labels("", "Body mass (g)")
g.legend.set_title("")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-18-73ccbac4ce16> in <module>
#      12 g.despine(left=True)
#      13 g.set_axis_labels("", "Body mass (g)")
# ---> 14 g.legend.set_title("")
#
# AttributeError: 'FacetGrid' object has no attribute 'legend'

# %%
from pyecharts.charts import Bar
from pyecharts import options as opts
from pyecharts.globals import ThemeType
bar = (
    Bar()
    .add_xaxis(['JAN','FEB','MAR','APR','MAY','JUN','JUL','AUG','SEP','OCT','NOV','DEC'])
    .add_yaxis("Temperature Max", [-7,-6,-2,4,10,15,18,17,13,7,2,-3],color="#1565C0")
    .add_yaxis("Temperature Min", [-1,0,5,12,18,24,27,26,21,14,8,2],color='#80CBC4')
    .set_global_opts(title_opts=opts.TitleOpts(title="30-year temperature for Toronto", subtitle="Year 1981 to 2010"))
    .set_series_opts(
        label_opts=opts.LabelOpts(is_show=False),
        markpoint_opts=opts.MarkPointOpts(
        data=[opts.MarkPointItem(type_="max", name="Highest Temp"),
              opts.MarkPointItem(type_="min", name="Lowest Temp"),]),
                )
                )
bar.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="ef679080e7a14b1d844137de93f0e519" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_ef679080e7a14b1d844137de93f0e519 = echarts.init(
#                     document.getElementById('ef679080e7a14b1d844137de93f0e519'), 'white', {renderer: 'canvas'});
#                 var option_ef679080e7a14b1d844137de93f0e519 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#80CBC4",
#         "#1565C0",
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "bar",
#             "name": "Temperature Max",
#             "data": [
#                 -7,
#                 -6,
#                 -2,
#                 4,
#                 10,
#                 15,
#                 18,
#                 17,
#                 13,
#                 7,
#                 2,
#                 -3
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "show": false,
#                 "position": "top",
#                 "margin": 8
#             },
#             "markPoint": {
#                 "label": {
#                     "show": true,
#                     "position": "inside",
#                     "color": "#fff",
#                     "margin": 8
#                 },
#                 "data": [
#                     {
#                         "name": "Highest Temp",
#                         "type": "max"
#                     },
#                     {
#                         "name": "Lowest Temp",
#                         "type": "min"
#                     }
#                 ]
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         },
#         {
#             "type": "bar",
#             "name": "Temperature Min",
#             "data": [
#                 -1,
#                 0,
#                 5,
#                 12,
#                 18,
#                 24,
#                 27,
#                 26,
#                 21,
#                 14,
#                 8,
#                 2
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "show": false,
#                 "position": "top",
#                 "margin": 8
#             },
#             "markPoint": {
#                 "label": {
#                     "show": true,
#                     "position": "inside",
#                     "color": "#fff",
#                     "margin": 8
#                 },
#                 "data": [
#                     {
#                         "name": "Highest Temp",
#                         "type": "max"
#                     },
#                     {
#                         "name": "Lowest Temp",
#                         "type": "min"
#                     }
#                 ]
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "Temperature Max",
#                 "Temperature Min"
#             ],
#             "selected": {
#                 "Temperature Max": true,
#                 "Temperature Min": true
#             },
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "xAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "JAN",
#                 "FEB",
#                 "MAR",
#                 "APR",
#                 "MAY",
#                 "JUN",
#                 "JUL",
#                 "AUG",
#                 "SEP",
#                 "OCT",
#                 "NOV",
#                 "DEC"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ],
#     "title": [
#         {
#             "text": "30-year temperature for Toronto",
#             "subtext": "Year 1981 to 2010",
#             "padding": 5,
#             "itemGap": 10
#         }
#     ]
# };
#                 chart_ef679080e7a14b1d844137de93f0e519.setOption(option_ef679080e7a14b1d844137de93f0e519);
#         });
#     </script>

# %%
# import libraries
from pyecharts.charts import Bar
from pyecharts import options as opts


bar = (
 Bar(init_opts=opts.InitOpts())
 .add_xaxis(['JAN','FEB','MAR','APR','MAY','JUN','JUL','AUG','SEP','OCT','NOV','DEC'])
    .add_yaxis("Temperature Max", [-7,-6,-2,4,10,15,18,17,13,7,2,-3],color="#1565C0")
    .add_yaxis("Temperature Min", [-1,0,5,12,18,24,27,26,21,14,8,2],color='#80CBC4')
 .set_global_opts(title_opts=opts.TitleOpts(title="30-year temperature for Toronto", subtitle="Year 1981 to 2010"))
)
bar.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="fba73ca130264ec6ac60cbdee0ca1fa5" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_fba73ca130264ec6ac60cbdee0ca1fa5 = echarts.init(
#                     document.getElementById('fba73ca130264ec6ac60cbdee0ca1fa5'), 'white', {renderer: 'canvas'});
#                 var option_fba73ca130264ec6ac60cbdee0ca1fa5 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#80CBC4",
#         "#1565C0",
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "bar",
#             "name": "Temperature Max",
#             "data": [
#                 -7,
#                 -6,
#                 -2,
#                 4,
#                 10,
#                 15,
#                 18,
#                 17,
#                 13,
#                 7,
#                 2,
#                 -3
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             }
#         },
#         {
#             "type": "bar",
#             "name": "Temperature Min",
#             "data": [
#                 -1,
#                 0,
#                 5,
#                 12,
#                 18,
#                 24,
#                 27,
#                 26,
#                 21,
#                 14,
#                 8,
#                 2
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "Temperature Max",
#                 "Temperature Min"
#             ],
#             "selected": {
#                 "Temperature Max": true,
#                 "Temperature Min": true
#             },
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "xAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "JAN",
#                 "FEB",
#                 "MAR",
#                 "APR",
#                 "MAY",
#                 "JUN",
#                 "JUL",
#                 "AUG",
#                 "SEP",
#                 "OCT",
#                 "NOV",
#                 "DEC"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ],
#     "title": [
#         {
#             "text": "30-year temperature for Toronto",
#             "subtext": "Year 1981 to 2010",
#             "padding": 5,
#             "itemGap": 10
#         }
#     ]
# };
#                 chart_fba73ca130264ec6ac60cbdee0ca1fa5.setOption(option_fba73ca130264ec6ac60cbdee0ca1fa5);
#         });
#     </script>

# %%
df.columns
# Out:
# Index(['Millionaires', 'Top 10% of global wealth holders',
#        'Top 1% of global wealth holders'],
#       dtype='object')

# %%
df
# Out:
#        Millionaires  Top 10% of global wealth holders  \
# USA           20215                             97217
# CHINA          5788                            107517
#
#        Top 1% of global wealth holders
# USA                              20148
# CHINA                             5758

# %%
from pyecharts import options as opts
from pyecharts.charts import Bar
from IPython.display import IFrame
c = (
    Bar(init_opts=opts.InitOpts(width="600px", height="300px"))
    .add_xaxis(list(df.index))
    .add_yaxis("Millionaires", [20215,5788]) #tried using list(weekly_status.pv.values), doesn't work
    .add_yaxis("Top 10% of global wealth holders", [97217,107517])
    .add_yaxis("Top 1% of global wealth holders",[20148,5758])
    .set_global_opts(
#         title_opts=opts.TitleOpts(title="Individuals With Wealth"),
#         toolbox_opts=opts.ToolboxOpts(),
        legend_opts=opts.LegendOpts(is_show=True),
    )
    .render("bar_toolbox.html")
)
IFrame(src='./bar_toolbox.html', width=1600, height=600)
# Out:
#         <iframe
#             width="1600"
#             height="600"
#             src="./bar_toolbox.html"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %%
option = {
    tooltip: {
        trigger: 'item',
        formatter: '{a} <br/>{b}: {c} ({d}%)'
    },
    legend: {
        orient: 'vertical',
        left: 10,
        data: ['直接访问', '邮件营销', '联盟广告', '视频广告', '搜索引擎']
    },
    series: [
        {
            name: '访问来源',
            type: 'pie',
            radius: ['50%', '70%'],
            avoidLabelOverlap: false,
            label: {
                show: false,
                position: 'center'
            },
            emphasis: {
                label: {
                    show: true,
                    fontSize: '30',
                    fontWeight: 'bold'
                }
            },
            labelLine: {
                show: false
            },
            data: [
                {value: 335, name: '直接访问'},
                {value: 310, name: '邮件营销'},
                {value: 234, name: '联盟广告'},
                {value: 135, name: '视频广告'},
                {value: 1548, name: '搜索引擎'}
            ]
        }
    ]
};
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-63-94e3a03ae3c6> in <module>
#       1 option = {
# ----> 2     tooltip: {
#       3         trigger: 'item',
#       4         formatter: '{a} <br/>{b}: {c} ({d}%)'
#       5     },
#
# NameError: name 'tooltip' is not defined
