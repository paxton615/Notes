# %%
# need to import virtual environments

from flask import Flask

app = Flask(__name__)


@app.route('/')  # 重要，指定了url的访问路径
def hello_world(): # 定义这个url中的内容
    return 'Hello World!'

@app.route('/hello') # 更换路径
def hello_world2(): #相应更换内容title
    return 'Hello World 2!'

if __name__ == '__main__':
    app.run()

# %%
from flask import Flask, render_template

app = Flask(__name__)


@app.route('/')        # 重要，指定了url的访问路径
def hello_world():     # 定义这个url中的内容
    return 'Hello World!'

@app.route('/hello')   # 更换路径
def hello_world2():
    data = 'hello data'
    return render_template('hello.html', data = data)

# 路由route的本质就是个装饰器
@app.route('/user/<username>', methods=['get', 'post'])
def get_user(username):
    return 'hello {}'.format(username)


if __name__ == '__main__':
    app.run()

# %%
from flask import Flask, render_template, request

app = Flask(__name__)


@app.route('/')        # 重要，指定了url的访问路径
def hello_world():     # 定义这个url中的内容
    return 'Hello World!'

@app.route('/hello')   # 更换路径
def hello_world2():
    data = 'hello data'
    return render_template('hello.html', data = data)

# 路由route的本质就是个装饰器
@app.route('/user/<username>', methods=['get', 'post'])
def get_user(username):
    return 'hello {}'.format(username)



@app.route('/data', methods=['get', 'post'])
def test_data():
    # print(request.args)
    # print(request.args.get('a'), request.args.get('b'))
    # print(request.headers)
    # print(request.headers.get('User-Agent'))
    # print(request.data)
    # import json
    # print(json.loads(request.data))
    # print(request.cookies)
    # print(request.cookies.get('token'))
    print(request.form)
    print(request.form.get('username'), request.form.get('password'))
    return 'success'


if __name__ == '__main__':
    app.run()

# %% [markdown]
# <!DOCTYPE html>
# <html lang="en">
# <head>
#     <meta charset="UTF-8">
#     <title>Title</title>
# </head>
# <body>
#     <form action = 'http://127.0.0.1:5000/data' method = 'post'> #一定要确定route的method中有'post'方法
#         <input type = 'text' name="username">
#         <input type = 'text' name="password">
#         <input type="submit" value="submit"> # 创建submit按钮
#     </form>>
# </body>
# </html>

# %%
from flask import Flask, render_template, request

app = Flask(__name__)


@app.route('/')        # 重要，指定了url的访问路径
def hello_world():     # 定义这个url中的内容
    return 'Hello World!'

@app.route('/hello')   # 更换路径
def hello_world2():
    data = 'hello data'
    return render_template('hello.html', data = data)

# 路由route的本质就是个装饰器
@app.route('/user/<username>', methods=['get', 'post'])
def get_user(username):
    return 'hello {}'.format(username)



@app.route('/data', methods=['get', 'post'])
def test_data():
    # print(request.args)
    # print(request.args.get('a'), request.args.get('b'))
    # print(request.headers)
    # print(request.headers.get('User-Agent'))
    # print(request.data)
    # import json
    # print(json.loads(request.data))
    # print(request.cookies)
    # print(request.cookies.get('token'))
    # print(request.form)
    # print(request.form.get('username'), request.form.get('password'))
    return 'success'

@app.route('/user_template')
def use_template():
    datas = [(1, 'name1'),(2, 'name2'), (3, 'name3')]
    title = '学生信息'
    return render_template('user_template.html', datas = datas, title = title)

if __name__ == '__main__':
    app.run()

# %% [markdown]
# <!DOCTYPE html>
# <html lang="en">
# <head>
#     <meta charset="UTF-8">
#     <title>Title</title>
# </head>
# <body>
# <h1>{{ title }}</h1>
#     {% for data in datas %}
#         {% if data[0] !=2 %}
#         <h2>
#             {{ data[0] }} - {{ data[1] }}
#         </h2>>
#         {% endif %}
#     {% endfor %}
# </body>
# </html>

# %%
# not having a very smooth day in coding

# %%
from flask import Flask, render_template, request

app = Flask(__name__)


@app.route('/')        # 重要，指定了url的访问路径
def hello_world():     # 定义这个url中的内容
    return 'Hello World!'

@app.route('/hello')   # 更换路径
def hello_world2():
    data = 'hello data'
    return render_template('hello.html', data = data)

# 路由route的本质就是个装饰器
@app.route('/user/<username>', methods=['get', 'post'])
def get_user(username):
    return 'hello {}'.format(username)



@app.route('/data', methods=['get', 'post'])
def test_data():
    # print(request.args)
    # print(request.args.get('a'), request.args.get('b'))
    # print(request.headers)
    # print(request.headers.get('User-Agent'))
    # print(request.data)
    # import json
    # print(json.loads(request.data))
    # print(request.cookies)
    # print(request.cookies.get('token'))
    # print(request.form)
    # print(request.form.get('username'), request.form.get('password'))
    return 'success'

@app.route('/user_template')
def use_template():
    datas = [(1, 'name1'),(2, 'name2'), (3, 'name3')]
    title = '学生信息'
    return render_template('user_template.html', datas = datas, title = title)


@app.route('/pvuv')
def pvuv():
    # read file
    data = []
    with open('./data/pv_uv.txt') as fin:
        for line in fin:
            pdate, pv, uv = line.split('-')
            data.append((pdate, pv, uv))
    # return html
    return render_template('pvuv.html', data = data)
if __name__ == '__main__':
    app.run()

# %% [markdown]
# <!DOCTYPE html>
# <html lang="en">
# <head>
#     <meta charset="UTF-8">
#     <title>网站的pvuv数据</title>
# </head>
# <body>
#     <h1>网站的pvuv数据表格</h1>
#     <div>
#         <table border="1px">
#             <tr style="background-color: #ee0000"> # tr代表一行
#                 <th>日期</th>
#                 <th>pv</th>
#                 <th>uv</th>
#             </tr>
#
#             {%  for row in data %}
#                 <tr>
#                     <td>{{ row[0] }}</td>
#                     <td>{{ row[1] }}</td>
#                     <td>{{ row[2] }}</td>
#                 </tr>
#             {% endfor %}
#         </table>
#     </div>
# </body>
# </html>

# %% [markdown]
# 日期-PV-UV
# 2019-15000-150
# 2019-15000-151
# 2019-15000-152

# %%
from flask import Flask, render_template, request
import json

app = Flask(__name__)


@app.route('/')        # 重要，指定了url的访问路径
def hello_world():     # 定义这个url中的内容
    return 'Hello World!'

@app.route('/hello')   # 更换路径
def hello_world2():
    data = 'hello data'
    return render_template('hello.html', data = data)

# 路由route的本质就是个装饰器
@app.route('/user/<username>', methods=['get', 'post'])
def get_user(username):
    return 'hello {}'.format(username)



@app.route('/data', methods=['get', 'post'])
def test_data():
    # print(request.args)
    # print(request.args.get('a'), request.args.get('b'))
    # print(request.headers)
    # print(request.headers.get('User-Agent'))
    # print(request.data)
    # import json
    # print(json.loads(request.data))
    # print(request.cookies)
    # print(request.cookies.get('token'))
    # print(request.form)
    # print(request.form.get('username'), request.form.get('password'))
    return 'success'

@app.route('/user_template')
def use_template():
    datas = [(1, 'name1'),(2, 'name2'), (3, 'name3')]
    title = '学生信息'
    return render_template('user_template.html', datas = datas, title = title)

def read_pvuv_data():
    '''
    read pvuv data
    :return: list, ele:(pdate, pv, uv)
    '''
    data = []
    with open('./data/pv_uv.txt') as fin:
        for line in fin:
            pdate, pv, uv = line.split('-')
            data.append((pdate, pv, uv))
    return (data)

@app.route('/pvuv')
def pvuv():
    # read file
    data = read_pvuv_data()
    # return html
    return render_template('pvuv.html', data = data)

@app.route('/getjson')
def getjson():
    # read file
    data = read_pvuv_data()
    # return html
    return json.dumps(data)
# 虽然我们开发的是一个后端的api，但是在前端也是可以访问的

if __name__ == '__main__':
    app.run()

# %%
import requests

url = 'http://127.0.0.1:5000/getjson' #注意，这里test_get_json并不是调用app.py所得到的数据
# 而是通过这个url，来远程请求服务而得到的数据

r = requests.get(url)

print(r.status_code)
print(r.text)
print('*'*60)
import json # 变成json对象后是可以遍历的，r.text不可以，它只有字符串儿
print(json.loads(r.text)) # json本身没有turple的概念，都是[]

print('*'*60)

for row in json.loads(r.text):
    print(row)

# %%
# linked sql with pycharm
# next step, show results online

# %%
import sys
print(sys.version)
# Out:
# 3.8.3 (default, Jul  2 2020, 11:26:31)
# [Clang 10.0.0 ]

# %%
from platform import python_version
print(python_version())
# Out:
# 3.8.3

# %%
import pymysql

# 用pymysql实现pycharm与mysql的connection
def get_conn():
    return pymysql.connect(   # 这里开头直接是return
        host = '127.0.0.1',
        user = 'root',
        password = 'pcx19570403',
        database = 'python_mysql',
        charset = 'utf8'
    ) # 先测试函数内容，RUN后不报错,说明成功,再用函数封装，以便之后使用

# 用一个函数来提取sql请求，抓取数据
def query_data(sql):
    conn = get_conn()  # 建立连接
    try:
        cursor = conn.cursor(pymysql.cursors.DictCursor) #在建好的链接中,创建pymysql光标，并返回字典形式
        cursor.execute(sql)  # 光标执行sql语句
        return cursor.fetchall() # 提取所有内容
    finally:
        conn.close() # 为防止资源占用,使用try, finally使用后关闭

# 用一个函数来插入，更新mysql数据库
def insert_or_update_data(sql): # 插入和更新表格
    conn = get_conn() # 建立连接
    try:
        cursor = conn.cursor() #建立光标
        cursor.execute(sql) #光标执行sql语句
        conn.commit()  # 确认commit
    finally:
        conn.close()

# 统一执行以上出现过的函数
if __name__ == '__main__':
    # 插入，更新一条sql数据
    sql = 'insert user (name, sex, age, email) values("daming", "male", 23 , "daming@gmail.com")' # 内容
    insert_or_update_data(sql) # 执行函数
    
    # 提取mysql数据并展示
    sql = 'select * from user'
    datas = query_data(sql)
    import pprint
    pprint.pprint(datas)
# Out:
# [{'age': 21,
#   'email': 'xiaoming@gmail.com',
#   'id': 1,
#   'name': 'xiaoming',
#   'sex': 'man'},
#  {'age': 22,
#   'email': 'xiaohong@gmail.com',
#   'id': 2,
#   'name': 'xiaohong',
#   'sex': 'woman'},
#  {'age': 18,
#   'email': 'xiaomei@gmail.com',
#   'id': 3,
#   'name': 'xiaomei',
#   'sex': 'woman'},
#  {'age': 23,
#   'email': 'daming@gmail.com',
#   'id': 4,
#   'name': 'daming',
#   'sex': 'male'},
#  {'age': 23,
#   'email': 'daming@gmail.com',
#   'id': 5,
#   'name': 'daming',
#   'sex': 'male'}]

# %%
from flask import Flask, render_template, request
import json
from db import insert_or_update_data

app = Flask(__name__)


@app.route('/')        # 重要，指定了url的访问路径
def hello_world():     # 定义这个url中的内容
    return 'Hello World!'


@app.route('/hello')   # 更换路径
def hello_world2():
    data = 'hello data'
    return render_template('hello.html', data = data)

# 路由route的本质就是个装饰器
@app.route('/user/<username>', methods=['get', 'post'])
def get_user(username):
    return 'hello {}'.format(username)



@app.route('/data', methods=['get', 'post'])
def test_data():
    # print(request.args)
    # print(request.args.get('a'), request.args.get('b'))
    # print(request.headers)
    # print(request.headers.get('User-Agent'))
    # print(request.data)
    # import json
    # print(json.loads(request.data))
    # print(request.cookies)
    # print(request.cookies.get('token'))
    # print(request.form)
    # print(request.form.get('username'), request.form.get('password'))
    return 'success'

@app.route('/user_template')
def use_template():
    datas = [(1, 'name1'),(2, 'name2'), (3, 'name3')]
    title = '学生信息'
    return render_template('user_template.html', datas = datas, title = title)

def read_pvuv_data():
    '''
    read pvuv data
    :return: list, ele:(pdate, pv, uv)
    '''
    data = []
    with open('./data/pv_uv.txt') as fin:
        for line in fin:
            pdate, pv, uv = line.split('-')
            data.append((pdate, pv, uv))
    return (data)

@app.route('/pvuv')
def pvuv():
    # read file
    data = read_pvuv_data()
    # return html
    return render_template('pvuv.html', data = data)

#
@app.route('/getjson')
def getjson():
    # read file
    data = read_pvuv_data()
    # return html
    return json.dumps(data)
# 虽然我们开发的是一个后端的api，但是在前端也是可以访问的

# flask 提交网页表单数据到mysql
@app.route("/show_add_user")
def show_add_user(): # 注意,如果是静态数据,放入static即可；写一个函数的目的是为了数据的交互
    return render_template('show_add_user.html')

@app.route("/do_add_user", methods=['POST'])
def do_add_user():
    print(request.form)  # 在这里打印一下接收到的post的参数（是show_add_user.html中的）
    name = request.form.get("name")
    sex = request.form.get("sex")
    age = request.form.get("age")
    email = request.form.get("email")

    # 注意一下 f '''''' 加 {}的数据引用方式，赞
    sql = f'''
        insert into user (name, sex, age ,email) value ('{name}', '{sex}' , '{age}', '{email}' )
    '''
    print(sql)
    insert_or_update_data(sql)
    return 'success'  # 一定要return 一点什么东西，否则会报错

if __name__ == '__main__':
    app.run()

# %% [markdown]
# <!DOCTYPE html>  # 要注意文件的路径，不在templates下面的文件是无法被app render_template的
# <html lang="en">
# <head>
#     <meta charset="UTF-8">
#     <title>提交用户信息</title>
# </head>
# <body>
# <div>
#     <h1>提交用户信息：</h1>
#     <form action="/do_add_user" method="post">
#         <table border="1">
#             <tr>
#                 <th>用户名</th>
#                 <td><input type="text" name="name"></td>
#             </tr>
#             <tr>
#                 <th>性别</th>
#                 <td><input type="text" name="sex"></td>
#             </tr>
#             <tr>
#                 <th>年龄</th>
#                 <td><input type="text" name="age"></td>
#             </tr>
#             <tr>
#                 <th>邮箱</th>
#                 <td><input type="text" name="email"></td>
#             </tr>
#             <tr>
#                 <th>提交</th>
#                 <td><input type="submit" name="submit"></td>
#             </tr>
#         </table>
#     </form>
# </div>
# </body>
# </html>

# %%
# 用pymysql实现pycharm与mysql的connection
def get_conn():
    return pymysql.connect(   # 这里开头直接是return
        host = '127.0.0.1',
        user = 'root',
        password = 'pcx19570403',
        database = 'python_mysql',
        charset = 'utf8'
    ) # 先测试函数内容，RUN后不报错,说明成功,再用函数封装，以便之后使用

# 用一个函数来提取sql请求，抓取数据
def query_data(sql):
    conn = get_conn()  # 建立连接
    try:
        cursor = conn.cursor(pymysql.cursors.DictCursor) #在建好的链接中,创建pymysql光标，并返回字典形式
        cursor.execute(sql)  # 光标执行sql语句
        return cursor.fetchall() # 提取所有内容
    finally:
        conn.close() # 为防止资源占用,使用try, finally使用后关闭

# 用一个函数来插入，更新mysql数据库
def insert_or_update_data(sql): # 插入和更新表格
    conn = get_conn() # 建立连接
    try:
        cursor = conn.cursor() #建立光标
        cursor.execute(sql) #光标执行sql语句
        conn.commit()  # 确认commit
    finally:
        conn.close()

# 统一执行以上出现过的函数
if __name__ == '__main__':
    # 插入，更新一条sql数据
    sql = 'insert user (name, sex, age, email) values("daming", "male", 23 , "daming@gmail.com")' # 内容
    insert_or_update_data(sql) # 执行函数

    # 提取mysql数据并展示
    sql = 'select * from user'
    datas = query_data(sql)
    import pprint
    pprint.pprint(datas)

# %% [markdown]
# #### 查看所有用户信息和单个用户信息，表单查询

# %%
from flask import Flask, render_template, request
import json
from db import insert_or_update_data
import db

app = Flask(__name__)


@app.route('/')        # 重要，指定了url的访问路径
def hello_world():     # 定义这个url中的内容
    return 'Hello World!'


@app.route('/hello')   # 更换路径
def hello_world2():
    data = 'hello data'
    return render_template('hello.html', data = data)

# 路由route的本质就是个装饰器
@app.route('/user/<username>', methods=['get', 'post'])
def get_user(username):
    return 'hello {}'.format(username)



@app.route('/data', methods=['get', 'post'])
def test_data():
    # print(request.args)
    # print(request.args.get('a'), request.args.get('b'))
    # print(request.headers)
    # print(request.headers.get('User-Agent'))
    # print(request.data)
    # import json
    # print(json.loads(request.data))
    # print(request.cookies)
    # print(request.cookies.get('token'))
    # print(request.form)
    # print(request.form.get('username'), request.form.get('password'))
    return 'success'

@app.route('/user_template')
def use_template():
    datas = [(1, 'name1'),(2, 'name2'), (3, 'name3')]
    title = '学生信息'
    return render_template('user_template.html', datas = datas, title = title)

def read_pvuv_data():
    '''
    read pvuv data
    :return: list, ele:(pdate, pv, uv)
    '''
    data = []
    with open('./data/pv_uv.txt') as fin:
        for line in fin:
            pdate, pv, uv = line.split('-')
            data.append((pdate, pv, uv))
    return (data)

@app.route('/pvuv')
def pvuv():
    # read file
    data = read_pvuv_data()
    # return html
    return render_template('pvuv.html', data = data)

#
@app.route('/getjson')
def getjson():
    # read file
    data = read_pvuv_data()
    # return html
    return json.dumps(data)
# 虽然我们开发的是一个后端的api，但是在前端也是可以访问的


# flask 提交网页表单数据到mysql
@app.route("/show_add_user")
def show_add_user(): # 注意,如果是静态数据,放入static即可；写一个函数的目的是为了数据的交互
    return render_template('show_add_user.html')

# 网页表单提交后，数据录入后台mysql并显示'success'
@app.route("/do_add_user", methods=['POST'])
def do_add_user():
    print(request.form)  # 在这里打印一下接收到的post的参数（是show_add_user.html中的）
    name = request.form.get("name")
    sex = request.form.get("sex")
    age = request.form.get("age")
    email = request.form.get("email")
    # 注意一下 f '''''' 加 {}的数据引用方式，赞
    sql = f'''
        insert into user (name, sex, age ,email) value ('{name}', '{sex}' , '{age}', '{email}' )
    '''
    print(sql)
    insert_or_update_data(sql) #课程中代码是 db.insert_or_update_data(sql) 我在上方做了import处理
    return 'success'  # 一定要return 一点什么东西，否则会报错



@app.route("/show_users")
def show_users():
    # 首先，展示用户的列表
    sql = "select id,name from user"
    datas = db.query_data(sql)  # 需要import db
    return render_template("show_users.html", datas=datas) # 将sql提取数据放入html中进行渲染, 这里框架搭好,再写html功能

@app.route("/show_user/<user_id>")  # 这里的<>用于传递参数到functions
def show_user(user_id):
    sql = "select * from user where id=" + user_id  # 此方法查出的是一个列表,需再切片
    datas = db.query_data(sql)
    user = datas[0]
    return render_template("show_user.html", user = user)  # 框架搭好后，开始创建show_user.html



if __name__ == '__main__':
    app.run()

# %% [markdown]
# <!DOCTYPE html>
# <html lang="en">
# <head>
#     <meta charset="UTF-8">
#     <title>查看单个用户信息</title>
# </head>
# <body>
#     <table border="1">
#         <tr>
#             <th>用户ID</th>
#             <td>{{ user['id'] }}</td>
#         </tr>
#         <tr>
#             <th>姓名</th>
#             <td>{{ user['name'] }}</td>
#         </tr>
#         <tr>
#             <th>性别</th>
#             <td>{{ user['sex'] }}</td>
#         </tr>
#         <tr>
#             <th>年龄</th>
#             <td>{{ user['age'] }}</td>
#         </tr>
#         <tr>
#             <th>Email</th>
#             <td>{{ user['email'] }}</td>
#         </tr>
#     </table>
# </body>

# %% [markdown]
# <!DOCTYPE html>
# <html lang="en">
# <head>
#     <meta charset="UTF-8">
#     <title>查看用户列表</title>
# </head>
# <body>
#     <h1>查看用户列表</h1>
#     <table border="1">
#         <tr>
#             <th>用户ID</th>
#             <th>用户名称</th>
#             <th>查看详情</th>
#         </tr>>
#         {% for user in datas %}
#             <tr>
#                 <td>{{ user['id'] }}</td>
#                 <td>{{ user['name'] }}</td>
#                 <td><a href="/show_user/{{ user["id"] }}">查看详情</td>
#             </tr>
#         {% endfor %}
#     </table>
# </body>
# </html>

# %% [markdown]
# #### echarts图表实现

# %%
from flask import Flask, render_template, request
import json
from db import insert_or_update_data
import db
from jinja2 import Markup

app = Flask(__name__)


@app.route('/')        # 重要，指定了url的访问路径
def hello_world():     # 定义这个url中的内容
    return 'Hello World!'


@app.route('/hello')   # 更换路径
def hello_world2():
    data = 'hello data'
    return render_template('hello.html', data = data)

# 路由route的本质就是个装饰器
@app.route('/user/<username>', methods=['get', 'post'])
def get_user(username):
    return 'hello {}'.format(username)



@app.route('/data', methods=['get', 'post'])
def test_data():
    # print(request.args)
    # print(request.args.get('a'), request.args.get('b'))
    # print(request.headers)
    # print(request.headers.get('User-Agent'))
    # print(request.data)
    # import json
    # print(json.loads(request.data))
    # print(request.cookies)
    # print(request.cookies.get('token'))
    # print(request.form)
    # print(request.form.get('username'), request.form.get('password'))
    return 'success'

@app.route('/user_template')
def use_template():
    datas = [(1, 'name1'),(2, 'name2'), (3, 'name3')]
    title = '学生信息'
    return render_template('user_template.html', datas = datas, title = title)

def read_pvuv_data():
    '''
    read pvuv data
    :return: list, ele:(pdate, pv, uv)
    '''
    data = []
    with open('./data/pv_uv.txt') as fin:
        for line in fin:
            pdate, pv, uv = line.split('-')
            data.append((pdate, pv, uv))
    return (data)

@app.route('/pvuv')
def pvuv():
    # read file
    data = read_pvuv_data()
    # return html
    return render_template('pvuv.html', data = data)

#
@app.route('/getjson')
def getjson():
    # read file
    data = read_pvuv_data()
    # return html
    return json.dumps(data)
# 虽然我们开发的是一个后端的api，但是在前端也是可以访问的


# flask 提交网页表单数据到mysql
@app.route("/show_add_user")
def show_add_user(): # 注意,如果是静态数据,放入static即可；写一个函数的目的是为了数据的交互
    return render_template('show_add_user.html')

# 网页表单提交后，数据录入后台mysql并显示'success'
@app.route("/do_add_user", methods=['POST'])
def do_add_user():
    print(request.form)  # 在这里打印一下接收到的post的参数（是show_add_user.html中的）
    name = request.form.get("name")
    sex = request.form.get("sex")
    age = request.form.get("age")
    email = request.form.get("email")
    # 注意一下 f '''''' 加 {}的数据引用方式，赞
    sql = f'''
        insert into user (name, sex, age ,email) value ('{name}', '{sex}' , '{age}', '{email}' )
    '''
    print(sql)
    insert_or_update_data(sql) #课程中代码是 db.insert_or_update_data(sql) 我在上方做了import处理
    return 'success'  # 一定要return 一点什么东西，否则会报错



@app.route("/show_users")
def show_users():
    # 首先，展示用户的列表
    sql = "select id,name from user"
    datas = db.query_data(sql)  # 需要import db
    return render_template("show_users.html", datas=datas) # 将sql提取数据放入html中进行渲染, 这里框架搭好,再写html功能

@app.route("/show_user/<user_id>")  # 这里的<>用于传递参数到functions
def show_user(user_id):
    sql = "select * from user where id=" + user_id  # 此方法查出的是一个列表,需再切片
    datas = db.query_data(sql)
    user = datas[0]
    return render_template("show_user.html", user = user)  # 框架搭好后，开始创建show_user.html

@app.route("/show_echarts")
def show_echarts():
    xdatas = ["彭戈","彭春翔","彭夏炎","彭洁盈"]
    ydatas = [172, 174, 60, 160]
    return render_template("show_echarts_line.html", xdatas = Markup(json.dumps(xdatas)), ydatas = json.dumps(ydatas))

if __name__ == '__main__':
    app.run()

# %% [markdown]
# <!DOCTYPE html>
# <html>
# <head>
#     <meta charset="utf-8">
#     <title>ECharts</title>
#     <!-- 引入 echarts.js -->
#      {## js代码本地存放路径static#}
#     <script src="/static/echarts.min.js"></script>
# </head>
# <body>
#     <!-- 为ECharts准备一个具备大小（宽高）的Dom -->
#     <div id="main" style="width: 600px;height:400px;"></div>
# {#    #js代码开始#}
#     <script type="text/javascript">
#         // 基于准备好的dom，初始化echarts实例
#         {##首先得到div元素#}
#         var myChart = echarts.init(document.getElementById('main'));
#
#         // 指定图表的配置项和数据
#         var option = {
#             title: {
#                 text: 'ECharts 入门示例'
#             },
#             tooltip: {},
#             legend: {
#                 data: ["身高"]
#             },
#             xAxis: {
#                 {## 注意数据引入的位置#}
#                 data: {{ xdatas }}
#             },
#             yAxis: {},
#             series: [{
#                 name: "身高",
#                 type: 'bar',
#                 {## 注意数据引入的位置#}
#                 data: {{ ydatas }}
#             }]
#         };
#
#         // 使用刚指定的配置项和数据显示图表。
#         myChart.setOption(option);
#     </script>
# </body>
# </html>

# %% [markdown]
# <!DOCTYPE html>
# <html>
# <head>
#     <meta charset="utf-8">
#     <title>ECharts</title>
#     <!-- 引入 echarts.js -->
#     <script src="/static/echarts.min.js"></script>
# </head>
# <body>
#     <!-- 为ECharts准备一个具备大小（宽高）的Dom -->
#     <div id="main" style="width: 600px;height:400px;"></div>
#     <script type="text/javascript">
#         // 基于准备好的dom，初始化echarts实例
#         var myChart = echarts.init(document.getElementById('main'));
#
#         // 指定图表的配置项和数据
#         var option = {
#     xAxis: {
#         type: 'category',
#         data: ["彭戈","彭春翔","彭夏炎","彭洁盈"]
#     },
#     yAxis: {
#         type: 'value'
#     },
#     series: [{
#         data: [172, 174, 60, 160],
#         type: 'line'
#     }]
# };
#
#         // 使用刚指定的配置项和数据显示图表。
#         myChart.setOption(option);
#     </script>
# </body>
# </html>

# %% [markdown]
# #### epychats实现多图同页面显示

# %%
from flask import Flask, render_template, request
import json
from db import insert_or_update_data
import db
from jinja2 import Markup
from pyecharts.charts import Bar
from pyecharts import options as opts
from pyecharts.charts import Pie
from pyecharts.faker import Faker
from pyecharts.charts import Line


app = Flask(__name__)


@app.route('/')        # 重要，指定了url的访问路径
def hello_world():     # 定义这个url中的内容
    return 'Hello World!'


@app.route('/hello')   # 更换路径
def hello_world2():
    data = 'hello data'
    return render_template('hello.html', data = data)

# 路由route的本质就是个装饰器
@app.route('/user/<username>', methods=['get', 'post'])
def get_user(username):
    return 'hello {}'.format(username)



@app.route('/data', methods=['get', 'post'])
def test_data():
    # print(request.args)
    # print(request.args.get('a'), request.args.get('b'))
    # print(request.headers)
    # print(request.headers.get('User-Agent'))
    # print(request.data)
    # import json
    # print(json.loads(request.data))
    # print(request.cookies)
    # print(request.cookies.get('token'))
    # print(request.form)
    # print(request.form.get('username'), request.form.get('password'))
    return 'success'

@app.route('/user_template')
def use_template():
    datas = [(1, 'name1'),(2, 'name2'), (3, 'name3')]
    title = '学生信息'
    return render_template('user_template.html', datas = datas, title = title)

def read_pvuv_data():
    '''
    read pvuv data
    :return: list, ele:(pdate, pv, uv)
    '''
    data = []
    with open('./data/pv_uv.txt') as fin:
        for line in fin:
            pdate, pv, uv = line.split('-')
            data.append((pdate, pv, uv))
    return (data)

@app.route('/pvuv')
def pvuv():
    # read file
    data = read_pvuv_data()
    # return html
    return render_template('pvuv.html', data = data)

#
@app.route('/getjson')
def getjson():
    # read file
    data = read_pvuv_data()
    # return html
    return json.dumps(data)
# 虽然我们开发的是一个后端的api，但是在前端也是可以访问的


# flask 提交网页表单数据到mysql
@app.route("/show_add_user")
def show_add_user(): # 注意,如果是静态数据,放入static即可；写一个函数的目的是为了数据的交互
    return render_template('show_add_user.html')

# 网页表单提交后，数据录入后台mysql并显示'success'
@app.route("/do_add_user", methods=['POST'])
def do_add_user():
    print(request.form)  # 在这里打印一下接收到的post的参数（是show_add_user.html中的）
    name = request.form.get("name")
    sex = request.form.get("sex")
    age = request.form.get("age")
    email = request.form.get("email")
    # 注意一下 f '''''' 加 {}的数据引用方式，赞
    sql = f'''
        insert into user (name, sex, age ,email) value ('{name}', '{sex}' , '{age}', '{email}' )
    '''
    print(sql)
    insert_or_update_data(sql) #课程中代码是 db.insert_or_update_data(sql) 我在上方做了import处理
    return 'success'  # 一定要return 一点什么东西，否则会报错



@app.route("/show_users")
def show_users():
    # 首先，展示用户的列表
    sql = "select id,name from user"
    datas = db.query_data(sql)  # 需要import db
    return render_template("show_users.html", datas=datas) # 将sql提取数据放入html中进行渲染, 这里框架搭好,再写html功能

@app.route("/show_user/<user_id>")  # 这里的<>用于传递参数到functions
def show_user(user_id):
    sql = "select * from user where id=" + user_id  # 此方法查出的是一个列表,需再切片
    datas = db.query_data(sql)
    user = datas[0]
    return render_template("show_user.html", user = user)  # 框架搭好后，开始创建show_user.html


@app.route("/show_echarts")
def show_echarts():
    xdatas = ["彭戈","彭春翔","彭夏炎","彭洁盈"]
    ydatas = [172, 174, 60, 160]
    return render_template("show_echarts_line.html", xdatas = Markup(json.dumps(xdatas)), ydatas = json.dumps(ydatas))


@app.route("/show_pyecharts")
def show_pyecharts():
    bar = (
        Bar()
            .add_xaxis(["衬衫", "羊毛衫", "雪纺衫", "裤子", "高跟鞋", "袜子"])
            .add_yaxis("商家A", [5, 20, 36, 10, 75, 90])
    )
    return render_template("show_pyecharts.html", bar_options = bar.dump_options())

def get_pie()-> Pie:
    sql = """
        select sex,count(1) as cnt from user group by sex
    """
    datas = db.query_data(sql)
    c = (
        Pie()
            .add("", [(data['sex'], data['cnt']) for data in datas])
            .set_colors(["blue", "green", "yellow", "red", "pink", "orange", "purple"])
            .set_global_opts(title_opts=opts.TitleOpts(title="Pie-设置颜色"))
            .set_series_opts(label_opts=opts.LabelOpts(formatter="{b}: {c}"))
            # .render("pie_set_color.html")
    )
    return c

def get_bar():
    sql = """
            select sex,count(1) as cnt from user group by sex
        """
    datas = db.query_data(sql)

    c = (
        Bar()
            .add_xaxis([data['sex'] for data in datas])
            .add_yaxis("数量", [data['cnt'] for data in datas])
            # .add_yaxis("商家B", Faker.values())
            .set_global_opts(title_opts=opts.TitleOpts(title="Bar-基本示例", subtitle="我是副标题"))
            # .render("bar_base.html")
    )
    return c

def get_line():
    sql = """
            select pdate,pv,uv from pvuv
            """
    datas = db.query_data(sql)
    c = (
        Line()
            .add_xaxis([data['pdate'] for data in datas])
            .add_yaxis("pv",  [data['pv'] for data in datas])
            .add_yaxis("uv",  [data['uv'] for data in datas])
            .set_global_opts(title_opts=opts.TitleOpts(title="Line-基本示例"))
            # .render("line_base.html")
    )
    return c

@app.route("/show_myecharts")  #创建路由
def show_myecharts():          #创建方法
    pie = get_pie()
    bar = get_bar()
    line = get_line()
    return render_template( "show_myecharts.html",
                     pie_options=pie.dump_options(),
                     bar_options = bar.dump_options(),
                     line_options = line.dump_options()
                     )


if __name__ == '__main__':
    app.run()

# %% [markdown]
# <!DOCTYPE html>
# <html>
# <head>
#     <meta charset="utf-8">
#     <title>ECharts</title>
#     <!-- 引入 echarts.js -->
#      {## js代码本地存放路径static#}
#     <script src="/static/echarts.min.js"></script>
# </head>
# <body>
#     <!-- 为ECharts准备一个具备大小（宽高）的Dom -->
#     <h1>饼图</h1>
#     <div id="pie" style="width: 600px;height:400px;"></div>
#     <h1>柱状图</h1>
#     <div id="bar" style="width: 600px;height:400px;"></div>
#     <h1>折线图</h1>
#     <div id="line" style="width: 600px;height:400px;"></div>
# {#    #js代码开始#}
#     <script type="text/javascript">
#         // 基于准备好的dom，初始化echarts实例
#         {##首先得到div元素#}
#         var pieChart = echarts.init(document.getElementById('pie'));
#         var barChart = echarts.init(document.getElementById('bar'));
#         var lineChart = echarts.init(document.getElementById('line'));
#         // 指定图表的配置项和数据
#         // | safe 的作用和Markup是一样的
#         pieChart.setOption({{ pie_options | safe }});
#         barChart.setOption({{ bar_options | safe }});
#         lineChart.setOption({{ line_options | safe }});
#     </script>
# </body>
# </html>

# %% [markdown]
# #### 以excel形式实现网络数据下载

# %%
from flask import Flask, render_template, request, send_from_directory
import json
from db import insert_or_update_data
import db
from jinja2 import Markup
from pyecharts.charts import Bar
from pyecharts import options as opts
from pyecharts.charts import Pie
from pyecharts.faker import Faker
from pyecharts.charts import Line
import datetime
import xlwt
import os

app = Flask(__name__)


@app.route('/')        # 重要，指定了url的访问路径
def hello_world():     # 定义这个url中的内容
    return 'Hello World!'


@app.route('/hello')   # 更换路径
def hello_world2():
    data = 'hello data'
    return render_template('hello.html', data = data)

# 路由route的本质就是个装饰器
@app.route('/user/<username>', methods=['get', 'post'])
def get_user(username):
    return 'hello {}'.format(username)



@app.route('/data', methods=['get', 'post'])
def test_data():
    # print(request.args)
    # print(request.args.get('a'), request.args.get('b'))
    # print(request.headers)
    # print(request.headers.get('User-Agent'))
    # print(request.data)
    # import json
    # print(json.loads(request.data))
    # print(request.cookies)
    # print(request.cookies.get('token'))
    # print(request.form)
    # print(request.form.get('username'), request.form.get('password'))
    return 'success'

@app.route('/user_template')
def use_template():
    datas = [(1, 'name1'),(2, 'name2'), (3, 'name3')]
    title = '学生信息'
    return render_template('user_template.html', datas = datas, title = title)

def read_pvuv_data():
    '''
    read pvuv data
    :return: list, ele:(pdate, pv, uv)
    '''
    data = []
    with open('./data/pv_uv.txt') as fin:
        for line in fin:
            pdate, pv, uv = line.split('-')
            data.append((pdate, pv, uv))
    return (data)

@app.route('/pvuv')
def pvuv():
    # read file
    data = read_pvuv_data()
    # return html
    return render_template('pvuv.html', data = data)

#
@app.route('/getjson')
def getjson():
    # read file
    data = read_pvuv_data()
    # return html
    return json.dumps(data)
# 虽然我们开发的是一个后端的api，但是在前端也是可以访问的


# flask 提交网页表单数据到mysql
@app.route("/show_add_user")
def show_add_user(): # 注意,如果是静态数据,放入static即可；写一个函数的目的是为了数据的交互
    return render_template('show_add_user.html')

# 网页表单提交后，数据录入后台mysql并显示'success'
@app.route("/do_add_user", methods=['POST'])
def do_add_user():
    print(request.form)  # 在这里打印一下接收到的post的参数（是show_add_user.html中的）
    name = request.form.get("name")
    sex = request.form.get("sex")
    age = request.form.get("age")
    email = request.form.get("email")
    # 注意一下 f '''''' 加 {}的数据引用方式，赞
    sql = f'''
        insert into user (name, sex, age ,email) value ('{name}', '{sex}' , '{age}', '{email}' )
    '''
    print(sql)
    insert_or_update_data(sql) #课程中代码是 db.insert_or_update_data(sql) 我在上方做了import处理
    return 'success'  # 一定要return 一点什么东西，否则会报错



@app.route("/show_users")
def show_users():
    # 首先，展示用户的列表
    sql = "select id,name from user"
    datas = db.query_data(sql)  # 需要import db
    return render_template("show_users.html", datas=datas) # 将sql提取数据放入html中进行渲染, 这里框架搭好,再写html功能

@app.route("/show_user/<user_id>")  # 这里的<>用于传递参数到functions
def show_user(user_id):
    sql = "select * from user where id=" + user_id  # 此方法查出的是一个列表,需再切片
    datas = db.query_data(sql)
    user = datas[0]
    return render_template("show_user.html", user = user)  # 框架搭好后，开始创建show_user.html


@app.route("/show_echarts")
def show_echarts():
    xdatas = ["彭戈","彭春翔","彭夏炎","彭洁盈"]
    ydatas = [172, 174, 60, 160]
    return render_template("show_echarts_line.html", xdatas = Markup(json.dumps(xdatas)), ydatas = json.dumps(ydatas))


@app.route("/show_pyecharts")
def show_pyecharts():
    bar = (
        Bar()
            .add_xaxis(["衬衫", "羊毛衫", "雪纺衫", "裤子", "高跟鞋", "袜子"])
            .add_yaxis("商家A", [5, 20, 36, 10, 75, 90])
    )
    return render_template("show_pyecharts.html", bar_options = bar.dump_options())

def get_pie()-> Pie:
    sql = """
        select sex,count(1) as cnt from user group by sex
    """
    datas = db.query_data(sql)
    c = (
        Pie()
            .add("", [(data['sex'], data['cnt']) for data in datas])
            .set_colors(["blue", "green", "yellow", "red", "pink", "orange", "purple"])
            .set_global_opts(title_opts=opts.TitleOpts(title="Pie-设置颜色"))
            .set_series_opts(label_opts=opts.LabelOpts(formatter="{b}: {c}"))
            # .render("pie_set_color.html")
    )
    return c

def get_bar():
    sql = """
            select sex,count(1) as cnt from user group by sex
        """
    datas = db.query_data(sql)

    c = (
        Bar()
            .add_xaxis([data['sex'] for data in datas])
            .add_yaxis("数量", [data['cnt'] for data in datas])
            # .add_yaxis("商家B", Faker.values())
            .set_global_opts(title_opts=opts.TitleOpts(title="Bar-基本示例", subtitle="我是副标题"))
            # .render("bar_base.html")
    )
    return c

def get_line():
    sql = """
            select pdate,pv,uv from pvuv
            """
    datas = db.query_data(sql)
    c = (
        Line()
            .add_xaxis([data['pdate'] for data in datas])
            .add_yaxis("pv",  [data['pv'] for data in datas])
            .add_yaxis("uv",  [data['uv'] for data in datas])
            .set_global_opts(title_opts=opts.TitleOpts(title="Line-基本示例"))
            # .render("line_base.html")
    )
    return c

@app.route("/show_myecharts")  #创建路由
def show_myecharts():          #创建方法
    pie = get_pie()
    bar = get_bar()
    line = get_line()
    return render_template( "show_myecharts.html",
                     pie_options=pie.dump_options(),
                     bar_options = bar.dump_options(),
                     line_options = line.dump_options()
                     )


def generate_excel(data_dir, fname):# 需要安装xlwt package, 在import xlwt
    fpath = os.path.join(data_dir, fname)
    workbook = xlwt.Workbook(encoding="utf-8") # 使用xlwt穿件excel对象，utf8支持中文读取
    worksheet = workbook.add_sheet("pvuv")   # 为这个excel对象添加一个sheet

    for idx,name in enumerate(['日期', 'pv', 'uv']): # 写出sheet的表头
        worksheet.write(0, idx, name)

    datas = db.query_data("select * from pvuv") # 读取mysql数据后，写入每一行的数据
    for row,data in enumerate(datas):
        for col, kv in enumerate(data.items()):
            worksheet.write(row+1, col, kv[1])
    workbook.save(fpath)                       #对数据进行保存



@app.route("/download_pvuv")
def download_pvuv():
    data_dir = os.path.join(app.root_path, "downloads")   #app.root_path可以调取当前路径, 需要import os
    now_time = datetime.datetime.now().strftime("%y%m%d_%h%m%s")  #用时间给每个文件设置文件名,精确到秒，避免重复
    fname = f"pvuv_{now_time}.xls"  # str加时间的方式来创建文件名

    generate_excel(data_dir, fname) # 一会儿在写

    return send_from_directory(data_dir, fname, as_attachment=True)  #需要从flask中引入send_from_directory
    # 重要，最终通过send_from_directory()方法将，目录 - 文件 - 作为附件下载

if __name__ == '__main__':
    app.run()

# %%
# many materials about deploying flask online, which is bit confusing ...

# %%
# need a list for deploying learning

# %%
import dash
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-6-41ab4880e0b0> in <module>
# ----> 1 import dash
#
# ModuleNotFoundError: No module named 'dash'

# %%
import dash
