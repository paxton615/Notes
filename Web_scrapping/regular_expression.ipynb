# %%
import re  #regex/RE
from IPython.display import Image 
import os
import shutil

# %%
pwd
# Out:
# '/Users/paxton615/Github_Personal/Notes/Notes/Web_scrapping'

# %%
# newpath = r'/Users/paxton615/Github_Personal/Notes/Notes/pics/re' 
# if not os.path.exists(newpath):
#     os.makedirs(newpath)

# %%
# original = r'/Users/paxton615/Github_Personal/Notes/Notes/re'
# target = r'/Users/paxton615/Github_Personal/Notes/Notes/pics/re'

# shutil.move(original,target)
# #https://datatofish.com/move-file-python/  #移动文件或文件夹

# %%
def add_pics(name):
    return (Image(filename='/Users/paxton615/Github_Personal/Notes/Notes/pics/re/'+name))

# %%
add_pics('re1.png')

# %%
print('P(Y|YT|YTH|YTHO)?N')
# Out:
# P(Y|YT|YTH|YTHO)?N

# %%
add_pics('re2.png')

# %%
add_pics('re3.png')

# %%
add_pics('re4.png')

# %%
add_pics('re5.png')

# %%
add_pics('re6.png')

# %%
add_pics('re7.png')
