# %%
import requests
from bs4 import BeautifulSoup
import bs4
import pandas as pd
import numpy as np
from IPython.display import Image
pd.options.display.max_rows = 5000 #(设定能显示的行数)

# %%
bdrooms = []
addresses = []
rent = []

for start in range(0,480,24):
    url = 'https://www.rightmove.co.uk/property-to-rent/find.html?locationIdentifier=STATION%5E9233&minBedrooms=2&radius=1.0&propertyTypes=flat&primaryDisplayPropertyType=flats&includeLetAgreed=false&mustHave=&dontShow=&furnishTypes=&keywords='.format(start)
    r = requests.get(url)
    soup = BeautifulSoup(r.text, "html.parser")
    
    for num in soup.find_all('h2', class_= 'propertyCard-title'):
        bdrooms.append(num.text.strip())
        
    for add in soup.find_all('address', class_="propertyCard-address"):
        for meta in add:
            for loc in meta:
                if type(loc) is bs4.element.NavigableString:
                    addresses.append(loc)
                    
    for pc in soup.find_all('span', 'propertyCard-priceValue'):
        rent.append(pc.string)

# %%
print(len(bdrooms))
print(bdrooms[:5])
print(len(addresses))
print(addresses[:5])
print(len(rent))
print(rent[:5])
# Out:
# 500
# ['2 bedroom flat', '2 bedroom flat', '2 bedroom flat', '2 bedroom apartment', '2 bedroom apartment']
# 240
# ['Tonbridge', 'Quarry Hill road, Tonbridge', 'South Tonbridge', 'Church Street, Tonbridge TN9 1HD', 'Dame Kelly Holmes Way, Tonbridge TN9 2FB']
# 500
# ['£1,195 pcm', '£1,000 pcm', '£1,100 pcm', '£1,150 pcm', '£1,250 pcm']

# %%
tonbridge_2bedsflat_1ms = pd.DataFrame({'bdrooms':pd.Series(bdrooms), 'address':pd.Series(addresses), 'pcm':pd.Series(rent)})
tonbridge_2bedsflat_1ms = tonbridge_2bedsflat_1ms.dropna()
tonbridge_2bedsflat_1ms['pcm'] = [int(''.join(filter(str.isdigit, i))) for i in tonbridge_2bedsflat_1ms['pcm']]
tonbridge_2bedsflat_1ms.describe()
# Out:
#                pcm
# count   120.000000
# mean   1099.166667
# std     121.628193
# min     895.000000
# 25%     987.500000
# 50%    1125.000000
# 75%    1200.000000
# max    1250.000000

# %%
tonbridge_2bedsflat_1ms
# Out:
#                  bdrooms                                   address   pcm
# 0         2 bedroom flat                                 Tonbridge  1195
# 1         2 bedroom flat               Quarry Hill road, Tonbridge  1000
# 2         2 bedroom flat                           South Tonbridge  1100
# 3    2 bedroom apartment          Church Street, Tonbridge TN9 1HD  1150
# 4    2 bedroom apartment  Dame Kelly Holmes Way, Tonbridge TN9 2FB  1250
# 5         2 bedroom flat                 Annison Street, Tonbridge  1200
# 6         2 bedroom flat         Medway Wharf Road, Tonbridge, TN9  1200
# 7         2 bedroom flat                                 Tonbridge   950
# 8         2 bedroom flat                    High Street, Tonbridge  1050
# 9    2 bedroom apartment               Quarry Hill Road, Tonbridge   895
# 10        2 bedroom flat                Springwell Road, Tonbridge   950
# 11        2 bedroom flat                    Hadlow Road, Tonbridge  1250
# ...
