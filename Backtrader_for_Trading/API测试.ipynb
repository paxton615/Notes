# %% [markdown]
# 对API的需求说明：
#
# 1. 能够回测某只股票以往常年的数据
#
# 2. 最好能够调取股票公司的财务记录
#
# 3. 最好兼顾美国，英国，香港和中国大陆的股票数据

# %% [markdown]
# 以往用过Alpha Vantage, 本次继续测试Alpha是否符合以上需求
#
# Alpha Vantage api-key
#
# EUWPYIBX33PPD5U5
#
# url = 'https://www.alphavantage.co/query?function=TIME_SERIES_DAILY_ADJUSTED&symbol=COBR.LON&outputsize=full&apikey=EUWPYIBX33PPD5U5'
#
# r = requests.get(url)
#
# data = r.json()
#
# print(data)

# %%
import requests

url = "https://alpha-vantage.p.rapidapi.com/query"

querystring = {"time_period":"60","interval":"5min","series_type":"close","function":"SMA","symbol":"MSFT","datatype":"json"}

headers = {
	"X-RapidAPI-Key": "9cd97ba3camsh244cbd2e3e420a4p1e83c0jsne0fdd0787f8e",
	"X-RapidAPI-Host": "alpha-vantage.p.rapidapi.com"
}

response = requests.request("GET", url, headers=headers, params=querystring)

print(response.text)
# Out:
# {
#     "Meta Data": {
#         "1: Symbol": "MSFT",
#         "2: Indicator": "Simple Moving Average (SMA)",
#         "3: Last Refreshed": "2022-08-04 20:00:00",
#         "4: Interval": "5min",
#         "5: Time Period": 60,
#         "6: Series Type": "close",
#         "7: Time Zone": "US/Eastern"
#     },
#     "Technical Analysis: SMA": {
#         "2022-08-04 20:00": {
#             "SMA": "283.3407"
#         },
#         "2022-08-04 19:45": {
#             "SMA": "283.3202"
#         },
#         "2022-08-04 19:35": {
#             "SMA": "283.3032"
#         },
#         "2022-08-04 19:25": {
#             "SMA": "283.2829"
#         },
#         "2022-08-04 19:20": {
#             "SMA": "283.2609"
#         },
#         "2022-08-04 19:15": {
#             "SMA": "283.2386"
#         },
#         "2022-08-04 19:05": {
#             "SMA": "283.2154"
#         },
#         "2022-08-04 19:00": {
#             "SMA": "283.1862"
#         },
#         "2022-08-04 18:55": {
# ...

# %%
import requests

url = "https://apidojo-yahoo-finance-v1.p.rapidapi.com/market/get-trending-tickers"

querystring = {"region":"US"}

headers = {
	"X-RapidAPI-Key": "9cd97ba3camsh244cbd2e3e420a4p1e83c0jsne0fdd0787f8e",
	"X-RapidAPI-Host": "apidojo-yahoo-finance-v1.p.rapidapi.com"
}

response = requests.request("GET", url, headers=headers, params=querystring)

print(response.text)
# Out:
# {"finance":{"result":[{"count":20,"quotes":[{"language":"en-US","region":"US","quoteType":"EQUITY","typeDisp":"Equity","quoteSourceName":"Nasdaq Real Time Price","triggerable":true,"customPriceAlertConfidence":"HIGH","trendingScore":88.33890877642628,"exchangeTimezoneName":"America/New_York","exchangeTimezoneShortName":"EDT","gmtOffSetMilliseconds":-14400000,"esgPopulated":false,"tradeable":false,"firstTradeDateMilliseconds":1564061400000,"priceHint":2,"regularMarketChange":1.8199997,"regularMarketChangePercent":11.124692,"regularMarketTime":1659714967,"regularMarketPrice":18.18,"regularMarketPreviousClose":16.36,"exchange":"NMS","market":"us_market","fullExchangeName":"NasdaqGS","shortName":"DraftKings Inc.","longName":"DraftKings Inc.","marketState":"REGULAR","sourceInterval":15,"exchangeDataDelayedBy":0,"symbol":"DKNG"},{"language":"en-US","region":"US","quoteType":"EQUITY","typeDisp":"Equity","quoteSourceName":"Nasdaq Real Time Price","triggerable":false,"customPriceAlertConfiden
# ...

# %%
url = "https://apidojo-yahoo-finance-v1.p.rapidapi.com/stock/v3/get-historical-data"

querystring = {"symbol":"AMRN","region":"US"}

headers = {
	"X-RapidAPI-Key": "9cd97ba3camsh244cbd2e3e420a4p1e83c0jsne0fdd0787f8e",
	"X-RapidAPI-Host": "apidojo-yahoo-finance-v1.p.rapidapi.com"
}

response = requests.request("GET", url, headers=headers, params=querystring)

print(response.text)
# Out:
# {"prices":[{"date":1659715367,"open":1.2799999713897705,"high":1.2899999618530273,"low":1.25,"close":1.2549999952316284,"volume":698685,"adjclose":1.2549999952316284},{"date":1659619800,"open":1.25,"high":1.309999942779541,"low":1.25,"close":1.2799999713897705,"volume":3502900,"adjclose":1.2799999713897705},{"date":1659533400,"open":1.2999999523162842,"high":1.4199999570846558,"low":1.2400000095367432,"close":1.2699999809265137,"volume":4992000,"adjclose":1.2699999809265137},{"date":1659447000,"open":1.25,"high":1.3700000047683716,"low":1.25,"close":1.3300000429153442,"volume":4496100,"adjclose":1.3300000429153442},{"date":1659360600,"open":1.3200000524520874,"high":1.350000023841858,"low":1.2699999809265137,"close":1.2899999618530273,"volume":4287500,"adjclose":1.2899999618530273},{"date":1659101400,"open":1.3200000524520874,"high":1.350000023841858,"low":1.2899999618530273,"close":1.3300000429153442,"volume":1475000,"adjclose":1.3300000429153442},{"date":1659015000,"open":1.3500000
# ...
