# %%
import pandas as pd
import numpy as np
from datetime import datetime
from datetime import date
import matplotlib.pyplot as plt
import seaborn as sns
import requests
pd.options.display.max_rows = 5000 
pd.options.display.max_columns = 200

# %%
df = pd.read_csv(r'/Users/paxton615/Desktop/Stock_Price_csv/gold/{}.csv'.format('gold_1985'))
# df.drop('Unnamed: 0',axis=1, inplace=True)

# %%
df.time = [i[:10] for i in df.time]

# %%
data = df[['time','close']]

# %%
# Out:
#             time      close
# 0     1985-02-13   0.625000
# 1     1985-02-14   0.703125
# 2     1985-02-15   0.664063
# 3     1985-02-19   0.644531
# 4     1985-02-20   0.625000
# ...          ...        ...
# 9300  2022-01-05  18.570000
# 9301  2022-01-06  18.020000
# 9302  2022-01-07  18.100000
# 9303  2022-01-10  18.620000
# 9304  2022-01-11  18.860000
#
# [9305 rows x 2 columns]

# %%
df.close.plot(figsize=(20,10))
