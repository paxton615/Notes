# %%
import pandas as pd
import datetime as dt
from datetime import datetime
from datetime import date
import matplotlib.pyplot as plt
import re
import requests
pd.options.display.max_rows = 5000

# %%
pwd
# Out:
# '/Users/paxton615/Github_Personal/Notes/Notes/Client_stats'

# %% [markdown]
# - Stock data:
#
# spaq : Spinaker Aquisitions

# %%
url = "https://yahoo-finance15.p.rapidapi.com/api/yahoo/hi/history/spaq.l/1d"

headers = {
    'x-rapidapi-key': "9cd97ba3camsh244cbd2e3e420a4p1e83c0jsne0fdd0787f8e",
    'x-rapidapi-host': "yahoo-finance15.p.rapidapi.com"
    }

spaq = requests.request("GET", url, headers=headers)

# print(response.text[:500])

# %% [markdown]
# - Stock data
#
# pre : Pensana

# %%
url = "https://yahoo-finance15.p.rapidapi.com/api/yahoo/hi/history/pre.l/1d"

headers = {
    'x-rapidapi-key': "9cd97ba3camsh244cbd2e3e420a4p1e83c0jsne0fdd0787f8e",
    'x-rapidapi-host': "yahoo-finance15.p.rapidapi.com"
    }

pre = requests.request("GET", url, headers=headers)

# %%
spaq = spaq.text
pre = pre.text

# %%
def get_dates(string):
    date = re.compile('"date":((.*),)')
    date = date.findall(string)
    date = [i[0][2:12] for i in date]
    date = [datetime.strptime(i, "%d-%m-%Y").strftime("%Y-%m-%d") for i in date]
    return date

def get_close(string):
    close = re.compile('"close":((.*),)')
    close = close.findall(string)
    close = [float(i[1].strip()) for i in close]
    return close

# %%
spaq_date = get_dates(spaq)
spaq_close = get_close(spaq)

# %%
pre_date = get_dates(pre)
pre_close = get_close(pre)

# %%
print(spaq_date[-1])
print(spaq_close[-1])
print(pre_date[-1])
print(pre_close[-1])
# Out:
# 2021-10-11
# 13.25
# 2021-10-11
# 77.0

# %%
fund = 10000
client = ['Ma', 'Ma']
stock = ['spaq', 'pre']
total_cap = [10000, 10000]
invest_in = [5000, 5000]
ipo_price = [0.1, 1.34]
w_pirce = [0.2, 0]
s_position = pd.Series(invest_in)/pd.Series(ipo_price)
p_vs_w = [0.5, 0]
w_position = pd.Series(s_position)*pd.Series(p_vs_w)
s_date = [spaq_date[-1], pre_date[-1]]
s_close = [spaq_close[-1]/100, pre_close[-1]/100]

# %%
mr_ma = pd.DataFrame({'client':client, 'stock':stock, 'total_cap':total_cap, 'invest_in':invest_in, \
             'ipo_price':ipo_price, 'w_pirce':w_pirce ,'p_vs_w':p_vs_w,'s_position':s_position, \
             'w_position':w_position, 's_date':s_date, 's_close':s_close,\
             })

# %%
mr_ma['s_pft'] = (mr_ma['s_close'] - mr_ma['ipo_price'])* mr_ma['s_position']

mr_ma['w_pft'] = [(i-j)*k if i>j else 0 for i,j,k in zip(mr_ma.s_close, mr_ma.w_pirce, mr_ma.w_position)]

mr_ma['charge_plcing'] = 0.03 * mr_ma['invest_in'] + 10

# %%
mr_ma
# Out:
#   client stock  total_cap  invest_in  ipo_price  w_pirce  p_vs_w  \
# 0     Ma  spaq      10000       5000       0.10      0.2     0.5
# 1     Ma   pre      10000       5000       1.34      0.0     0.0
#
#      s_position  w_position      s_date  s_close        s_pft  w_pft  \
# 0  50000.000000     25000.0  2021-10-11   0.1325  1625.000000    0.0
# 1   3731.343284         0.0  2021-10-11   0.7700 -2126.865672    0.0
#
#    charge_plcing
# 0          160.0
# 1          160.0

# %%
account_balance = fund + sum(mr_ma['s_pft'])+sum(mr_ma['w_pft'])

total_charges = sum( mr_ma['charge_plcing'])

total_pft = account_balance - total_charges

# %%
print('Account_balance:', account_balance)
print('total_charges:', total_charges)
print('total_profit:', total_pft)
# Out:
# Account_balance: 9498.134328358208
# total_charges: 320.0
# total_profit: 9178.134328358208

# %% [markdown]
# 测算一下，如果稳定的拥有30%的年化回报，资金的增长情况是怎样的

# %%
def final_return(initial, rr, times):
    final = initial * ((1+rr)**times)
    return final

# %%
import pyreadstat as pr

# %%
spss = pr.read_sav(r'/Users/paxton615/Downloads/UKDA-8351-spss/spss/spss25/2016_17_dvper_ukanon.sav')

# %%
import requests

# replace the "demo" apikey below with your own key from https://www.alphavantage.co/support/#api-key
url = 'https://www.alphavantage.co/query?function=TIME_SERIES_DAILY&symbol=cobr.l&apikey=EUWPYIBX33PPD5U5'
r = requests.get(url)
data = r.json()

print(data)
# Out:
# {'Meta Data': {'1. Information': 'Daily Prices (open, high, low, close) and Volumes', '2. Symbol': 'cobr.l', '3. Last Refreshed': '2021-10-12', '4. Output Size': 'Compact', '5. Time Zone': 'US/Eastern'}, 'Time Series (Daily)': {'2021-10-12': {'1. open': '1.5599', '2. high': '1.6300', '3. low': '1.5100', '4. close': '1.5500', '5. volume': '3224921'}, '2021-10-11': {'1. open': '1.5000', '2. high': '1.5490', '3. low': '1.4130', '4. close': '1.5000', '5. volume': '895375'}, '2021-10-08': {'1. open': '1.5500', '2. high': '1.5900', '3. low': '1.3200', '4. close': '1.5000', '5. volume': '3446806'}, '2021-10-07': {'1. open': '1.6500', '2. high': '1.6500', '3. low': '1.5000', '4. close': '1.5500', '5. volume': '2289569'}, '2021-10-06': {'1. open': '1.6490', '2. high': '1.6490', '3. low': '1.5800', '4. close': '1.6490', '5. volume': '906761'}, '2021-10-05': {'1. open': '1.6500', '2. high': '1.6799', '3. low': '1.6000', '4. close': '1.6500', '5. volume': '346865'}, '2021-10-04': {'1. open': '1.6500', '2. high': '1.6884', '3. low': '1.6000', '4. close': '1.6500', '5. volume': '357021'}, '2021-10-01': {'1. open': '1.7000', '2. high': '1.7000', '3. low': '1.6000', '4. close': '1.6500', '5. volume': '924617'}, '2021-09-30': {'1. open': '1.6300', '2. high': '1.6300', '3. low': '1.6300', '4. close': '1.6300', '5. volume': '50160'}, '2021-09-29': {'1. open': '1.7000', '2. high': '1.7490', '3. low': '1.6200', '4. close': '1.7000', '5. volume': '258202'}, '2021-09-28': {'1. open': '1.6501', '2. high': '1.7900', '3. low': '1.6501',

r = requests.get(url)
data = r.json()

print(data)
# Out:
# {'Meta Data': {'1. Information': 'Daily Time Series with Splits and Dividend Events', '2. Symbol': 'COBR.LON', '3. Last Refreshed': '2021-10-12', '4. Output Size': 'Full size', '5. Time Zone': 'US/Eastern'}, 'Time Series (Daily)': {'2021-10-12': {'1. open': '1.5599', '2. high': '1.63', '3. low': '1.51', '4. close': '1.55', '5. adjusted close': '1.55', '6. volume': '3224921', '7. dividend amount': '0.0000', '8. split coefficient': '1.0'}, '2021-10-11': {'1. open': '1.5', '2. high': '1.549', '3. low': '1.413', '4. close': '1.5', '5. adjusted close': '1.5', '6. volume': '895375', '7. dividend amount': '0.0000', '8. split coefficient': '1.0'}, '2021-10-08': {'1. open': '1.55', '2. high': '1.59', '3. low': '1.32', '4. close': '1.5', '5. adjusted close': '1.5', '6. volume': '3446806', '7. dividend amount': '0.0000', '8. split coefficient': '1.0'}, '2021-10-07': {'1. open': '1.65', '2. high': '1.65', '3. low': '1.5', '4. close': '1.55', '5. adjusted close': '1.55', '6. volume': '2289569', '7. dividend amount': '0.0000', '8. split coefficient': '1.0'}, '2021-10-06': {'1. open': '1.649', '2. high': '1.649', '3. low': '1.58', '4. close': '1.649', '5. adjusted close': '1.649', '6. volume': '906761', '7. dividend amount': '0.0000', '8. split coefficient': '1.0'}, '2021-10-05': {'1. open': '1.65', '2. high': '1.6799', '3. low': '1.6', '4. close': '1.65', '5. adjusted close': '1.65', '6. volume': '346865', '7. dividend amount': '0.0000', '8. split coefficient': '1.0'}, '2021-10-04': {'1. open': '1.65', '2. high': '1.6884', '3. low': '1.6', '4. close': '1.65', '5. adjusted close': '1.65', '6. volume': '357021', '7. dividend amount': '0.0000', '8. split coefficient': '1.0'}, '2021-10-01': {'1. open': '1.7', '2. high': '1.7', '3. low': '1.6', '4. close': '1.65', '5. adjusted close': '1.65', '6. volume': '924617', '7. dividend amount': '0.0000', '8. split coefficient': '1.0'}, '2021-09-30': {'1. open': '1.63', '2. high': '1.63', '3. low': '1.63', '4. close': '1.63', '5. adjusted close': '1.63', '6. volume': '50160', '7. dividend amount': '0.0000', '8. split coefficient': '1.0'}, '2021-09-29': {'1. open': '1.7', '2. high': '1.749', '3. low': '1.62', '4. close': '1.7', '5. adjusted close': '1.7', '6. volume': '258202', '7. dividend amount': '0.0000', '8. split coefficient': '1.0'}, '2021-09-28': {'1. open': '1.6501', '2. high': '1.79', '3. low': '1.6501', '4. close': '1.79', '5. adjusted close': '1.79', '6. volume': '1273387', '7. dividend amount': '0.0000', '8. split coefficient': '1.0'}, '2021-09-27': {'1. open': '1.7', '2. high': '1.7', '3. low': '1.6', '4. close': '1.65', '5. adjusted close': '1.65', '6. volume': '694168', '7. dividend amount': '0.0000', '8. split coefficient': '1.0'}, '2021-09-24': {'1. open': '1.75', '2. high': '1.777', '3. low': '1.7', '4. close': '1.75', '5. adjusted close': '1.75', '6. volume': '599526', '7. dividend amount': '0.0000', '8. split coefficient': '1.0'}, '2021-09-23': {'1. open': '1.75', '2. high': '1.795', '3. low': '1.7', '4. close': '1.75', '5. adjusted close': '1.75', '6. volume': '610101', '7. dividend amount': '0.0000', '8. split coefficient': '1.0'}, '2021-09-22': {'1. open': '1.75', '2. high': '1.785', '3. low': '1.725', '4. close': '1.75', '5. adjusted close': '1.75', '6. volume': '72897', '7. dividend amount': '0.0000', '8. split coefficient': '1.0'}, '2021-09-21': {'1. open': '1.7', '2. high': '1.767', '3. low': '1.62', '4. close': '1.75', '5. adjusted close': '1.75', '6. volume': '407991', '7. dividend amount': '0.0000', '8. split coefficient': '1.0'}, '2021-09-20': {'1. open': '1.75', '2. high': '1.77', '3. low': '1.633', '4. close': '1.7', '5. adjusted close': '1.7', '6. volume': '360420', '7. dividend amount': '0.0000', '8. split coefficient': '1.0'}, '2021-09-17': {'1. open': '1.75', '2. high': '1.82', '3. low': '1.696', '4. close': '1.75', '5. adjusted close': '1.75', '6. volume': '242369', '7. dividend amount': '0.0000', '8. split coefficient': '1.0'}, '2021-09-16': {'1. open': '1.75', '2.  ...
