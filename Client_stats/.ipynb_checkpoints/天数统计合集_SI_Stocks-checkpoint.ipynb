# %%
import pandas as pd
import numpy as np
from datetime import datetime
from datetime import date
import matplotlib.pyplot as plt
import requests
pd.options.display.max_rows = 5000

# %%
pre = pd.read_csv(r'/Users/paxton615/Desktop/Stock_Price_csv/pre-2021-10.csv')
pre.drop('Unnamed: 0',axis=1, inplace=True)

# 

p2_date = '2020-01-01'
p2_price = 1.00
p2_wprice = 2.00

twenty_per_up = p2_price * (1+0.2)
thirty_per_up = p2_price * (1+0.3)
fourty_per_up = p2_price * (1+0.4)
fifty_per_up = p2_price * (1+0.5)

pre_p1 = pre[pre['pre_dates']>=p2_date]
pre_p1 = pre_p1[::-1].reset_index(drop=True)

# ----------------------------------------------------------

trade_high = pre_p1['pre_close'].max()
trade_high_date = (pre_p1.loc[pre_p1['pre_close']==pre_p1['pre_close'].max(), 'pre_dates'].item())
highest_rtn = (pre_p1['pre_close'].max()- p2_price + pre_p1['pre_close'].max() - p2_wprice)/p2_price


pre_p1_df = pd.DataFrame({'placing':'pre_p1', 'trade_high':trade_high, 'trade_high_date':trade_high_date, 'highest_rtn':highest_rtn},index=[0])


pre_p1_df['wprice_bar'] = (p2_wprice-p2_price)/p2_price 
pre_p1_df['over_w_days'] = len(pre_p1[pre_p1['pre_close']>= p2_wprice])

pre_p1_df['all_trade_days'] = len(pre_p1.pre_close)
pre_p1_df['20%up_days'] = len(pre_p1[pre_p1['pre_close']>= twenty_per_up].pre_close)
pre_p1_df['30%up_days'] = len(pre_p1[pre_p1['pre_close']>= thirty_per_up].pre_close)
pre_p1_df['40%up_days'] = len(pre_p1[pre_p1['pre_close']>= fourty_per_up].pre_close)
pre_p1_df['50%up_days'] = len(pre_p1[pre_p1['pre_close']>= fifty_per_up].pre_close)
pre_p1_df['200%up_days'] = len(pre_p1[pre_p1['pre_close']>= p2_price*2].pre_close)
pre_p1_df['300%up_days'] = len(pre_p1[pre_p1['pre_close']>= p2_price*3].pre_close)
pre_p1_df['400%up_days'] = len(pre_p1[pre_p1['pre_close']>= p2_price*4].pre_close)
pre_p1_df['500%up_days'] = len(pre_p1[pre_p1['pre_close']>= p2_price*5].pre_close)
pre_p1_df['600%up_days'] = len(pre_p1[pre_p1['pre_close']>= p2_price*6].pre_close)
pre_p1_df['700%up_days'] = len(pre_p1[pre_p1['pre_close']>= p2_price*7].pre_close)
pre_p1_df['800%up_days'] = len(pre_p1[pre_p1['pre_close']>= p2_price*8].pre_close)
pre_p1_df['900%up_days'] = len(pre_p1[pre_p1['pre_close']>= p2_price*9].pre_close)

def first_profit_day(column, target_price, profit_percentage):
    count = 0
    for i in column:
        if i < target_price:
            count += 1
        if i > target_price:
            break
            
first_profit_day(pre_p1['pre_close'], p2_price, '0%+')
first_profit_day(pre_p1['pre_close'], twenty_per_up, '20%')
first_profit_day(pre_p1['pre_close'], thirty_per_up, '30%')
first_profit_day(pre_p1['pre_close'], fourty_per_up, '40%')
first_profit_day(pre_p1['pre_close'], fifty_per_up, '50%')


def first_profit_day_number(column, target_price):
    count = 0
    for i in column:
        if i < target_price:
            count += 1
        if i > target_price:
            break
    return count

pre_p1_df['0_to_0%+'] = first_profit_day_number(pre_p1['pre_close'], p2_price)
pre_p1_df['0_to_20%+'] = first_profit_day_number(pre_p1['pre_close'], twenty_per_up)
pre_p1_df['0_to_30%+'] = first_profit_day_number(pre_p1['pre_close'], thirty_per_up)
pre_p1_df['0_to_40%+'] = first_profit_day_number(pre_p1['pre_close'], fourty_per_up)
pre_p1_df['0_to_50%+'] = first_profit_day_number(pre_p1['pre_close'], fifty_per_up)

pre_p1_df
# Out:
#   placing  trade_high trade_high_date  highest_rtn  wprice_bar  over_w_days  \
# 0  pre_p1       205.0      2021-03-15        407.0         1.0          324
#
#    all_trade_days  20%up_days  30%up_days  40%up_days  ...  500%up_days  \
# 0             324         324         324         324  ...          324
#
#    600%up_days  700%up_days  800%up_days  900%up_days  0_to_0%+  0_to_20%+  \
# 0          324          324          324          324         0          0
#
#    0_to_30%+  0_to_40%+  0_to_50%+
# 0          0          0          0
#
# [1 rows x 24 columns]

# %%
cobr = pd.read_csv(r'/Users/paxton615/Desktop/Stock_Price_csv/cobr-2021-10.csv')
cobr.drop('Unnamed: 0',axis=1, inplace=True)             #换CSV

# ----------------------------------------------------------

p2_date = '2020-09-01' #换
p2_price = 2.30      #换
p2_wprice = 3.00       #换

twenty_per_up = p2_price * (1+0.2)
thirty_per_up = p2_price * (1+0.3)
fourty_per_up = p2_price * (1+0.4)
fifty_per_up = p2_price * (1+0.5)

cobr_p2 = cobr[cobr['cobr_dates']>=p2_date]
cobr_p2 = cobr_p2[::-1].reset_index(drop=True)

# ----------------------------------------------------------

trade_high = cobr_p2['cobr_close'].max()
trade_high_date = (cobr_p2.loc[cobr_p2['cobr_close']==cobr_p2['cobr_close'].max(), 'cobr_dates'].item())
highest_rtn = (cobr_p2['cobr_close'].max()- p2_price + cobr_p2['cobr_close'].max() - p2_wprice)/p2_price


cobr_p2_df = pd.DataFrame({'placing':'cobr_p2', 'trade_high':trade_high, 'trade_high_date':trade_high_date, 'highest_rtn':highest_rtn},index=[0])


cobr_p2_df['wprice_bar'] = (p2_wprice-p2_price)/p2_price 
cobr_p2_df['over_w_days'] = len(cobr_p2[cobr_p2['cobr_close']>= p2_wprice])

cobr_p2_df['all_trade_days'] = len(cobr_p2.cobr_close)
cobr_p2_df['20%up_days'] = len(cobr_p2[cobr_p2['cobr_close']>= twenty_per_up].cobr_close)
cobr_p2_df['30%up_days'] = len(cobr_p2[cobr_p2['cobr_close']>= thirty_per_up].cobr_close)
cobr_p2_df['40%up_days'] = len(cobr_p2[cobr_p2['cobr_close']>= fourty_per_up].cobr_close)
cobr_p2_df['50%up_days'] = len(cobr_p2[cobr_p2['cobr_close']>= fifty_per_up].cobr_close)
cobr_p2_df['200%up_days'] = len(cobr_p2[cobr_p2['cobr_close']>= p2_price*2].cobr_close)
cobr_p2_df['300%up_days'] = len(cobr_p2[cobr_p2['cobr_close']>= p2_price*3].cobr_close)
cobr_p2_df['400%up_days'] = len(cobr_p2[cobr_p2['cobr_close']>= p2_price*4].cobr_close)
cobr_p2_df['500%up_days'] = len(cobr_p2[cobr_p2['cobr_close']>= p2_price*5].cobr_close)
cobr_p2_df['600%up_days'] = len(cobr_p2[cobr_p2['cobr_close']>= p2_price*6].cobr_close)
cobr_p2_df['700%up_days'] = len(cobr_p2[cobr_p2['cobr_close']>= p2_price*7].cobr_close)
cobr_p2_df['800%up_days'] = len(cobr_p2[cobr_p2['cobr_close']>= p2_price*8].cobr_close)
cobr_p2_df['900%up_days'] = len(cobr_p2[cobr_p2['cobr_close']>= p2_price*9].cobr_close)

def first_profit_day(column, target_price, profit_percentage):
    count = 0
    for i in column:
        if i < target_price:
            count += 1
        if i > target_price:
            break
            
first_profit_day(cobr_p2['cobr_close'], p2_price, '0%+')
first_profit_day(cobr_p2['cobr_close'], twenty_per_up, '20%')
first_profit_day(cobr_p2['cobr_close'], thirty_per_up, '30%')
first_profit_day(cobr_p2['cobr_close'], fourty_per_up, '40%')
first_profit_day(cobr_p2['cobr_close'], fifty_per_up, '50%')


def first_profit_day_number(column, target_price):
    count = 0
    for i in column:
        if i < target_price:
            count += 1
        if i > target_price:
            break
    return count

cobr_p2_df['0_to_0%+'] = first_profit_day_number(cobr_p2['cobr_close'], p2_price)
cobr_p2_df['0_to_20%+'] = first_profit_day_number(cobr_p2['cobr_close'], twenty_per_up)
cobr_p2_df['0_to_30%+'] = first_profit_day_number(cobr_p2['cobr_close'], thirty_per_up)
cobr_p2_df['0_to_40%+'] = first_profit_day_number(cobr_p2['cobr_close'], fourty_per_up)
cobr_p2_df['0_to_50%+'] = first_profit_day_number(cobr_p2['cobr_close'], fifty_per_up)

cobr_p2_df
# Out:
#    placing  trade_high trade_high_date  highest_rtn  wprice_bar  over_w_days  \
# 0  cobr_p2         3.5      2020-10-20      0.73913    0.304348           24
#
#    all_trade_days  20%up_days  30%up_days  40%up_days  ...  500%up_days  \
# 0             284          43          24           7  ...            0
#
#    600%up_days  700%up_days  800%up_days  900%up_days  0_to_0%+  0_to_20%+  \
# 0            0            0            0            0         8         34
#
#    0_to_30%+  0_to_40%+  0_to_50%+
# 0         34         35         35
#
# [1 rows x 24 columns]

# %%
pre = pd.read_csv(r'/Users/paxton615/Desktop/Stock_Price_csv/pre-2021-10.csv')
pre.drop('Unnamed: 0',axis=1, inplace=True)

# 

p1_date = '2021-06-01'
p1_price = 120.00
p1_wprice = 0.00

twenty_per_up = p1_price * (1+0.2)
thirty_per_up = p1_price * (1+0.3)
fourty_per_up = p1_price * (1+0.4)
fifty_per_up = p1_price * (1+0.5)

pre_p1 = pre[pre['pre_dates']>=p1_date]
pre_p1 = pre_p1[::-1].reset_index(drop=True)

# ----------------------------------------------------------

trade_high = pre_p1['pre_close'].max()
trade_high_date = (pre_p1.loc[pre_p1['pre_close']==pre_p1['pre_close'].max(), 'pre_dates'].item())
highest_rtn = (pre_p1['pre_close'].max()- p1_price + pre_p1['pre_close'].max() - p1_wprice)/p1_price


pre_p1_df = pd.DataFrame({'placing':'pre_p1', 'trade_high':trade_high, 'trade_high_date':trade_high_date, 'highest_rtn':highest_rtn},index=[0])


pre_p1_df['wprice_bar'] = (p1_wprice-p1_price)/p1_price 
pre_p1_df['over_w_days'] = len(pre_p1[pre_p1['pre_close']>= p1_wprice])

pre_p1_df['all_trade_days'] = len(pre_p1.pre_close)
pre_p1_df['20%up_days'] = len(pre_p1[pre_p1['pre_close']>= twenty_per_up].pre_close)
pre_p1_df['30%up_days'] = len(pre_p1[pre_p1['pre_close']>= thirty_per_up].pre_close)
pre_p1_df['40%up_days'] = len(pre_p1[pre_p1['pre_close']>= fourty_per_up].pre_close)
pre_p1_df['50%up_days'] = len(pre_p1[pre_p1['pre_close']>= fifty_per_up].pre_close)
pre_p1_df['200%up_days'] = len(pre_p1[pre_p1['pre_close']>= p1_price*2].pre_close)
pre_p1_df['300%up_days'] = len(pre_p1[pre_p1['pre_close']>= p1_price*3].pre_close)
pre_p1_df['400%up_days'] = len(pre_p1[pre_p1['pre_close']>= p1_price*4].pre_close)
pre_p1_df['500%up_days'] = len(pre_p1[pre_p1['pre_close']>= p1_price*5].pre_close)
pre_p1_df['600%up_days'] = len(pre_p1[pre_p1['pre_close']>= p1_price*6].pre_close)
pre_p1_df['700%up_days'] = len(pre_p1[pre_p1['pre_close']>= p1_price*7].pre_close)
pre_p1_df['800%up_days'] = len(pre_p1[pre_p1['pre_close']>= p1_price*8].pre_close)
pre_p1_df['900%up_days'] = len(pre_p1[pre_p1['pre_close']>= p1_price*9].pre_close)

def first_profit_day(column, target_price, profit_percentage):
    count = 0
    for i in column:
        if i < target_price:
            count += 1
        if i > target_price:
            break
            
first_profit_day(pre_p1['pre_close'], p1_price, '0%+')
first_profit_day(pre_p1['pre_close'], twenty_per_up, '20%')
first_profit_day(pre_p1['pre_close'], thirty_per_up, '30%')
first_profit_day(pre_p1['pre_close'], fourty_per_up, '40%')
first_profit_day(pre_p1['pre_close'], fifty_per_up, '50%')


def first_profit_day_number(column, target_price):
    count = 0
    for i in column:
        if i < target_price:
            count += 1
        if i > target_price:
            break
    return count

pre_p1_df['0_to_0%+'] = first_profit_day_number(pre_p1['pre_close'], p1_price)
pre_p1_df['0_to_20%+'] = first_profit_day_number(pre_p1['pre_close'], twenty_per_up)
pre_p1_df['0_to_30%+'] = first_profit_day_number(pre_p1['pre_close'], thirty_per_up)
pre_p1_df['0_to_40%+'] = first_profit_day_number(pre_p1['pre_close'], fourty_per_up)
pre_p1_df['0_to_50%+'] = first_profit_day_number(pre_p1['pre_close'], fifty_per_up)

pre_p1_df
# Out:
#   placing  trade_high trade_high_date  highest_rtn  wprice_bar  over_w_days  \
# 0  pre_p1       129.0      2021-06-11         1.15        -1.0           96
#
#    all_trade_days  20%up_days  30%up_days  40%up_days  ...  500%up_days  \
# 0              96           0           0           0  ...            0
#
#    600%up_days  700%up_days  800%up_days  900%up_days  0_to_0%+  0_to_20%+  \
# 0            0            0            0            0         7         96
#
#    0_to_30%+  0_to_40%+  0_to_50%+
# 0         96         96         96
#
# [1 rows x 24 columns]
