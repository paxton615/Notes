# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
 pd.set_option('display.float_format', lambda x: '%.3f' % x)

# %%
pensana_book = pd.read_excel(r'/Users/paxton615/Github_Personal/Notes/Notes/Client_stats/Pensana_book_data.xlsx')

# %%
pensana = pensana_book

# %%
pensana.columns = ['ref', 'name', 'consideration','shares_gross', 'shares_net']

# %%
pensana.head(3)
# Out:
#   ref                   name  consideration  shares_gross  shares_net
# 0   -  Clear Capital markets        1881900   1568250.000     1568250
# 1   -   Axis Capital markets         168000    140000.000      140000
# 2   -             Omar Ahmed         100000     83333.333       83333

# %%
pensana[['shares_gross','consideration']].describe()
# Out:
#        shares_gross  consideration
# count       112.000        112.000
# mean     100446.429     120535.714
# std      289995.737     347994.884
# min        4166.667       5000.000
# 25%        8333.333      10000.000
# 50%       20833.333      25000.000
# 75%       43750.000      52500.000
# max     2299583.333    2759500.000

# %%
pensana.plot(figsize=(25,10), x='name', y='consideration', kind='bar', rot=90);

# %%
pensana_normal = pensana.loc[pensana['consideration']<200000]

# %%
pensana_normal.plot(figsize=(25,10), x='name', y='consideration', kind='bar', rot=90);

# %%
print(len(pensana.consideration))
print(len(pensana_normal.consideration))
# Out:
# 112
# 98

# %%
pensana.describe()
# Out:
#        consideration  shares_gross  shares_net
# count        112.000       112.000     112.000
# mean      120535.714    100446.429  100446.429
# std       347994.884    289995.737  289995.725
# min         5000.000      4166.667    4166.000
# 25%        10000.000      8333.333    8333.000
# 50%        25000.000     20833.333   20833.000
# 75%        52500.000     43750.000   43750.250
# max      2759500.000   2299583.333 2299583.000

# %%
pensana_normal.describe()
# Out:
#        consideration  shares_gross  shares_net
# count         98.000        98.000      98.000
# mean       31546.939     26289.116   26289.102
# std        34714.973     28929.144   28929.150
# min         5000.000      4166.667    4166.000
# 25%        10000.000      8333.333    8333.000
# 50%        20000.000     16666.667   16667.000
# 75%        40000.000     33333.333   33333.000
# max       168000.000    140000.000  140000.000

# %%
pensana.consideration.hist(figsize=(12,5),bins=30,);

# %%
pensana_normal.consideration.hist(figsize=(12,5),bins=30,);

# %% [markdown]
# - less than 10k

# %%
pensana[pensana['consideration']<=10000].consideration.count()
# Out:
# 40

# %% [markdown]
# - between 10k to 20k

# %%
pensana[(pensana['consideration']>10000)&(pensana['consideration']<=20000)].consideration.count()
# Out:
# 14

# %% [markdown]
# - between 20k to 100k

# %%
pensana[(pensana['consideration']>20000)&(pensana['consideration']<=100000)].consideration.count()
# Out:
# 40

# %% [markdown]
# - over 100k

# %%
pensana[pensana['consideration']>100000].consideration.count()
# Out:
# 18

# %%
pensana[pensana['consideration']<=10000].describe()
# Out:
#        consideration  shares_gross  shares_net
# count         40.000        40.000      40.000
# mean        7750.000      6458.333    6458.275
# std         2457.328      2047.773    2047.500
# min         5000.000      4166.667    4166.000
# 25%         5000.000      4166.667    4167.000
# 50%        10000.000      8333.333    8333.000
# 75%        10000.000      8333.333    8333.000
# max        10000.000      8333.333    8333.000

# %%
pensana[(pensana['consideration']>20000)&(pensana['consideration']<=100000)].describe()
# Out:
#        consideration  shares_gross  shares_net
# count         40.000        40.000      40.000
# mean       49340.000     41116.667   41116.600
# std        25816.481     21513.734   21513.706
# min        21600.000     18000.000   18000.000
# 25%        26500.000     22083.333   22083.250
# 50%        40000.000     33333.333   33333.500
# 75%        52500.000     43750.000   43750.250
# max       100000.000     83333.333   83333.000
