# %%
# !pwd
# Out:
# /Users/paxton615/Github_Personal/Notes/Notes/Client_stats

# %%
import pandas as pd
import numpy as np

# %%
amte = pd.read_excel(r'/Users/paxton615/Github_Personal/Notes/Notes/Client_stats/AMTE_book_data.xlsx')

# %%
amte.columns = ['name', 'jarvis', 'sedol', 'quantity', 'price', 'consideration', 'comm', 'additional', 'total_req']

# %%
amte.head(10)
# Out:
#               name  jarvis    sedol  quantity  price  consideration     comm  \
# 0       SI Capital  363220  BNQRZZ5  134286.0    175      235000.00        -
# 1    Simon Philpot  365876  BNQRZZ5  128571.0    175      225000.00     6750
# 2    David Bennett  404401  BNQRZZ5   42857.0    175       75000.00      375
# 3       Simon Snow  370253  BNQRZZ5   41143.0    175       72000.00     2160
# 4  Adrian Crucefix  370357  BNQRZZ5   38571.0    175       67498.75  674.988
# 5  Alan Witzenfeld  395986  BNQRZZ5   32143.0    175       56250.00   1687.5
# 6     Philip Small  396168  BNQRZZ5   32143.0    175       56250.00       25
# 7      Paul Martin  377322  BNQRZZ5   30858.0    175       54000.00     1620
# 8     SRL Property  400385  BNQRZZ5   28571.0    175       50000.00     1500
# 9    Phil Williams  381371  BNQRZZ5   22857.0    175       40000.00     1200
#
#   additional    total_req
# 0          -  255000.0000
# 1         10  231760.0000
# 2         10   75385.0000
# 3         10   74170.0000
# 4         10   68183.7375
# 5         10   57947.5000
# 6         10   56285.0000
# 7         10   55630.0000
# 8         10   51510.0000
# 9         10   41210.0000

# %%
amte[['quantity','consideration']].describe()
# Out:
#             quantity  consideration
# count     150.000000     150.000000
# mean     8829.524733   15451.658333
# std     16512.284680   28896.427604
# min       571.000000    1000.000000
# 25%      1749.750000    3062.500000
# 50%      4285.500000    7500.000000
# 75%      8572.000000   15000.000000
# max    134286.000000  235000.000000

# %%
amte.plot(figsize=(30,10), x='name', y='consideration', kind='bar', rot=90);
