# %%
# 导入pytesseract包
import pytesseract

# %%
#从 Python Image Library中导入 Image 包
from PIL import Image

# %%
# 通过pytesseract 调取 tesseract_cmd（就是去找到tesseract.exe 所在的目录）
pytesseract.pytesseract.tesseract_cmd = r'/usr/local/Cellar/tesseract/4.1.1/bin/tesseract'

# %%
# 将png 中的文字变成 txt 格式
print(pytesseract.image_to_string(r'/Users/paxton615/Desktop/ref_letter.png'))
# Out:
# {SENDER'S NAME]
#
# {SENDER'S ADDRESS]
# {SENDER'S CONTACT NUMBER]
# [SENDER'S EMAIL ADDRESS]
#
# (DATE]
#
# {RECIPIENT'S NAME]
#
# Office of the Registrar
#
# (NAME OF THE GRADUATE SCHOOL]
# [ADDRESS]
#
# Dear Mr./Ms.
#
# I highly recommend [NAME OF THE CANDIDATE] as a candidate for graduate school. |
# have worked with in my capacity as [POSITION] of the Department of
# [DEPARTMENT] at [NAME OF THE SCHOOL].
#
# While he/she was a student at the university, was able to maintain a GPA of
# [GPA] while taking a full load of classes as well as seminars. He/she is a consistent honor
# student, and while he/she was under me, he/she excelled as the top student. Other
# instructors and professors in the same department talk highly of his/her performance.
#
# In addition to him/her being a dedicated student, he/she also worked at in
# various job positions to help him/her with all the expenses.
#
# He/she does the tasks given to him/her with a positive attitude. He/she can establish
# ...

# %%
# print(pytesseract.image_to_string(r'/Users/paxton615/Downloads/TheEconomist.2020.11.19.pdf'))

# %%
ref_letter1 = pytesseract.image_to_string(r'/Users/paxton615/Desktop/JPG_app_files/BTBU_certificate_bachelor_degree.jpg')

# %%
print(ref_letter1)
# Out:
#
#
#
#
# @wkezGE wees
# SS , Zl a 33 Fucheng Road
# ae Y 3) Beijing, China
#
# BEIJING TECHNOLOGY AND BUSINESS UNIVERSITY Post Code: 100048
#
# CERTIFICATE OF BACHELOR’S DEGREE
# (Translation)
#
# Peng Ge, male , bom in June , 1984, studied Intemational Economics & Trade
# in Economics School of Beijing Technology and Business University from
# September, 2003 to March, 2008. He completed the four-year course stipulated
# by teaching program, and was approved to graduate from the university. Having
# been verified, it conforms to “Regulations on Academic Degree of the People’s
# Republic of China”. He is conferred upon the Degree of Bachelor of Economics.
#
# Beijing Technology and Business University

# %%
print(pytesseract.image_to_string(r'/Users/paxton615/Desktop/JPG_app_files/BTBU_certificate_bachelor_degree.jpg'))
# Out:
#
#
#
#
# @wkezGE wees
# SS , Zl a 33 Fucheng Road
# ae Y 3) Beijing, China
#
# BEIJING TECHNOLOGY AND BUSINESS UNIVERSITY Post Code: 100048
#
# CERTIFICATE OF BACHELOR’S DEGREE
# (Translation)
#
# Peng Ge, male , bom in June , 1984, studied Intemational Economics & Trade
# in Economics School of Beijing Technology and Business University from
# September, 2003 to March, 2008. He completed the four-year course stipulated
# by teaching program, and was approved to graduate from the university. Having
# been verified, it conforms to “Regulations on Academic Degree of the People’s
# Republic of China”. He is conferred upon the Degree of Bachelor of Economics.
#
# Beijing Technology and Business University

# %%
print(pytesseract.image_to_string(r'/Users/paxton615/Downloads/ Interview_preparation_GA/Interview infographic.jpg'))
# Out:
# What You Wish You’d Known Before Your
#
# RAY
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Common nonverbal Inasurveyof 2000 bosses 3 D/O
# mistakes made nfist 90 secondsof an interview
#
# whether they will
# hire someone
#
# at a job interview
#
# From a survey of 2000 bosses
#
# ie |
# 21% —
#
# Playing with hair or
# touching face
#
# 47%
#
# Having little or no
#
# Knowledge dt the Statistics show that
#
# tl st .
#
# oa, when meeting new
# people the impact is:
#
# seekers make during
# 7% ,
# (0. From what we actually say
#
# interviews
# The quality of our voice
#
# raceme 67%
# Lack of smile 38% 38% seammarond overall
#
# sstnane 33% 55% waist
#
# 21% \ 2
#
# Crossing arms over their chest
#
# =
#
# The average length of an interview is
# approximately 40 minutes
#
#
#
#
#
#
# Clothes
#
# Using too many hand gestures
# nmr 26% -\
# ee
# 33%
#
# Fidgeting too much
#
# Bright colors are a turnoff
# Employers claiming they
#
# — 70% don't want applicants to
#
# ...

# %%
with open("/Users/paxton615/Desktop/ref_letter1.txt", "w") as f:
    f.write(ref_letter1)

# %%
import PyPDF2

# %%
# pdf_file = open(r'/Users/paxton615/Downloads/General_Assembly_Certificate-of-Completion.pdf')
# read_pdf = PyPDF2.PdfFileReader(pdf_file)
# number_of_pages = read_pdf.getNumPages()
# page = read_pdf.getPage(0)
# page_content = page.extractText()
# print( page_content)

# %%
import textract

# %%
text = textract.process("/Users/paxton615/Downloads/General_Assembly_Certificate-of-Completion.pdf")

# %%
text
# Out:
# b'CERTIFICATE OF\nCOMPLETION\n\nOctober 04, 2019\n\nDear Paxton Peng,\n\nCongratulations on your successful completion of General\nAssembly\xc3\xa2\xe2\x82\xac\xe2\x84\xa2s Data Science course beginning on 24/06/2019 and\nending on 13/09/2019. Receipt of this email attachment can be\nused to confirm that you received 480 hours of instruction. \n\nIf you have any questions, please let me know. \n\nGood luck on your continued educational and professional\nadventures.\n\nSincerely,\n\nJulien Deslangles-Blanch\nRegional Director, UK & Germany\n\nGENERAL ASSEMBLY \nhttps://generalassemb.ly\n\n1 Commercial Street\nLondon E1 7PT, UK\n\n\x0c'

# %%
text1 = textract.process("/Users/paxton615/Downloads/TheEconomist20201119.pdf")

# %%
text1
# Out:
# b'\x0c\t\n\nThe\tworld\tthis\tweek\nLeaders\nLetters\nBriefing\nAsia\nChina\nUnited\tStates\nThe\tAmericas\nMiddle\tEast\t&\tAfrica\nEurope\nBritain\nInternational\nBusiness\nFinance\t&\teconomics\nScience\t&\ttechnology\nBooks\t&\tarts\nEconomic\t&\tfinancial\tindicators\nGraphic\tdetail\nObituary\n\n\x0cThe\tworld\tthis\tweek\n\n\t\n\nPolitics\tthis\tweek\nBusiness\tthis\tweek\nKAL\xe2\x80\x99s\tcartoon\n\n\x0cPolitics\tthis\tweek\n\nNov\t21st\t2020\t|\n\nGovernment\t forces\t in\t Ethiopia\t said\t they\t had\t captured\t key\t towns\t on\t the\t road\ntowards\tMekelle,\tthe\tcapital\tof\tthe\trebellious\tprovince\tof\tTigray.\tThe\tcivil\twar\nhas\t spilled\t across\t the\t border\t into\t Eritrea\t and\t led\t to\t an\t ethnic\t massacre.\t The\ngovernment\t has\t resisted\t calls\t for\t talks\t or\t mediation.\t Tens\t of\t thousands\t of\nrefugees\thave\tfled\tinto\tSudan.\tSee\tarticle.\n\nRussia\t said\t it\t would\t build\t a\t naval\t base\t in\t Sudan,\t adding\t to\t a\
# ...
