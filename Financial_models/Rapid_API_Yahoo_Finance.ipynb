# %%
import requests

url = "https://apidojo-yahoo-finance-v1.p.rapidapi.com/auto-complete"

querystring = {"q":"sbry","region":"Uk"}

headers = {
    'x-rapidapi-key': "9cd97ba3camsh244cbd2e3e420a4p1e83c0jsne0fdd0787f8e",
    'x-rapidapi-host': "apidojo-yahoo-finance-v1.p.rapidapi.com"
    }

response = requests.request("GET", url, headers=headers, params=querystring)

print(response.text)
# Out:
# {"explains":[],"count":9,"quotes":[{"exchange":"LSE","shortname":"SAINSBURY (J) PLC ORD 28 4/7P","quoteType":"EQUITY","symbol":"SBRY.L","index":"quotes","score":20320.0,"typeDisp":"Equity","longname":"J Sainsbury plc","exchDisp":"London","isYahooFinance":true}],"news":[{"uuid":"9839eeb8-5f9d-3824-b814-9802f52dbc0e","title":"BT shares skid on report Sky may back rival fiber investment","publisher":"MarketWatch","link":"https://finance.yahoo.com/m/9839eeb8-5f9d-3824-b814-9802f52dbc0e/bt-shares-skid-on-report-sky.html","providerPublishTime":1633347360,"type":"STORY"},{"uuid":"4538967a-1134-3dd8-9b7e-fb5690580e63","title":"Sainsbury Soars on Report of PE Firms' Interest in Buyout","publisher":"Investing.com","link":"https://finance.yahoo.com/news/sainsbury-soars-report-pe-firms-055314040.html","providerPublishTime":1629697994,"type":"STORY"},{"uuid":"13304c7e-7512-3bb3-878a-246f0a84b00e","title":"Sainsbury shares slump as UBS interprets Apollo interest as ‘exploratory’","publisher":"Mark
# ...

# %%
import http.client

conn = http.client.HTTPSConnection("apidojo-yahoo-finance-v1.p.rapidapi.com")

headers = {
    'x-rapidapi-key': "9cd97ba3camsh244cbd2e3e420a4p1e83c0jsne0fdd0787f8e",
    'x-rapidapi-host': "apidojo-yahoo-finance-v1.p.rapidapi.com"
    }

conn.request("GET", "/auto-complete?q=sbry&region=UK", headers=headers)

res = conn.getresponse()
data = res.read()

print(data.decode("utf-8"))
# Out:
# {"explains":[],"count":9,"quotes":[{"exchange":"LSE","shortname":"SAINSBURY (J) PLC ORD 28 4/7P","quoteType":"EQUITY","symbol":"SBRY.L","index":"quotes","score":20320.0,"typeDisp":"Equity","longname":"J Sainsbury plc","exchDisp":"London","isYahooFinance":true}],"news":[{"uuid":"9839eeb8-5f9d-3824-b814-9802f52dbc0e","title":"BT shares skid on report Sky may back rival fiber investment","publisher":"MarketWatch","link":"https://finance.yahoo.com/m/9839eeb8-5f9d-3824-b814-9802f52dbc0e/bt-shares-skid-on-report-sky.html","providerPublishTime":1633347360,"type":"STORY"},{"uuid":"4538967a-1134-3dd8-9b7e-fb5690580e63","title":"Sainsbury Soars on Report of PE Firms' Interest in Buyout","publisher":"Investing.com","link":"https://finance.yahoo.com/news/sainsbury-soars-report-pe-firms-055314040.html","providerPublishTime":1629697994,"type":"STORY"},{"uuid":"13304c7e-7512-3bb3-878a-246f0a84b00e","title":"Sainsbury shares slump as UBS interprets Apollo interest as ‘exploratory’","publisher":"Mark
# ...

# %% [markdown]
# ### get-chart只给我当天的数据，虽然可以选分钟或小时显示，但还不知道如何获得更多历史数据。

# %%
import requests

url = "https://apidojo-yahoo-finance-v1.p.rapidapi.com/stock/v2/get-chart"

querystring = {"interval":"1m","symbol":"SBRY.L", "region":"Uk"}

headers = {
    'x-rapidapi-key': "9cd97ba3camsh244cbd2e3e420a4p1e83c0jsne0fdd0787f8e",
    'x-rapidapi-host': "apidojo-yahoo-finance-v1.p.rapidapi.com"
    }

response = requests.request("GET", url, headers=headers, params=querystring)

print(response.text)
# Out:
# {"chart":{"result":[{"meta":{"currency":"GBp","symbol":"SBRY.L","exchangeName":"LSE","instrumentType":"EQUITY","firstTradeDate":583743600,"regularMarketTime":1616423186,"gmtoffset":0,"timezone":"GMT","exchangeTimezoneName":"Europe/London","regularMarketPrice":242.7,"chartPreviousClose":244.8,"previousClose":244.8,"scale":3,"priceHint":2,"currentTradingPeriod":{"pre":{"timezone":"GMT","start":1616397300,"end":1616400000,"gmtoffset":0},"regular":{"timezone":"GMT","start":1616400000,"end":1616430600,"gmtoffset":0},"post":{"timezone":"GMT","start":1616430600,"end":1616433300,"gmtoffset":0}},"tradingPeriods":{"pre":[[{"timezone":"GMT","start":1616397300,"end":1616400000,"gmtoffset":0}]],"post":[[{"timezone":"GMT","start":1616430600,"end":1616433300,"gmtoffset":0}]],"regular":[[{"timezone":"GMT","start":1616400000,"end":1616430600,"gmtoffset":0}]]},"dataGranularity":"1m","range":"1d","validRanges":["1d","5d","1mo","3mo","6mo","1y","2y","5y","10y","ytd","max"]},"timestamp":[1616400000,16164
# ...

# %%
data = response.text

# type(data)

# print(len(data.split("}")))
# print(data.split("}")) # 用“}”将整个text变成包含15个parts的list

nine = data.split("}")
# seperate the big text in 15 segments with "}"，make it into a list

ten = nine[9].split(":") #截取timestamp - high整个这一大块儿
# len(ten)

# print(ten[0], ten[1]) 

eleven = ten[1].split(",")
# print(eleven) # this is the timestamp's content

twelve = eleven[0:-1]
# print(twelve)

thirteen = []
for i in twelve:
    thirteen.append(i.replace(r"[","").replace(r"]","")) 
# print(thirteen)

timestamp = []
import datetime
for i in thirteen:
    timestamp.append(datetime.datetime.fromtimestamp(int(i)).isoformat())
    
print(timestamp)
# Out:
# ['2021-03-22T08:00:00', '2021-03-22T08:01:00', '2021-03-22T08:02:00', '2021-03-22T08:03:00', '2021-03-22T08:04:00', '2021-03-22T08:05:00', '2021-03-22T08:06:00', '2021-03-22T08:07:00', '2021-03-22T08:08:00', '2021-03-22T08:09:00', '2021-03-22T08:10:00', '2021-03-22T08:11:00', '2021-03-22T08:12:00', '2021-03-22T08:13:00', '2021-03-22T08:14:00', '2021-03-22T08:15:00', '2021-03-22T08:16:00', '2021-03-22T08:17:00', '2021-03-22T08:18:00', '2021-03-22T08:19:00', '2021-03-22T08:20:00', '2021-03-22T08:21:00', '2021-03-22T08:22:00', '2021-03-22T08:23:00', '2021-03-22T08:24:00', '2021-03-22T08:25:00', '2021-03-22T08:26:00', '2021-03-22T08:27:00', '2021-03-22T08:28:00', '2021-03-22T08:29:00', '2021-03-22T08:30:00', '2021-03-22T08:31:00', '2021-03-22T08:32:00', '2021-03-22T08:33:00', '2021-03-22T08:34:00', '2021-03-22T08:35:00', '2021-03-22T08:36:00', '2021-03-22T08:37:00', '2021-03-22T08:38:00', '2021-03-22T08:39:00', '2021-03-22T08:40:00', '2021-03-22T08:41:00', '2021-03-22T08:42:00', '2021-03
# ...

# %%
datetime.datetime.fromtimestamp(1616160600).isoformat()
# Out:
# '2021-03-19T13:30:00'

# %%
import requests

url = "https://apidojo-yahoo-finance-v1.p.rapidapi.com/stock/v3/get-historical-data"

querystring = {"symbol":"AAPL","period2":"1571590800","period1":"493578000","region":"US"}

headers = {
    'x-rapidapi-key': "9cd97ba3camsh244cbd2e3e420a4p1e83c0jsne0fdd0787f8e",
    'x-rapidapi-host': "apidojo-yahoo-finance-v1.p.rapidapi.com"
    }

response = requests.request("GET", url, headers=headers, params=querystring)

print(response.text)
# Out:
# {"prices":[{"date":1616422004,"open":120.33000183105469,"high":121.9800033569336,"low":120.26000213623047,"close":121.8949966430664,"volume":18264075,"adjclose":121.8949966430664},{"date":1616160600,"open":119.9000015258789,"high":121.43000030517578,"low":119.68000030517578,"close":119.98999786376953,"volume":185023200,"adjclose":119.98999786376953},{"date":1616074200,"open":122.87999725341797,"high":123.18000030517578,"low":120.31999969482422,"close":120.52999877929688,"volume":121229700,"adjclose":120.52999877929688},{"date":1615987800,"open":124.05000305175781,"high":125.86000061035156,"low":122.33999633789062,"close":124.76000213623047,"volume":111437500,"adjclose":124.76000213623047},{"date":1615901400,"open":125.69999694824219,"high":127.22000122070312,"low":124.72000122070312,"close":125.56999969482422,"volume":114740000,"adjclose":125.56999969482422},{"date":1615815000,"open":121.41000366210938,"high":124,"low":120.41999816894531,"close":123.98999786376953,"volume":92403800,"
# ...

# %%
datetime.datetime.fromtimestamp(1596807000).isoformat()
# Out:
# '2020-08-07T14:30:00'

# %%
datetime.datetime.fromtimestamp(1616422004).isoformat()
# Out:
# '2021-03-22T14:06:44'

# %%
datetime.datetime.fromtimestamp(1571590800).isoformat()
# Out:
# '2019-10-20T18:00:00'

# %%
import requests

url = "https://apidojo-yahoo-finance-v1.p.rapidapi.com/stock/v2/get-insights"

querystring = {"symbol":"AAPL"}

headers = {
    'x-rapidapi-key': "9cd97ba3camsh244cbd2e3e420a4p1e83c0jsne0fdd0787f8e",
    'x-rapidapi-host': "apidojo-yahoo-finance-v1.p.rapidapi.com"
    }

response = requests.request("GET", url, headers=headers, params=querystring)

print(response.text)
# Out:
# {"finance":{"result":{"symbol":"AAPL","instrumentInfo":{"technicalEvents":{"provider":"Trading Central","shortTerm":"NONE","midTerm":"down","longTerm":"NONE"},"keyTechnicals":{"provider":"Trading Central","support":50.585,"resistance":120.88,"stopLoss":112.97484},"valuation":{"color":0.0,"description":"Overvalued","discount":"13%","relativeValue":"Premium","provider":"Trading Central"},"recommendation":{"targetPrice":165.0,"provider":"Argus Research","rating":"BUY"}},"reports":[{"id":"ARGUS_29377_ThematicPortfolio_1615806071000","title":"The Argus Innovation Model Portfolio","provider":"Argus Research","publishedOn":"2021-03-15T11:01:11Z","summary":"The United States economy is full of innovation. It has to be. Manufacturing industries that dominated the economy decades ago - textiles, televisions, even automobiles, to a large degree - have moved overseas, where costs are lower. Yet the U.S. economy, prior to the pandemic, had expanded to record levels. And now, the U.S. Healthcare i
# ...

# %%
import requests

url = "https://apidojo-yahoo-finance-v1.p.rapidapi.com/news/list" #获取当天yahoo所有的商业金融新闻 

querystring = {"category":"generalnews","region":"UK"}

headers = {
    'x-rapidapi-key': "9cd97ba3camsh244cbd2e3e420a4p1e83c0jsne0fdd0787f8e",
    'x-rapidapi-host': "apidojo-yahoo-finance-v1.p.rapidapi.com"
    }

response = requests.request("GET", url, headers=headers, params=querystring)

print(response.text)
# Out:
# {"items":{"result":[{"uuid":"6c1bffc9-3489-4b0a-9d93-f5e5968bd42c","title":"Stock market news live updates: Stocks mixed, tech stocks rebound as Treasury yields retreat","link":"https://finance.yahoo.com/news/stock-market-news-live-updates-march-22-2021-110753903.html","summary":"Stock traded mixed on Monday, with technology stocks looking to recover some of last week's declines.","publisher":"Yahoo Finance","author":"Emily McCormick","type":"story","entities":[{"term":"TICKER:BTC-USD","label":"Bitcoin USD","score":1.0},{"term":"TICKER:ES=F","label":"E-Mini S&P 500 Mar 21","score":1.0},{"term":"TICKER:NQ=F","label":"Nasdaq 100 Mar 21","score":1.0},{"term":"TICKER:QQQ","label":"Invesco QQQ Trust, Series 1","score":1.0},{"term":"TICKER:^DJI","label":"Dow Jones Industrial Average","score":1.0},{"term":"TICKER:^IXIC","label":"NASDAQ Composite","score":1.0}],"offnet":false,"content":"<a href=\"https://finance.yahoo.com/quote/NKLA\" target=\"_self\">undefined</a> \n<p>Stock traded mixed on
# ...

# %%
from bs4 import BeautifulSoup

# %%
content = BeautifulSoup(response.text, 'html.parser')

# %%
print(content.prettify())
# Out:
# {"items":{"result":[{"uuid":"6c1bffc9-3489-4b0a-9d93-f5e5968bd42c","title":"Stock market news live updates: Stocks mixed, tech stocks rebound as Treasury yields retreat","link":"https://finance.yahoo.com/news/stock-market-news-live-updates-march-22-2021-110753903.html","summary":"Stock traded mixed on Monday, with technology stocks looking to recover some of last week's declines.","publisher":"Yahoo Finance","author":"Emily McCormick","type":"story","entities":[{"term":"TICKER:BTC-USD","label":"Bitcoin USD","score":1.0},{"term":"TICKER:ES=F","label":"E-Mini S&amp;P 500 Mar 21","score":1.0},{"term":"TICKER:NQ=F","label":"Nasdaq 100 Mar 21","score":1.0},{"term":"TICKER:QQQ","label":"Invesco QQQ Trust, Series 1","score":1.0},{"term":"TICKER:^DJI","label":"Dow Jones Industrial Average","score":1.0},{"term":"TICKER:^IXIC","label":"NASDAQ Composite","score":1.0}],"offnet":false,"content":"
# <a href='\"https://finance.yahoo.com/quote/NKLA\"' target='\"_self\"'>
#  undefined
# </a>
# \n
# ...
