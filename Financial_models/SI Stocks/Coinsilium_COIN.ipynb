# %%
import pandas as pd, seaborn as sns, matplotlib.pyplot as plt
import numpy as np
import yfinance as yf
from datetime import datetime
# %config IPCompleter.greedy=True
# %config InlineBackend.figure_format = 'retina'
# %matplotlib inline
pd.options.display.max_rows = 5000 

import warnings
warnings.filterwarnings('ignore')

# %%
coin = yf.Ticker('coin.aq')
# coin_2020 = coin.history(start="2020-01-01", end= datetime.today().strftime('%Y-%m-%d'))
# print(coin_2020.shape)
# print(coin_2020.head())
# print(coin_2020.tail())

# %%
data = coin.history()

# %%
data
# Out:
#             Open  High  Low  Close  Volume  Dividends  Stock Splits
# Date
# 2021-05-21   7.0   7.5  7.0  7.375  238925          0             0

# %%
plt.figure(figsize=(12,6))
plt.scatter(data.index, data.Close )
plt.show()
