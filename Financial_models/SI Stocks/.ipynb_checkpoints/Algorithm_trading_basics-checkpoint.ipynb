# %%
import numpy as np
import pandas as pd
import yfinance as yf

# %%
pre_tick = yf.Ticker('pre.l')

# %%
pre_price = pre_tick.history()

# %%
pre_price = pre_tick.history(start='2001-01-01')

# %%
pre_price
# Out:
#              Open        High         Low  Close   Volume  Dividends  \
# Date
# 2020-07-06   17.5   32.000000   20.000000   27.0   119715          0
# 2020-07-07   26.0   29.600000   22.000000   24.0   398455          0
# 2020-07-08   24.0   24.959999   20.559999   21.0  5102822          0
# 2020-07-09   21.0   21.250000   20.000000   20.0   323101          0
# 2020-07-10   20.0   20.200001   19.820000   20.0   376333          0
# ...           ...         ...         ...    ...      ...        ...
# 2021-06-10  117.0  134.500000  114.500000  122.5  1235326          0
# 2021-06-11  126.0  129.000000  122.000000  129.0   357206          0
# 2021-06-14  130.0  130.000000  115.500000  116.0   282015          0
# 2021-06-15  115.0  124.324997  115.000000  119.5   114606          0
# 2021-06-16  121.5  122.000000  117.500000  120.5   115618          0
#
#             Stock Splits
# Date
# 2020-07-06             0
# 2020-07-07             0
# 2020-07-08             0
# 2020-07-09             0
# 2020-07-10             0
# ...                  ...
# 2021-06-10             0
# 2021-06-11             0
# 2021-06-14             0
# 2021-06-15             0
# 2021-06-16             0
#
# [240 rows x 7 columns]

# %%
pre_tick.info
# Out:
# {'zip': 'SW1Y 5NQ',
#  'sector': 'Basic Materials',
#  'longBusinessSummary': 'Pensana Plc explores for and develops mineral properties in Angola. The company primarily explores for rare earth metals, consisting of neodymium and praseodymium (NdPr) deposits. Its flagship asset is 84% owned Longonjo NdPr Project located in Angola. The company was formerly known as Pensana Rare Earths Plc and changed its name to Pensana Plc in February 2021. Pensana Plc was incorporated in 2006 and is based in London, the United Kingdom.',
#  'city': 'London',
#  'country': 'United Kingdom',
#  'companyOfficers': [],
#  'website': 'http://www.pensana.co.uk',
#  'maxAge': 1,
#  'address1': '8 Signature by Regis',
#  'industry': 'Other Industrial Metals & Mining',
#  'address2': '100 Pall Mall St James',
#  'previousClose': 119.5,
#  'regularMarketOpen': 121.5,
#  'twoHundredDayAverage': 121.975174,
#  'trailingAnnualDividendYield': None,
#  'payoutRatio': 0,
#  'volume24Hr': None,
#  'regularMarketDayHigh': 122,
#  'navPrice': None,
#  'averageDailyVolume10Day': 541974,
#  'totalAssets': None,
#  'regularMarketPreviousClose': 119.5,
#  'fiftyDayAverage': 127.3,
#  'trailingAnnualDividendRate': None,
#  'open': 121.5,
#  'toCurrency': None,
#  'averageVolume10days': 541974,
#  'expireDate': None,
#  'yield': None,
#  'algorithm': None,
#  'dividendRate': None,
#  'exDividendDate': None,
#  'beta': None,
#  'circulatingSupply': None,
#  'startDate': None,
#  'regularMarketDayLow': 117.5,
#  'priceHint': 2,
#  'currency': 'GBp',
#  'regularMarketVolume': 115618,
#  'lastMarket': None,
#  'maxSupply': None,
#  'openInterest': None,
#  'marketCap': 245393424,
#  'volumeAllCurrencies': None,
#  'strikePrice': None,
#  'averageVolume': 575522,
#  'priceToSalesTrailing12Months': None,
#  'dayLow': 117.5,
#  'ask': 120.5,
#  'ytdReturn': None,
#  'askSize': None,
#  'volume': 115618,
#  'fiftyTwoWeekHigh': 205,
#  'forwardPE': None,
#  'fromCurrency': None,
#  'fiveYearAvgDividendYield': None,
#  'fiftyTwoWeekLow': 19.5,
#  'bid': 118,
#  'tradeable': False,
#  'dividendYield': None,
#  'bidSize': None,
#  'dayHigh': 122,
#  'exchange': 'LSE',
#  'shortName': 'PENSANA PLC ORD 01',
#  'longName': 'Pensana Plc',
#  'exchangeTimezoneName': 'Europe/London',
#  'exchangeTimezoneShortName': 'BST',
#  'isEsgPopulated': False,
#  'gmtOffSetMilliseconds': '3600000',
#  'quoteType': 'EQUITY',
#  'symbol': 'PRE.L',
#  'messageBoardId': 'finmb_37616530',
#  'market': 'gb_market',
#  'annualHoldingsTurnover': None,
#  'enterpriseToRevenue': None,
#  'beta3Year': None,
#  'profitMargins': 0,
#  'enterpriseToEbitda': -58.197,
#  '52WeekChange': 3.2962961,
#  'morningStarRiskRating': None,
#  'forwardEps': None,
#  'revenueQuarterlyGrowth': None,
#  'sharesOutstanding': 203646000,
#  'fundInceptionDate': None,
#  'annualReportExpenseRatio': None,
#  'bookValue': 0.109,
#  'sharesShort': None,
#  'sharesPercentSharesOut': None,
#  'fundFamily': None,
#  'lastFiscalYearEnd': 1593475200,
#  'heldPercentInstitutions': 0.00030000000000000003,
#  'netIncomeToCommon': -4664574,
#  'trailingEps': -1.9,
#  'lastDividendValue': None,
#  'SandP52WeekChange': 0.3666818,
#  'priceToBook': 1105.5046,
#  'heldPercentInsiders': 0.45764000000000005,
#  'nextFiscalYearEnd': 1656547200,
#  'mostRecentQuarter': 1609372800,
#  'shortRatio': None,
#  'sharesShortPreviousMonthDate': None,
#  'floatShares': 140379832,
#  'enterpriseValue': 235146640,
#  'threeYearAverageReturn': None,
#  'lastSplitDate': None,
#  'lastSplitFactor': None,
#  'legalType': None,
#  'lastDividendDate': None,
#  'morningStarOverallRating': None,
#  'earningsQuarterlyGrowth': None,
#  'dateShortInterest': None,
#  'pegRatio': None,
#  'lastCapGain': None,
#  'shortPercentOfFloat': None,
#  'sharesShortPriorMonth': None,
#  'impliedSharesOutstanding': 82362496,
#  'category': None,
#  'fiveYearAverageReturn': None,
#  'regularMarketPrice': 121.5,
#  'logo_url': 'https://logo.clearbit.com/pensana.co.uk'}

# %%
pre_price.Close.plot();

# %%
pre_price.Volume.plot();

# %%
palm_ticker = yf.Ticker('palm.l')

# %%
palm_price = palm_ticker.history(period='max')

# %%
palm_price
# Out:
#              Open    High     Low  Close   Volume  Dividends  Stock Splits
# Date
# 2020-01-09  13.50   9.000   6.775   6.50    20749          0             0
# 2020-01-10   6.50   6.700   5.800   6.15   317241          0             0
# 2020-01-13   6.15   6.700   4.000   4.35  1332896          0             0
# 2020-01-14   4.35   4.340   4.290   4.35    23694          0             0
# 2020-01-15   4.35   4.240   4.240   4.35    22508          0             0
# ...           ...     ...     ...    ...      ...        ...           ...
# 2021-06-11  13.75  13.825  13.500  13.75    65694          0             0
# 2021-06-14  13.75  13.883  13.000  13.75   449976          0             0
# 2021-06-15  13.75  14.320  13.750  14.00    86393          0             0
# 2021-06-16  14.00  14.320  13.755  14.00   176099          0             0
# 2021-06-18  13.60  13.600  13.500  13.50    53407          0             0
#
# [364 rows x 7 columns]

# %%
palm_price.Close.plot();

# %%
from pandas_datareader import data
start_date = '2014-01-01'
end_date = '2018-01-01'
goog_data = data.DataReader('goog', 'yahoo', start_date, end_date)

# %%
goog_data
# Out:
#                    High          Low         Open        Close     Volume  \
# Date
# 2014-01-02   556.788025   552.060730   555.647278   554.481689  3656454.0
# 2014-01-03   556.379578   550.401978   555.418152   550.436829  3345894.0
# 2014-01-06   557.340942   551.154114   554.426880   556.573853  3551864.0
# 2014-01-07   567.717041   558.486633   560.399475   567.303589  5124336.0
# 2014-01-08   571.517822   564.528992   570.860291   568.484192  4501811.0
# ...                 ...          ...          ...          ...        ...
# 2017-12-22  1064.199951  1059.439941  1061.109985  1060.119995   755100.0
# 2017-12-26  1060.119995  1050.199951  1058.069946  1056.739990   760600.0
# 2017-12-27  1058.369995  1048.050049  1057.390015  1049.369995  1271900.0
# 2017-12-28  1054.750000  1044.770020  1051.599976  1048.140015   837100.0
# 2017-12-29  1049.699951  1044.900024  1046.719971  1046.400024   887500.0
#
#               Adj Close
# Date
# 2014-01-02   554.481689
# 2014-01-03   550.436829
# 2014-01-06   556.573853
# 2014-01-07   567.303589
# 2014-01-08   568.484192
# ...                 ...
# 2017-12-22  1060.119995
# 2017-12-26  1056.739990
# 2017-12-27  1049.369995
# 2017-12-28  1048.140015
# 2017-12-29  1046.400024
#
# [1007 rows x 6 columns]

# %%
data = pd.DataFrame(goog_data['Adj Close'], index=goog_data.index)

# %%
data
# Out:
#               Adj Close
# Date
# 2014-01-02   554.481689
# 2014-01-03   550.436829
# 2014-01-06   556.573853
# 2014-01-07   567.303589
# 2014-01-08   568.484192
# ...                 ...
# 2017-12-22  1060.119995
# 2017-12-26  1056.739990
# 2017-12-27  1049.369995
# 2017-12-28  1048.140015
# 2017-12-29  1046.400024
#
# [1007 rows x 1 columns]

# %%
goog_data_signal = pd.DataFrame(index = goog_data.index)

# %%
goog_data_signal['price'] = goog_data['Adj Close']

# %%
goog_data_signal['daily_diff'] = goog_data_signal['price'].diff()

# %%
print(goog_data_signal.head())
# Out:
#                  price  daily_diff
# Date
# 2014-01-02  554.481689         NaN
# 2014-01-03  550.436829   -4.044861
# 2014-01-06  556.573853    6.137024
# 2014-01-07  567.303589   10.729736
# 2014-01-08  568.484192    1.180603

# %%
goog_data_signal['signal'] = 0.0

# %% [markdown]
# np.where(数据，对比值，正确填1，非正确填0)

# %%
goog_data_signal['signal'] = np.where(goog_data_signal['daily_diff']>0, 1.0, 0.0)

# %%
goog_data_signal.head()
# Out:
#                  price  daily_diff  signal
# Date
# 2014-01-02  554.481689         NaN     0.0
# 2014-01-03  550.436829   -4.044861     0.0
# 2014-01-06  556.573853    6.137024     1.0
# 2014-01-07  567.303589   10.729736     1.0
# 2014-01-08  568.484192    1.180603     1.0

# %%
goog_data_signal['positions'] = goog_data_signal['signal'].diff()

# %%
goog_data_signal.head(10)
# Out:
#                  price  daily_diff  signal  positions
# Date
# 2014-01-02  554.481689         NaN     0.0        NaN
# 2014-01-03  550.436829   -4.044861     0.0        0.0
# 2014-01-06  556.573853    6.137024     1.0        1.0
# 2014-01-07  567.303589   10.729736     1.0        0.0
# 2014-01-08  568.484192    1.180603     1.0        0.0
# 2014-01-09  563.009705   -5.474487     0.0       -1.0
# 2014-01-10  562.979797   -0.029907     0.0        0.0
# 2014-01-13  559.393250   -3.586548     0.0        0.0
# 2014-01-14  572.553955   13.160706     1.0        1.0
# 2014-01-15  572.165405   -0.388550     0.0       -1.0

# %% [markdown]
# 简单的趋势信号就做好了，1.6号买，1.9号卖，不考虑手续费，盈利为：

# %%
goog_data_signal.loc['2014-01-09'].price - goog_data_signal.loc['2014-01-06'].price
# Out:
# 6.43585205078125
