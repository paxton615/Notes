# %%
import pandas as pd, seaborn as sns, matplotlib.pyplot as plt
import numpy as np
# %config IPCompleter.greedy=True
# %config InlineBackend.figure_format = 'retina'
# %matplotlib inline
pd.options.display.max_rows = 5000 
from datetime import datetime
import warnings
warnings.filterwarnings('ignore')
import yfinance as yf

# %%
ccz = yf.Ticker('ccz.L')
ccz_2020 = ccz.history(start="2020-01-01", end= datetime.today().strftime('%Y-%m-%d'))
print(ccz_2020.shape)
print(ccz_2020.head())
print(ccz_2020.tail())
# Out:
# (202, 7)
#              Open  High   Low  Close    Volume  Dividends  Stock Splits
# Date
# 2020-08-04  2.025  2.48  1.75   2.30  23726309          0             0
# 2020-08-05  2.300  2.60  2.20   2.45   4903456          0             0
# 2020-08-06  2.450  2.67  2.20   2.45   4487446          0             0
# 2020-08-07  2.450  2.60  2.28   2.45     73193          0             0
# 2020-08-10  2.500  2.65  2.37   2.50   2734365          0             0
#             Open   High    Low  Close   Volume  Dividends  Stock Splits
# Date
# 2021-05-17  2.45  2.498  2.451   2.45  1121446          0             0
# 2021-05-18  2.45  2.487  2.400   2.45  1668886          0             0
# 2021-05-19  2.45  2.500  2.300   2.35   929648          0             0
# 2021-05-20  2.60  2.650  2.450   2.50  4714783          0             0
# 2021-05-21  2.50  2.590  2.477   2.50  1012584          0             0

# %%
tickers = ['palm.l','cobr.l','kat.l','amte.l','knb.l','kav.l','irr.l','mnrg.l'
          ,'ecr.l','ccz.l','imm.l','thr.l','avo.l','cgh.l','pre.l']
print(tickers)
# Out:
# ['palm.l', 'cobr.l', 'kat.l', 'amte.l', 'knb.l', 'kav.l', 'irr.l', 'mnrg.l', 'ecr.l', 'ccz.l', 'imm.l', 'thr.l', 'avo.l', 'cgh.l', 'pre.l']

# %%
ccz_2020.Close.plot();

# %%
df = pd.DataFrame()
for i in tickers:
    x = yf.Ticker(i)
    new_name = str(x) +'_2020'
    df[new_name] = x.history(start="2020-01-01", end= datetime.today().strftime('%Y-%m-%d')).Close

# %%
df.columns = [i.replace('yfinance.Ticker object <','') for i in df.columns]
df.columns = [i.replace('.L>_2020','') for i in df.columns]

# %%
df.head()
# Out:
#             PALM  COBR    KAT  AMTE     KNB  KAV     IRR   MNRG    ECR  CCZ  \
# Date
# 2020-01-09  6.50  1.25  0.925   NaN  0.0465  1.8  10.500  0.535  0.700  NaN
# 2020-01-10  6.15  1.25  0.925   NaN  0.0465  1.7  10.500  0.530  0.700  NaN
# 2020-01-13  4.35  1.25  0.925   NaN  0.0465  1.7  10.625  0.525  0.725  NaN
# 2020-01-14  4.35  1.25  0.925   NaN  0.0465  1.7  10.625  0.510  0.725  NaN
# 2020-01-15  4.35  1.25  0.925   NaN  0.0465  1.7  11.750  0.525  0.725  NaN
#
#               IMM    THR    AVO        CGH  PRE
# Date
# 2020-01-09  16.50  0.450  39.00  36.299999  NaN
# 2020-01-10  16.15  0.440  38.50  36.799999  NaN
# 2020-01-13  15.65  0.430  38.50  37.900002  NaN
# 2020-01-14  14.31  0.445  38.00  37.500000  NaN
# 2020-01-15  14.22  0.435  37.75  35.799999  NaN

# %%
df.columns
# Out:
# Index(['PALM', 'COBR', 'KAT', 'AMTE', 'KNB', 'KAV', 'IRR', 'MNRG', 'ECR',
#        'CCZ', 'IMM', 'THR', 'AVO', 'CGH', 'PRE'],
#       dtype='object')

# %%
df.index
# Out:
# DatetimeIndex(['2020-01-09', '2020-01-10', '2020-01-13', '2020-01-14',
#                '2020-01-15', '2020-01-16', '2020-01-17', '2020-01-20',
#                '2020-01-21', '2020-01-22',
#                ...
#                '2021-05-10', '2021-05-11', '2021-05-12', '2021-05-13',
#                '2021-05-14', '2021-05-17', '2021-05-18', '2021-05-19',
#                '2021-05-20', '2021-05-21'],
#               dtype='datetime64[ns]', name='Date', length=346, freq=None)

# %% [markdown]
# #### for some reason, data in 4.13 is divided by 100, need to get them back up.

# %%
# df.loc['2021-04-13',:] =df.loc['2021-04-13',:]*100

# %%
# df.tail(30)

# %%
fig = plt.figure(figsize=(15,8))
#get the axis
ax = fig.gca()
plt.legend()
ax.plot(df);
# Out:
# No handles with labels found to put in legend.

# %%
fig = plt.figure(figsize=(15,8))
#get the axis
ax = fig.gca()

ax.plot(np.log(df))

plt.show()

# %%
np.log(df).plot(figsize=(12,6));
