# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import warnings
from IPython.display import Image
from mpl_toolkits.mplot3d import Axes3D
from scipy import linalg  # for inverse matrix

# %%
Image(filename='/Users/paxton615/Github_Personal/Notes/Notes/pics/linear_algebra/.png')

# %% [markdown]
# ## 第三章
# ### 近似与拟合：真相最近处

# %% [markdown]
# 1. 从投影的角度去理解和定义最近距离
# 2. 描述向直线和平平面投影的过程
# 3. 介绍向n维空间投影的通用方法
# 4. 介绍最小二乘法原理
# 5. 运用最小二乘法解决无解方程组的近似解和线性拟合的实际问题
# 6. 运用施密特正交化的方法寻找任意空间的一组标准正交向量

# %% [markdown]
# https://zhuanlan.zhihu.com/p/43759544  MIT线数笔记1\
# ### 重温向量，矩阵，方程组的核心思想：
# 两个二元一次方程组的解：\
# 1.既可以看成是两条直线在平面上的交点。\
# 2.也可以看成是列向量的某种倍数组合。
#
# 方程：\
# 2x-y=0 \
# -x+2y=3

# %%
Image(filename='/Users/paxton615/Github_Personal/Notes/Notes/pics/linear_algebra/3.1a.png')

# %% [markdown]
# ### 多维行图像和多维列图像（从上图的二维到三维）

# %%
Image(filename='/Users/paxton615/Github_Personal/Notes/Notes/pics/linear_algebra/3.1b.png')

# %%
Image(filename='/Users/paxton615/Github_Personal/Notes/Notes/pics/linear_algebra/3.1c.png')

# %% [markdown]
# 这里的多维列图像因为各向量线性无关，因此以用它们表示的三维空间，***可以覆盖整个三维空间***

# %% [markdown]
# ### 矩阵与向量乘积的运算 \
# 1.矩阵乘以右侧列向量可看成矩阵各列向量的线性组合，结果为列向量！ \
# 2.左侧行向量乘以矩阵可以看做矩阵各行向量的线性组合，结果为行向量！

# %%
Image(filename='/Users/paxton615/Github_Personal/Notes/Notes/pics/linear_algebra/3.1d.png')

# %%
Image(filename='/Users/paxton615/Github_Personal/Notes/Notes/pics/linear_algebra/3.1e.png')

# %% [markdown]
# ### 列乘以行

# %%
Image(filename='/Users/paxton615/Github_Personal/Notes/Notes/pics/linear_algebra/3.1g.png')

# %% [markdown]
# ### 分块儿做乘法

# %%
Image(filename='/Users/paxton615/Github_Personal/Notes/Notes/pics/linear_algebra/3.1h.png')

# %% [markdown]
# ### 逆矩阵不存在的判定

# %%
Image(filename='/Users/paxton615/Github_Personal/Notes/Notes/pics/linear_algebra/3.1i.png')

# %% [markdown]
# ### 矩阵的转置Transpose

# %%
Image(filename='/Users/paxton615/Github_Personal/Notes/Notes/pics/linear_algebra/3.1j.png')

# %% [markdown]
# ### 向量空间

# %% [markdown]
# 理解：通过向量的相加或相乘，来表示整个特定的空间。之所以是相加或相乘，是因为这种运算只改变scale，不改变direction。

# %%
Image(filename='/Users/paxton615/Github_Personal/Notes/Notes/pics/linear_algebra/3.1k.png')

# %% [markdown]
# ### 子空间

# %% [markdown]
# 它们同样满足向量空间的规则，但它们只是向量空间的一部分。 \
# 二维空间的子空间：

# %%
Image(filename='/Users/paxton615/Github_Personal/Notes/Notes/pics/linear_algebra/3.1m.png')

# %% [markdown]
# 三维空间的子空间：

# %%
Image(filename='/Users/paxton615/Github_Personal/Notes/Notes/pics/linear_algebra/3.1l.png')

# %% [markdown]
# ### 子空间与方程组

# %%
Image(filename='/Users/paxton615/Github_Personal/Notes/Notes/pics/linear_algebra/3.1n.png')

# %% [markdown]
# Q1.这个方程始终有解么？ \
# 3维向量（原始空间）的线性组合是无法铺满整个4维空间（A）的，因此相乘后的Ax只能是4维空间的一个子空间，不能保证所有的4维向量b（映射结果）都能找到A列向量的一种线性组合，是的Ax=b

# %% [markdown]
# Q2.什么样的b可以使方程Ax=b有解？
# Ax表示A的列空间，因此，只要b在‘A的列空间中’，那么就能够找到一种A列向量的线性组合来构成b，是的Ax=b有解。

# %% [markdown]
# Q3.能否去掉A的一列，却不影响A的列空间（线性关系对维度的贡献）
# 1列+2列=3列，因此3列队线性组合没有贡献。1，2列就是构成A空间的主列。重新审视，A的列向量是4维空间里的2维子空间。

# %% [markdown]
# ### 零空间

# %% [markdown]
# 矩阵A的零空间为Ax=0的所有的解构成的向量空间，N（A）。

# %%
Image(filename='/Users/paxton615/Github_Personal/Notes/Notes/pics/linear_algebra/3.1o.png')

# %% [markdown]
# 因此，对于m*n的矩阵来说，列空间是Rm的子空间，零空间是Rn的子空间；
# 列空间的关键在于维数（秩数），零空间的关键在于列空间的个数（与n有关）。

# %% [markdown]
# ### 零空间与向量空间的重要关系

# %%
Image(filename='/Users/paxton615/Github_Personal/Notes/Notes/pics/linear_algebra/3.1p.png')

# %% [markdown]
# ### 秩与主变量和自由变量

# %%
Image(filename='/Users/paxton615/Github_Personal/Notes/Notes/pics/linear_algebra/3.1q.png')

# %% [markdown]
# ### 研究方程组的可解性
# 对于如下的一个方程组：

# %%
Image(filename='/Users/paxton615/Github_Personal/Notes/Notes/pics/linear_algebra/3.1r.png')

# %% [markdown]
# b为什么值时，（注意不是x为什么值时），方程会有解,否则无解！

# %%
Image(filename='/Users/paxton615/Github_Personal/Notes/Notes/pics/linear_algebra/3.1s.png')

# %%
Image(filename='/Users/paxton615/Github_Personal/Notes/Notes/pics/linear_algebra/3.1t.png')

# %% [markdown]
# ### Ax=b有解的条件总结：

# %% [markdown]
# ***1. 行， 如果方程组系数矩阵A的行向量的线性组合可生成 0向量，那么相同组合用在 b上，也必须得到 0.*** \
# ***2. 列， b必须是 A各列向量的线性组合.*** \
# ***3. 列空间，当且仅当 b属于 A的列空间时成立。***

# %%
Image(filename='/Users/paxton615/Github_Personal/Notes/Notes/pics/linear_algebra/3.1u.png')

# %%
Image(filename='/Users/paxton615/Github_Personal/Notes/Notes/pics/linear_algebra/3.1v.png')

# %%
Image(filename='/Users/paxton615/Github_Personal/Notes/Notes/pics/linear_algebra/3.1w.png')

# %%
Image(filename='/Users/paxton615/Github_Personal/Notes/Notes/pics/linear_algebra/3.1x.png')

# %%
Image(filename='/Users/paxton615/Github_Personal/Notes/Notes/pics/linear_algebra/3.1z.png')

# %% [markdown]
# ### 矩阵的秩

# %%
Image(filename='/Users/paxton615/Github_Personal/Notes/Notes/pics/linear_algebra/zhi1.png')

# %% [markdown]
# ***矩阵A不等于零的子式的最高阶数称为A的秩，零矩阵的秩是零。***

# %%
Image(filename='/Users/paxton615/Github_Personal/Notes/Notes/pics/linear_algebra/zhi2.png')

# %%
Image(filename='/Users/paxton615/Github_Personal/Notes/Notes/pics/linear_algebra/zhi3.png')
