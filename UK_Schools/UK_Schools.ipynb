# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
pd.options.display.max_columns=100 #(设定能显示的列数)

# %%
data = pd.read_csv('/Users/paxton615/database/2018-2019_886_school_information.csv')
kent = data

# %%
kent.head()
# Out:
#       URN LANAME   LA  ESTAB  LAESTAB                           SCHNAME  \
# 0  118245   Kent  886   2062  8862062  Darenth Community Primary School
# 1  118246   Kent  886   2066  8862066            Maypole Primary School
# 2  118254   Kent  886   2088  8862088        Crockenhill Primary School
# 3  118255   Kent  886   2089  8862089  The Anthony Roper Primary School
# 4  118257   Kent  886   2094  8862094             Cobham Primary School
#
#                     STREET     LOCALITY ADDRESS3       TOWN  ...  \
# 0  Green Street Green Road      Darenth      NaN   Dartford  ...
# 1            Franklin Road          NaN      NaN   Dartford  ...
# 2                The Green  Crockenhill      NaN        NaN  ...
# 3              High Street     Eynsford      NaN   Dartford  ...
# 4               The Street       Cobham      NaN  Gravesend  ...
#
#           MINORGROUP         SCHOOLTYPE ISPRIMARY ISSECONDARY ISPOST16 AGELOW  \
# ...

# %%
kent['TOWN'].unique()
# Out:
# array(['Dartford', nan, 'Gravesend', 'Rochester', 'Tonbridge',
#        'Sevenoaks', 'Edenbridge', 'Tunbridge Wells', 'Cranbrook',
#        'Maidstone', 'Headcorn', 'West Malling', 'Snodland', 'Faversham',
#        'Sittingbourne', 'Queenborough', 'Sheerness', 'Canterbury',
#        'Herne Bay', 'Whitstable', 'Ashford', 'Folkestone', 'Dover',
#        'Deal', 'Broadstairs', 'Westgate-on-Sea', 'Ramsgate', 'Riverhead',
#        'Aylesford', 'Hythe', 'Chatham', 'Swanley', 'Sandwich', 'Margate',
#        'Swanley Village', 'Longfield', 'Westerham', 'Gillingham',
#        'CANTERBURY', 'Romney Marsh', 'Birchington', 'Westgate on Sea',
#        'Tenterden', 'New Romney', 'DEAL', 'Otford', 'CRANBROOK', 'Kent',
#        'Swanscombe', 'Paddock Wood', 'Minster-on-Sea', 'Wilmington',
#        'Bexley', 'Temple Ewell', 'East Malling', 'Wye', 'Hadlow',
#        'Ebbsfleet', 'Greenhithe', 'Northfleet', 'Stone', 'Doddington'],
#       dtype=object)

# %%
data = pd.read_csv('/Users/paxton615/database/2018-2019_england_school_information.csv')

# %%
england = data

# %%
england
# Out:
#           URN          LANAME   LA  ESTAB  LAESTAB  \
# 0      100000  City of London  201   3614  2013614
# 1      100001  City of London  201   6005  2016005
# 2      100002  City of London  201   6006  2016006
# 3      100003  City of London  201   6007  2016007
# 4      100008          Camden  202   2019  2022019
# ...       ...             ...  ...    ...      ...
# 25550  148538           Derby  831   4011  8314011
# 25551  148545        Bradford  380   4092  3804092
# 25552  148547       Rotherham  372   4009  3724009
# 25553  148549  Leicestershire  855   4042  8554042
# 25554  148550        Somerset  933   2053  9332053
#
#                                     SCHNAME                     STREET  \
# 0                        The Aldgate School         St James's Passage
# 1           City of London School for Girls          St Giles' Terrace
# 2                St Paul's Cathedral School               2 New Change
# ...

# %%
england.ADMPOL.unique()
# Out:
# array(['Not applicable', 'Non-selective', 'Selective', nan], dtype=object)

# %%
england[england['TOWN']=='London'].count()
# Out:
# URN            1840
# LANAME         1840
# LA             1840
# ESTAB          1840
# LAESTAB        1840
# SCHNAME        1840
# STREET         1839
# LOCALITY       1143
# ADDRESS3        199
# TOWN           1840
# POSTCODE       1839
# SCHSTATUS      1840
# OPENDATE         61
# CLOSEDATE        73
# MINORGROUP     1840
# SCHOOLTYPE     1840
# ISPRIMARY      1840
# ISSECONDARY    1840
# ISPOST16       1840
# AGELOW         1836
# AGEHIGH        1836
# GENDER         1839
# RELCHAR        1811
# ADMPOL         1778
# dtype: int64

# %%
england.TOWN.nunique()
# Out:
# 1556

# %%
town = pd.DataFrame(england.groupby('TOWN')['LA'].count())

# %%
town[town['LA'] >= 20]
# Out:
#              LA
# TOWN
# Abingdon     38
# Accrington   34
# Alfreton     32
# Altrincham   32
# Amersham     21
# ...         ...
# Workington   22
# Worksop      29
# Worthing     39
# Yeovil       32
# York        151
#
# [325 rows x 1 columns]

# %%
town[town['LA'] >= 50]
# Out:
#                 LA
# TOWN
# Ashford         61
# Aylesbury       63
# Banbury         50
# Barnsley        84
# Basingstoke     57
# ...            ...
# Wigan           98
# Wirral          80
# Wolverhampton  128
# Worcester       65
# York           151
#
# [104 rows x 1 columns]

# %%
town[town['LA'] >= 100]
# Out:
#                        LA
# TOWN
# Bedford               106
# Birmingham            500
# Bolton                145
# Bradford              181
# Bristol               332
# Cambridge             127
# Colchester            107
# Coventry              149
# Derby                 169
# Doncaster             161
# Hull                  114
# Leeds                 265
# Leicester             238
# Lincoln               104
# Liverpool             274
# London               1840
# Manchester            419
# Milton Keynes         122
# Newcastle-upon-Tyne   144
# Northampton           140
# Norwich               199
# Nottingham            310
# Oldham                111
# Peterborough          126
# Plymouth              114
# Preston               171
# Reading               161
# Rotherham             105
# Sheffield             246
# Southampton           154
# Stockport             109
# Stoke-on-Trent        188
# Swindon               118
# Warrington            105
# ...

# %%
england[england['TOWN'] == 'Guildford']
# Out:
#           URN  LANAME   LA  ESTAB  LAESTAB  \
# 12534  124975  Surrey  936   2133  9362133
# 12544  124992  Surrey  936   2229  9362229
# 12551  125004  Surrey  936   2286  9362286
# 12554  125009  Surrey  936   5220  9365220
# 12562  125025  Surrey  936   2349  9362349
# 12584  125067  Surrey  936   2448  9362448
# 12592  125079  Surrey  936   2484  9362484
# 12632  125160  Surrey  936   3061  9363061
# 12636  125167  Surrey  936   3317  9363317
# 12653  125189  Surrey  936   3357  9363357
# 12659  125195  Surrey  936   3381  9363381
# 12663  125199  Surrey  936   3408  9363408
# 12666  125202  Surrey  936   3417  9363417
# 12690  125243  Surrey  936   3925  9363925
# 12692  125246  Surrey  936   3928  9363928
# 12698  125276  Surrey  936   4619  9364619
# 12703  125288  Surrey  936   5206  9365206
# 12705  125291  Surrey  936   5209  9365209
# 12710  125299  Surrey  936   5217  9365217
# 12716  125320  Surrey  936   6004  9366004
# 12733  125342  Surrey  936   6046  9366046
# ...

# %%
Oxfordshire

# %%
england[england['LANAME'] == 'Kent']
# Out:
#           URN LANAME   LA  ESTAB  LAESTAB  \
# 9251   118245   Kent  886   2062  8862062
# 9252   118246   Kent  886   2066  8862066
# 9253   118254   Kent  886   2088  8862088
# 9254   118255   Kent  886   2089  8862089
# 9255   118257   Kent  886   2094  8862094
# ...       ...    ...  ...    ...      ...
# 25345  148116   Kent  886   2183  8862183
# 25347  148118   Kent  886   3106  8863106
# 25414  148217   Kent  886   5202  8865202
# 25478  148308   Kent  886   3173  8863173
# 25516  148370   Kent  886   2327  8862327
#
#                                                  SCHNAME  \
# 9251                    Darenth Community Primary School
# 9252                              Maypole Primary School
# 9253                          Crockenhill Primary School
# 9254                    The Anthony Roper Primary School
# 9255                               Cobham Primary School
# ...                                                  ...
# ...

# %%
Oxfordshire_secondary_schools = pd.DataFrame(england[england['LANAME'] == 'Oxfordshire'].groupby('TOWN').count().POSTCODE)

# %%
Oxfordshire_secondary_schools[Oxfordshire_secondary_schools['POSTCODE']>=10].sort_values(by='POSTCODE', ascending=False)
# Out:
#                   POSTCODE
# TOWN
# Oxford                  94
# Banbury                 40
# Abingdon                38
# Witney                  29
# Bicester                24
# Didcot                  19
# Wallingford             15
# Wantage                 13
# Chipping Norton         12
# Henley-on-Thames        11
# Kidlington              11

# %%
kent_secondary_schools = pd.DataFrame(england[england['LANAME'] == 'Kent'].groupby('TOWN').count().POSTCODE)

# %%
kent_secondary_schools[kent_secondary_schools['POSTCODE']>=10].sort_values(by='POSTCODE', ascending=False)
# Out:
#                  POSTCODE
# TOWN
# Maidstone              65
# Ashford                52
# Canterbury             49
# Gravesend              41
# Tonbridge              41
# Tunbridge Wells        37
# Sevenoaks              37
# Sittingbourne          36
# Dartford               32
# Dover                  32
# Folkestone             27
# Deal                   22
# Ramsgate               21
# Cranbrook              17
# Faversham              16
# Broadstairs            14
# West Malling           11
# Margate                11
# Sheerness              10
# Herne Bay              10

# %%
from pyecharts import options as opts
from pyecharts.charts import Geo
from pyecharts.datasets import register_url

try:
    register_url("https://echarts-maps.github.io/echarts-countries-js/")
except Exception:
    import ssl

    ssl._create_default_https_context = ssl._create_unverified_context
    register_url("https://echarts-maps.github.io/echarts-countries-js/")

geo = (
    Geo()
    .add_schema(maptype="英国")
    .set_global_opts(title_opts=opts.TitleOpts(title="英国"))
    .render("geo_chart_countries_js.html")
)

# %%
from IPython.display import Image
from IPython.display import IFrame

# %%
from pyecharts import options as opts
from pyecharts.charts import Geo
from pyecharts.faker import Faker

c = (
    Geo()
    .add_schema(maptype="英国")
    .add("geo", [[['london',100],['york',200]]])
    .set_series_opts(label_opts=opts.LabelOpts(is_show=False))
    .set_global_opts(
        visualmap_opts=opts.VisualMapOpts(is_piecewise=True),
        title_opts=opts.TitleOpts(title="Geo-VisualMap（分段型）"),
    )
    .render("geo_visualmap_piecewise.html")
)
IFrame(src='./funnel_chart.html', width=1000, height=600)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-16-ee133edea817> in <module>
#       4
#       5 c = (
# ----> 6     Geo()
#       7     .add_schema(maptype="英国")
#       8     .add("geo", [[['london',100],['york',200]]])
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pyecharts/charts/basic_charts/geo.py in add(self, series_name, data_pair, type_, is_selected, symbol, symbol_size, blur_size, point_size, color, is_polyline, is_large, large_threshold, progressive, progressive_threshold, label_opts, effect_opts, linestyle_opts, tooltip_opts, itemstyle_opts, render_item, encode)
#      60     ):
#      61         self._zlevel += 1
# ---> 62         data = self._feed_data(data_pair, type_)
#      63
#      64         self._append_color(color)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pyecharts/charts/basic_charts/geo.py in _feed_data(self, data_pair, type_)
# ...

# %%
Image(filename='/Users/paxton615/Github_Personal/Notes/Notes/UK_Schools/geo_visualmap_piecewise.html')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-9-0ffa6ac74533> in <module>
# ----> 1 Image(filename='/Users/paxton615/Github_Personal/Notes/Notes/UK_Schools/geo_visualmap_piecewise.html')
#
# ~/opt/anaconda3/lib/python3.8/site-packages/IPython/core/display.py in __init__(self, data, url, filename, format, embed, width, height, retina, unconfined, metadata)
#    1214
#    1215         if self.embed and self.format not in self._ACCEPTABLE_EMBEDDINGS:
# -> 1216             raise ValueError("Cannot embed the '%s' image format" % (self.format))
#    1217         if self.embed:
#    1218             self._mimetype = self._MIMETYPES.get(self.format)
#
# ValueError: Cannot embed the 'html' image format

# %%
[list(z) for z in zip(Faker.provinces, Faker.values())]
# Out:
# [['广东', 134],
#  ['北京', 96],
#  ['上海', 44],
#  ['江西', 144],
#  ['湖南', 134],
#  ['浙江', 112],
#  ['江苏', 115]]
