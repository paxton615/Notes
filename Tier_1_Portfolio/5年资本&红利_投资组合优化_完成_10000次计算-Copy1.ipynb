# %%
import pandas as pd
import numpy as np
import datetime as dt
from datetime import datetime
from datetime import date
import matplotlib.pyplot as plt
import seaborn as sns
import re
import requests
pd.options.display.max_rows = 5000 
import warnings
warnings.filterwarnings('ignore')

# %%
stocks = ['AHT', 'AV', 'BA', 'GSK', 'HSBA', 'JD', 'NG', 'RDSB', 'RIO', 'SPX', 'TSCO', 'TW', 'ULVR']

# %%
def get_dates(lst, start_str, end_str):
    data = pd.read_csv(r'/Users/paxton615/Desktop/Stock_Price_csv/tier_1_stocks/{}.csv'.format(lst[0]))
    data = data.loc[(data['time']>=start_str)&(data['time']<end_str)]
    date = [datetime.fromisoformat(i[:10]) for i in data['time']]
    return(date)

# %%
def get_prices(lst,start_str, end_str):   
    new_list = []
    for i in lst:
        data = pd.read_csv(r'/Users/paxton615/Desktop/Stock_Price_csv/tier_1_stocks/{}.csv'.format(i)) # read data from csv 注意文件夹路径和文件名
        df = data[['time','close']]                                          # get time and close price
        df.columns = ['date', i]                                       # change column names
        df.date = [datetime.fromisoformat(i[:10]) for i in df['date']]       # convert dates into datetime
        df = df.loc[(df['date']>=start_str)&(df['date']<end_str)]    # make sure date start from 2016-01-01
        df = df.reset_index(drop=True)
        new_list.append(df[i])
    return(new_list)

# %%
date = get_dates(stocks,'2015-01-01','2020-01-01')
prices = get_prices(stocks,'2015-01-01','2020-01-01')

# %%
stock_prices = pd.DataFrame(np.array(prices).T, columns=stocks , index=np.array(date).T)
stock_prices.head()
# Out:
#                AHT         AV         BA     GSK       HSBA          JD  \
# 2015-01-02  1165.0  484.39999  469.20001  1383.0  612.00000  101.600000
# 2015-01-05  1182.0  470.79999  462.00000  1369.5  603.90002  101.400000
# 2015-01-06  1109.0  464.00000  456.70001  1357.0  593.70001   94.400000
# 2015-01-07  1109.0  463.29999  462.70001  1379.0  601.00000   95.159998
# 2015-01-08  1131.0  483.20001  468.89999  1427.5  606.20001   97.000000
#
#                    NG    RDSB     RIO     SPX       TSCO         TW    ULVR
# 2015-01-02  908.29999  2235.5  2970.0  2848.0  188.00000  134.89999  2606.0
# 2015-01-05  909.70001  2128.5  2883.5  2832.0  181.60001  133.80000  2573.0
# 2015-01-06  896.79999  2121.0  2944.5  2784.0  178.80000  131.10001  2574.0
# 2015-01-07  917.50000  2148.5  2962.5  2800.0  182.00000  132.39999  2591.0
# 2015-01-08  932.40002  2200.0  3027.5  2849.0  209.25000  132.80000  2668.0

# %%
stock_prices.tail()
# Out:
#                AHT         AV         BA     GSK       HSBA         JD  \
# 2019-12-23  2433.0  420.39999  577.79999  1815.0  599.00000  832.00000
# 2019-12-24  2437.0  422.60001  578.79999  1817.6  599.40002  834.40002
# 2019-12-27  2446.0  422.20001  579.59998  1818.8  597.79999  844.20001
# 2019-12-30  2405.0  420.20001  566.79999  1798.0  596.29999  832.20001
# 2019-12-31  2414.0  418.70001  564.79999  1779.0  591.90002  837.40002
#
#                    NG    RDSB     RIO     SPX       TSCO         TW    ULVR
# 2019-12-23  965.70001  2259.0  4559.0  9065.0  253.00000  191.50000  4429.0
# 2019-12-24  959.20001  2275.5  4535.0  9055.0  253.39999  192.60001  4389.5
# 2019-12-27  961.29999  2271.0  4548.5  9125.0  256.00000  194.45000  4416.0
# 2019-12-30  953.50000  2247.5  4507.0  9020.0  255.50000  194.00000  4373.0
# 2019-12-31  944.29999  2239.5  4503.0  8890.0  255.20000  193.39999  4350.5

# %% [markdown]
# #### Using df to facilitate following steps

# %%
df = stock_prices

# %% [markdown]
# ### 每年平均红利的回报率

# %%
div_5yrs_roi = [0.11866882, 0.2415348 , 0.233164  , 0.289224  , 0.38235506,
       0.07657471, 0.24634204, 0.4204902 , 0.4592588 , 0.15537502,
       0.05281924, 0.14314283, 0.27294232]  # 结果从‘红利5年收益计算’复制粘贴而来

# %%
div_5yrs_mean_roi = np.array(div_5yrs_roi) / 5
div_5yrs_mean_roi
# Out:
# array([0.02373376, 0.04830696, 0.0466328 , 0.0578448 , 0.07647101,
#        0.01531494, 0.04926841, 0.08409804, 0.09185176, 0.031075  ,
#        0.01056385, 0.02862857, 0.05458846])

# %% [markdown]
# ### covariance

# %%
# Log of percentage change, methods: .pct_change()  and  np.log(1+x)
# 但cov对彼此间的强弱关系度量magnitude不是很直观 
cov_matrix = df.pct_change().apply(lambda x: np.log(1+x)).cov()
cov_matrix.head(2)
# Out:
#           AHT        AV        BA       GSK      HSBA        JD        NG  \
# AHT  0.000365  0.000125  0.000100  0.000065  0.000106  0.000090  0.000026
# AV   0.000125  0.000228  0.000079  0.000045  0.000102  0.000104  0.000032
#
#          RDSB       RIO       SPX      TSCO        TW      ULVR
# AHT  0.000107  0.000154  0.000121  0.000072  0.000120  0.000047
# AV   0.000084  0.000107  0.000080  0.000106  0.000175  0.000039

# %% [markdown]
# ### .corr() 直观看到各股之间的correlation

# %%
corr_matrix = df.pct_change().apply(lambda x: np.log(1+x)).corr()
corr_matrix.head(2)
# Out:
#           AHT        AV        BA       GSK      HSBA        JD        NG  \
# AHT  1.000000  0.434803  0.417014  0.290717  0.436607  0.244262  0.118947
# AV   0.434803  1.000000  0.417631  0.254827  0.532805  0.356912  0.182602
#
#         RDSB       RIO       SPX      TSCO        TW      ULVR
# AHT  0.36753  0.404094  0.463824  0.215066  0.294437  0.199265
# AV   0.36652  0.356894  0.386856  0.398520  0.543614  0.210840

# %% [markdown]
# ### create weights for the portfolio 制定权数

# %%
weights = [0.050442  , 0.01677353, 0.03863963, 0.06460033, 0.01927376,
       0.18526292, 0.07234564, 0.0å4760596, 0.11553418, 0.15390222,
       0.082653  , 0.02023164, 0.13273519]
colnames = df.columns

print(weights,colnames)
# Out:
# [0.050442, 0.01677353, 0.03863963, 0.06460033, 0.01927376, 0.18526292, 0.07234564, 0.04760596, 0.11553418, 0.15390222, 0.082653, 0.02023164, 0.13273519] Index(['AHT', 'AV', 'BA', 'GSK', 'HSBA', 'JD', 'NG', 'RDSB', 'RIO', 'SPX',
#        'TSCO', 'TW', 'ULVR'],
#       dtype='object')

# %% [markdown]
# ### portfolio variance

# %%
port_weights = dict(zip(colnames,weights))

port_var = cov_matrix.mul(port_weights, axis=0).mul(port_weights, axis=1).sum().sum()

port_var # seems like the variance of the portfolio is very low
# Out:
# 8.300276009925509e-05

# %% [markdown]
# ### each stocks' mean return in certain amount of years

# %%
df.resample('Y').last()
# Out:
#                AHT         AV         BA     GSK       HSBA         JD  \
# 2015-12-31  1119.0  516.00000  499.60001  1373.0  536.20001  208.20000
# 2016-12-31  1580.0  486.39999  591.50000  1562.0  656.90002  317.89999
# 2017-12-31  1992.0  506.50000  573.00000  1322.5  766.90002  336.20001
# 2018-12-31  1637.0  375.50000  459.20001  1491.2  646.90002  348.79999
# 2019-12-31  2414.0  418.70001  564.79999  1779.0  591.90002  837.40002
#
#                    NG    RDSB     RIO     SPX       TSCO         TW    ULVR
# 2015-12-31  937.50000  1543.0  1979.5  3283.0  149.50000  203.10001  2926.5
# 2016-12-31  951.59998  2354.0  3158.5  4184.0  206.85001  153.50000  3292.5
# 2017-12-31  875.09998  2508.5  3942.0  5620.0  209.25000  206.39999  4125.5
# 2018-12-31  764.20001  2340.0  3730.0  6240.0  190.10001  136.25000  4108.5
# 2019-12-31  944.29999  2239.5  4503.0  8890.0  255.20000  193.39999  4350.5

# %%
stock_mean_return = df.resample('Y').last().pct_change().mean() 
stock_mean_return
# Out:
# AHT     0.242293
# AV     -0.039908
# BA      0.046008
# GSK     0.076222
# HSBA    0.037765
# JD      0.505686
# NG      0.010898
# RDSB    0.120278
# RIO     0.249281
# SPX     0.288164
# TSCO    0.161537
# TW      0.044997
# ULVR    0.108211
# dtype: float64

# %% [markdown]
# ## 以上，我们有了资本的stock_mean_return，还要加上红利的年收益率

# %%
div_5yrs_mean_roi
# Out:
# array([0.02373376, 0.04830696, 0.0466328 , 0.0578448 , 0.07647101,
#        0.01531494, 0.04926841, 0.08409804, 0.09185176, 0.031075  ,
#        0.01056385, 0.02862857, 0.05458846])

# %%
stock_mean_return = stock_mean_return + div_5yrs_mean_roi
stock_mean_return
# Out:
# AHT     0.266026
# AV      0.008399
# BA      0.092641
# GSK     0.134066
# HSBA    0.114236
# JD      0.521001
# NG      0.060166
# RDSB    0.204376
# RIO     0.341133
# SPX     0.319239
# TSCO    0.172101
# TW      0.073625
# ULVR    0.162800
# dtype: float64

# %% [markdown]
# #### calculate the portfolio returns, by adding the weights on each stock
#
# 这里有一个与之前计算不同的地方，按每年末价格计算，年均portfolio_return = 0.1424
#
# 但是，之前，按每天来做cumulative来计算，年均portfolio_return = 0.224
#
# 之前还用末年和初年，仅两年的数据算过一个数据，年均portfolio_return = 0.1467
#
# ### 第一个数据与第三个数据基本吻合，证明计算过程应该没有问题。是两种计算方式，产生了差距。需要继续验证那种方式更加准确。

# %%
portfolio_return = (weights * stock_mean_return).sum()
portfolio_return
# Out:
# 0.26447385923175454

# %% [markdown]
# #### calculate volatility is given by the annual standard deviation. Multiply by 250 because there are 250 trading days/year.

# %%
ann_sd = df.pct_change().apply(lambda x: np.log(1+x)).std().apply(lambda x: x*np.sqrt(250))
ann_sd
# Out:
# AHT     0.301952
# AV      0.238651
# BA      0.198753
# GSK     0.186321
# HSBA    0.201516
# JD      0.304766
# NG      0.181236
# RDSB    0.241384
# RIO     0.314986
# SPX     0.215461
# TSCO    0.277396
# TW      0.336443
# ULVR    0.194253
# dtype: float64

# %% [markdown]
# #### Creating a table for visualising returns and volatility of assets

# %%
assets = pd.concat([stock_mean_return, ann_sd], axis=1) 
assets.columns = ['Returns', 'Volatility']
assets
# Out:
#        Returns  Volatility
# AHT   0.266026    0.301952
# AV    0.008399    0.238651
# BA    0.092641    0.198753
# GSK   0.134066    0.186321
# HSBA  0.114236    0.201516
# JD    0.521001    0.304766
# NG    0.060166    0.181236
# RDSB  0.204376    0.241384
# RIO   0.341133    0.314986
# SPX   0.319239    0.215461
# TSCO  0.172101    0.277396
# TW    0.073625    0.336443
# ULVR  0.162800    0.194253

# %%
fig, ax = plt.subplots(ncols=2,figsize=(20, 5))
ax[0] = sns.barplot(x=assets.index, y="Returns", data=assets, ax=ax[0])    
ax[1] = sns.barplot(x=assets.index, y="Volatility", data=assets, ax=ax[1])   
ax[0].set_ylabel('Return',fontsize=20)
ax[1].set_ylabel('Volatility',fontsize=20)
# Out:
# Text(0, 0.5, 'Volatility')

# %%
nn = assets.sort_values(by='Returns', ascending=False).reset_index()

# %%
nn.index = nn.index +1

# %% [markdown]
# #### Plotting the efficient frontier
#
# Efficient frontier is a graph with ‘returns’ on the Y-axis and ‘volatility’ on the X-axis. It shows us the maximum return we can get for a set level of volatility, or conversely, the volatility that we need to accept for certain level of returns.

# %%
p_ret = [] # Define an empty array for portfolio returns
p_vol = [] # Define an empty array for portfolio volatility
p_weights = [] # Define an empty array for asset weights,cumulative sum must be 1

num_assets = len(df.columns)
num_portfolios = 10000 # Run 10000 times

# %%
weights = np.random.random(num_assets)
# weights = weights/np.sum(weights)
# p_weights.append(weights)

# %%
len(df.columns)
# Out:
# 13

# %%
(weights/weights.sum()).sum()
# Out:
# 1.0000000000000002

# %%
for portfolio in range(num_portfolios):
    weights = np.random.random(num_assets)
    weights = weights/np.sum(weights)
    p_weights.append(weights)
    returns = np.dot(weights, stock_mean_return) # Returns are the product of individual expected returns of asset and its weights
    p_ret.append(returns)
    
    var = cov_matrix.mul(weights, axis=0).mul(weights, axis=1).sum().sum()# Portfolio Variance
    sd = np.sqrt(var) # Daily standard deviation
    ann_sd = sd*np.sqrt(250) # Annual standard deviation = volatility
    p_vol.append(ann_sd)
    
# 10000 times needs approximately 15 seconds

# %%
returns = np.dot(weights, stock_mean_return)
returns
# Out:
# 0.1860208155390719

# %% [markdown]
# # 这里就是我思考的问题，如果我要把mean return和另一个notes里的红利5年数据相加，mean_return应该用天还是用年计算，我这里的mean_return的结果是每年的

# %%
stock_mean_return
# Out:
# AHT     0.266026
# AV      0.008399
# BA      0.092641
# GSK     0.134066
# HSBA    0.114236
# JD      0.521001
# NG      0.060166
# RDSB    0.204376
# RIO     0.341133
# SPX     0.319239
# TSCO    0.172101
# TW      0.073625
# ULVR    0.162800
# dtype: float64

# %%
data = {'Returns':p_ret, 'Volatility':p_vol}

for counter, symbol in enumerate(df.columns.tolist()):
    #print(counter, symbol)
    data[symbol+' weight'] = [w[counter] for w in p_weights]

# %%
portfolios  = pd.DataFrame(data)
portfolios.head() # Dataframe of the 10000 portfolios created
# Out:
#     Returns  Volatility  AHT weight  AV weight  BA weight  GSK weight  \
# 0  0.193132    0.156171    0.125474   0.111071   0.034006    0.099564
# 1  0.220750    0.150161    0.029867   0.097759   0.108143    0.007347
# 2  0.223229    0.152580    0.088186   0.013871   0.099867    0.009055
# 3  0.187096    0.142310    0.061723   0.007187   0.152049    0.030730
# 4  0.203040    0.152881    0.086098   0.101332   0.091561    0.064729
#
#    HSBA weight  JD weight  NG weight  RDSB weight  RIO weight  SPX weight  \
# 0     0.102553   0.031859   0.015054     0.078425    0.130082    0.082661
# 1     0.091710   0.188383   0.023384     0.154835    0.069223    0.003259
# 2     0.104032   0.109057   0.042244     0.094490    0.112794    0.103112
# 3     0.146309   0.022580   0.110480     0.103379    0.041574    0.184187
# 4     0.039980   0.101641   0.004532     0.110876    0.092538    0.044573
#
#    TSCO weight  TW weight  ULVR weight
# 0     0.065251   0.057276     0.066724
# 1     0.055416   0.029979     0.140694
# 2     0.052668   0.107723     0.062901
# 3     0.121270   0.008003     0.010530
# 4     0.085936   0.085273     0.090933

# %%
portfolios.describe()
# Out:
#             Returns    Volatility    AHT weight     AV weight     BA weight  \
# count  10000.000000  10000.000000  10000.000000  10000.000000  10000.000000
# mean       0.189653      0.147696      0.076361      0.077395      0.077545
# std        0.022474      0.006227      0.044145      0.044346      0.044550
# min        0.114672      0.130155      0.000021      0.000008      0.000002
# 25%        0.174004      0.143338      0.039142      0.040493      0.040383
# 50%        0.189803      0.147220      0.076419      0.077735      0.077511
# 75%        0.204795      0.151702      0.110873      0.111637      0.112037
# max        0.301202      0.176772      0.241930      0.249658      0.242218
#
#          GSK weight   HSBA weight     JD weight     NG weight   RDSB weight  \
# count  10000.000000  10000.000000  10000.000000  10000.000000  10000.000000
# mean       0.076822      0.076938      0.076583      0.077296      0.076872
# std        0.044268      0.044462      0.044615      0.044222      0.044204
# min        0.000014      0.000003      0.000026      0.000014      0.000067
# 25%        0.040151      0.039686      0.039259      0.040789      0.040252
# 50%        0.077047      0.077169      0.075801      0.077057      0.076866
# 75%        0.110645      0.110966      0.111777      0.111788      0.111187
# max        0.277078      0.241508      0.287587      0.242307      0.248845
#
#          RIO weight    SPX weight   TSCO weight     TW weight   ULVR weight
# count  10000.000000  10000.000000  10000.000000  10000.000000  10000.000000
# mean       0.076683      0.077149      0.076889      0.076816      0.076653
# std        0.044252      0.044350      0.044333      0.044241      0.044099
# min        0.000004      0.000028      0.000029      0.000015      0.000039
# 25%        0.039796      0.039846      0.039725      0.039904      0.039318
# 50%        0.075507      0.077597      0.076975      0.076604      0.076769
# 75%        0.111210      0.111820      0.111153      0.110879      0.111155
# max        0.243872      0.269855      0.259545      0.236089      0.277068

# %% [markdown]
# ###  maxium return portfolio

# %%
max_rtn = pd.DataFrame(portfolios.iloc[portfolios['Returns'].idxmax()])
max_rtn.iloc[:2]
# Out:
#                 8460
# Returns     0.301202
# Volatility  0.165483

# %%
max_rtn.iloc[2:].sort_values(by=[max_rtn.columns[0]], ascending=False)
# Out:
#                  8460
# JD weight    0.287587
# RIO weight   0.210270
# TSCO weight  0.136263
# ULVR weight  0.127237
# HSBA weight  0.070502
# RDSB weight  0.037242
# BA weight    0.034975
# AHT weight   0.032259
# AV weight    0.021942
# SPX weight   0.017673
# NG weight    0.012424
# GSK weight   0.009207
# TW weight    0.002419

# %% [markdown]
# ### Find the lowest volatility portfolio

# %%
min_vol = pd.DataFrame(portfolios.iloc[portfolios['Volatility'].idxmin()])
min_vol.iloc[:2]
# Out:
#                 2483
# Returns     0.172209
# Volatility  0.130155

# %%
min_vol.iloc[2:].sort_values(by=[min_vol.columns[0]], ascending=False)
# Out:
#                  2483
# GSK weight   0.158086
# NG weight    0.156487
# BA weight    0.134245
# ULVR weight  0.126054
# TSCO weight  0.084980
# JD weight    0.071097
# SPX weight   0.068763
# RIO weight   0.051700
# AV weight    0.039072
# HSBA weight  0.035087
# TW weight    0.026882
# RDSB weight  0.025596
# AHT weight   0.021949

# %%
# Plot efficient frontier
portfolios.plot.scatter(x='Volatility', y='Returns', marker='o', s=5, alpha=0.3, grid=True, figsize=[10,10]);

# %%
# plotting the maxium return portfolio
plt.subplots(figsize=[10,10])
plt.scatter(portfolios['Volatility'], portfolios['Returns'],marker='o', s=10, alpha=0.3);
plt.scatter(max_rtn.iloc[1], max_rtn.iloc[0], color='r', marker='*', s=200);

# %%
min_vol_port = portfolios.iloc[portfolios['Volatility'].idxmin()]
# idxmin() gives us the minimum value in the column specified.                               
min_vol_port
# Out:
# Returns        0.172209
# Volatility     0.130155
# AHT weight     0.021949
# AV weight      0.039072
# BA weight      0.134245
# GSK weight     0.158086
# HSBA weight    0.035087
# JD weight      0.071097
# NG weight      0.156487
# RDSB weight    0.025596
# RIO weight     0.051700
# SPX weight     0.068763
# TSCO weight    0.084980
# TW weight      0.026882
# ULVR weight    0.126054
# Name: 2483, dtype: float64

# %%
# plotting the minimum volatility portfolio
plt.subplots(figsize=[10,10])
plt.scatter(portfolios['Volatility'], portfolios['Returns'],marker='o', s=10, alpha=0.3);
plt.scatter(min_vol_port[1], min_vol_port[0], color='r', marker='*', s=200);

# %% [markdown]
# #### Sharpe Ratio
#
# Sharpe Ratio is the average return earned in excess of the risk-free rate per unit of volatility or total risk. Volatility is a measure of the price fluctuations of an asset or portfolio.

# %%
# Finding the optimal portfolio
rf = 0.01 # risk factor
optimal_risky_port = portfolios.iloc[((portfolios['Returns']-rf)/portfolios['Volatility']).idxmax()]
optimal_risky_port
# Out:
# Returns        0.301202
# Volatility     0.165483
# AHT weight     0.032259
# AV weight      0.021942
# BA weight      0.034975
# GSK weight     0.009207
# HSBA weight    0.070502
# JD weight      0.287587
# NG weight      0.012424
# RDSB weight    0.037242
# RIO weight     0.210270
# SPX weight     0.017673
# TSCO weight    0.136263
# TW weight      0.002419
# ULVR weight    0.127237
# Name: 8460, dtype: float64

# %%
# Plotting optimal portfolio
plt.subplots(figsize=(10, 10))
plt.scatter(portfolios['Volatility'], portfolios['Returns'],marker='o', s=10, alpha=0.3);
plt.scatter(min_vol_port[1], min_vol_port[0], color='r', marker='*', s=200);
plt.scatter(optimal_risky_port[1], optimal_risky_port[0], color='g', marker='*', s=200);

# %%
optimal_risky_port = pd.DataFrame(optimal_risky_port)
optimal_risky_port.iloc[:2]
# Out:
#                 8460
# Returns     0.301202
# Volatility  0.165483

# %%
optimal_risky_port.iloc[2:].sort_values(by = optimal_risky_port.columns[0], ascending=False)
# Out:
#                  8460
# JD weight    0.287587
# RIO weight   0.210270
# TSCO weight  0.136263
# ULVR weight  0.127237
# HSBA weight  0.070502
# RDSB weight  0.037242
# BA weight    0.034975
# AHT weight   0.032259
# AV weight    0.021942
# SPX weight   0.017673
# NG weight    0.012424
# GSK weight   0.009207
# TW weight    0.002419

# %%
(optimal_risky_port.iloc[2:].values)
# Out:
# array([[0.03225901],
#        [0.02194229],
#        [0.03497455],
#        [0.00920695],
#        [0.07050177],
#        [0.28758742],
#        [0.01242401],
#        [0.03724155],
#        [0.21027015],
#        [0.01767301],
#        [0.13626297],
#        [0.00241939],
#        [0.12723693]])

# %%
[i[0] for i in optimal_risky_port.iloc[2:].values]
# Out:
# [0.03225901438102995,
#  0.02194228542361982,
#  0.034974550871763294,
#  0.009206947688128575,
#  0.07050176576526508,
#  0.2875874228997454,
#  0.012424007991902047,
#  0.037241554526744824,
#  0.2102701493908237,
#  0.017673013662734684,
#  0.13626296727571727,
#  0.002419390836106476,
#  0.12723692928641883]

# %%
stocks
# Out:
# ['AHT',
#  'AV',
#  'BA',
#  'GSK',
#  'HSBA',
#  'JD',
#  'NG',
#  'RDSB',
#  'RIO',
#  'SPX',
#  'TSCO',
#  'TW',
#  'ULVR']
